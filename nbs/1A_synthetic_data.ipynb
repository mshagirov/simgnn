# %% [markdown]
# Preparing Simulation Data
# ===
#
# >Notebook for preparing synthetic datasets. This data will be called as a "raw data" in other notebooks.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import torch
from os import path
import datetime

from vertex_simulation.primitives import unit_hexagons, VoronoiRegions2Edges, Vertex, Monolayer
from vertex_simulation.simulation import Simulation_Honda, Simulation_Honda_t
from vertex_simulation.primitives import plot_graph_as_quiver, graph2networkx_with_pos
import networkx as nx
from simgnn.datautils import *

import matplotlib.pyplot as plt
import matplotlib
plt.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10,10) # use larger for presentation
matplotlib.rcParams['font.size']= 16 # use 14 for presentation

# %%
device = torch.device('cpu')
if torch.cuda.is_available():
    device = torch.device('cuda')
dtype = torch.float32
print(f'Defaults:\n |-device: {device}\n |-dtype : {dtype}')
# Out:
# Defaults:
#  |-device: cuda
#  |-dtype : torch.float32

# %% [markdown]
# # Raw Synthetic Dataset

# %% [markdown]
# ## Initialising cell monolayers

# %%
v_x,regions = unit_hexagons(3,3) # unit hexagons
edge_list,cells = VoronoiRegions2Edges(regions) #convert Voronoi regions to cells & edges

m = Monolayer(vertices = Vertex( v_x.copy().tolist(), dtype = dtype), edges = torch.tensor(edge_list), cells = cells)
m.to_(device) # to plot use --> plot_graph_as_quiver(cell_graph)

# %% [markdown]
# ## Plotting Monolayer Graphs

# %% [markdown]
# Using `plot_graph_as_quiver`

# %%
plt.figure(figsize=[2.5,2.5])
plot_graph_as_quiver(m)
plt.axis('equal');

# %% [markdown]
# Convert to `networkx.Graph` with `graph2networkx_with_pos` and use `networkx.draw` function

# %%
plt.figure(figsize=[2,2])
nx.draw(*graph2networkx_with_pos(m), node_size=50, width=1)
plt.axis('equal');

# %% [markdown]
# # Simulation

# %% [markdown]
# Prepare an initial state

# %% [markdown]
# - 17Nov2020: np seed 42, 10x10 cells, torch seed 0
# - 22Dec2020: np seed 24, 8x8 cells, torch seed 42

# %%
np.random.seed(24)# np RNG seed

v_x,regions = unit_hexagons(8,8) # unit hexagons
v_x += np.random.randn(v_x.shape[0], v_x.shape[1])*.2 #perturb vertices
edge_list,cells = VoronoiRegions2Edges(regions) #convert Voronoi regions to cells & edges
# Define cell monolayer
m = Monolayer(vertices = Vertex( v_x.copy().tolist(), dtype = dtype), edges = torch.tensor(edge_list), cells = cells)

# %% [markdown]
# - use the cell below for plotting `m`

# %%
plt.figure(figsize=[5,5])
nx.draw(*graph2networkx_with_pos(m), node_size=20, width=1)
plt.axis('equal');
plt.axis(False);
# plt.savefig('./sim_ocsill_10x10.png',dpi=100)

# %%
# # np.random.seed(21)
# Dt=0.001
# # t_tot = 5000
# t_unit = 1/Dt # t_start + 1/Dt
# t = np.linspace(0,t_unit*10,1000)*Dt

# N=3
# # omega0 = np.random.randint(0,5,size=(N,))# number of full peaks per-unit-of-time
# omega0 = np.array([0.0,0.03,.3]) # Number of peaks "half angular freq-y" from Uniform(0, 0.6) (later multiplied by "pi")
# phase0 = np.array([0.25,.0,.5]) # phase:Uniform([0, 1/2]) (later multiplied by "pi")

# fig, axs = plt.subplots(nrows=3,ncols=1,figsize=[15,15],sharex=True,sharey=True)

# for w,phi,ax,c in zip(omega0,phase0,axs,['crimson','steelblue','sandybrown']):
#     ax.plot(t,np.cos(w*np.pi*t+np.pi*phi)**2,lw=4, label=f'$\omega={w:2.2f}\pi$; $\phi={phi:2.2f}\pi$',color=c)
#     ax.legend(loc='upper right')

# plt.xlabel('Time [min]');plt.suptitle('$Cos^2(\omega t+\phi)$')

# # plt.savefig('oscillation_peaks_small.png',dpi=100)
# plt.show()

# %% [markdown]
# Base frequency selection for $cos^2(wt)$:
# $$\omega = peaks\_per\_unit\_time \times \pi$$
# e.g. for 5 peaks per-unit-time $\omega_0 = 5 \pi$. We can add random number (real number) of peaks to this "base frequency":
# - For $N_{max}$ peaks as threshold, I can sample:
# $$\omega\sim Unif(0,N_{max}\cdot \pi)$$
# - Phases ($\phi$) determine value at $t=0$ for $cos^2(wt+\phi) \in [0,1]$
# $$\phi \sim Unif(0,\frac{\pi}{2}) $$
# <!-- ![]('./oscillation_peaks_small.png') -->
# <img src="./oscillation_peaks_small.png" width=512>
# - I can also sample amplitudes, currently it is set to constant 2.5 ({0:off, 2.5:on})

# %% [markdown]
# My plan is to implement junctional oscillations as $\Lambda_{ij}(t)=\lambda_{ij}\cdot cos^2(\omega_{ij}t+\phi_{ij})$ in potential energy, for a set of vertices $V=\{v_i\in \mathbb{R}^2\}$ (vertex positions), and cells $C=\{c_k|c_k=\{v_l,v_m,\dots\}\}_{k=1:N_{cells}}$:
#
# $$U(V,t)=\sum_{cells: c_k}K^a_{c_k}(A_{c_k}-A_{c_k}^0)^2 + K^p_{c_k}(P_{c_k}-P_{c_k}^0)^2 + \sum_{edges:ij}\Lambda_{ij}(t)\cdot len_{ij}$$
#
# where $\Lambda_{ij}(t)$ is the "contractility".
#
# *Assumptions*:
# 1. Ka, A0, Kp, P0 are cell type specific and constant for the duration of simulation.
#     - i.e. {Ka, A0, Kp, P0} are same for all cells in a tissue and do not change in time.
# 2. $\lambda_{ij}$ are constant in time.
# 2. Ai, Pi, and lengths are NOT constant and change in time.
#     - Areas, perimeters, and lengths $\{A_i, P_i, len_{ij}\}_{cells}$ change passively.
#     - Lij depends on time (now only time, and could depend on the edge length and vertex positions in the future simulations)

# %% [markdown]
# Force acting on each vertex $v_i\in V$ ($v_i$ are vertex positions, $\mu$ linear/Stokes' drag coefficient )
# $$F_{v_i}=-\frac{\partial U(x,t)}{\partial v_i}=\mu{}\frac{dv_i}{dt}$$

# %% [markdown]
# Driving/restoring force $F^{(r)}_{ij}$ acts against the tension $T_{ij}$ acting on an edge `(i,j)`
# $$-T_{ij} = F^{(r)}_{ij}=-\frac{\partial U(V,t)}{\partial l_{ij}}$$
# $$T_{ij} = \Lambda_{ij}(t)+2K_p(P_i-P_i^0)+2K_p(P_j-P_j^0)$$
#
# $T_{ij}$ means tension, which is acting against the "driving" force ($F^{(r)}_{ij}$) to contract the edge `(i,j)`

# %% [markdown]
# Pressure (restoring force for area/volume)
# $$\pi_i=-\frac{\partial U(x,t)}{\partial A_i}$$
# $$\pi_i = - 2K_a(A_i-A_i^0)$$

# %%
# # # Sampling P0's (or A0's)
# plt.hist(torch.normal(mean=1.,std=.5,size=(len(edge_list),1) ).clamp_(0,6).reshape(1,-1),
#         label=f'{1.0};{0.5}');

# plt.hist(torch.normal(mean=0.25,std=1.5,size=(len(edge_list),1) ).clamp_(0,6).reshape(1,-1),alpha=.5,
#         label=f'{0.25};{1.5}');

# plt.hist(torch.normal(mean=1.,std=1.,size=(len(edge_list),1) ).clamp_(0,6).reshape(1,-1),alpha=.6,
#          label=f'{0.75};{1.0}');

# plt.legend();

# %%
torch.manual_seed(42);

# 1st trial: Amplitudes ~ Normal(mu=2.1,s.d.=.5) [clamped]
lmd_ij = torch.normal(mean=1.,std=1.,size=(len(edge_list),1) ).clamp_(0,5).type(dtype).to(device)
base_lmd_ij = 0.8+0.4*torch.rand((len(edge_list),1)).to(device)

# oscillation freq-s
# unit_of_time = 1 min = 1/Dt : Dt:simulation time step size
N_peaks_max = 0.6 # maximum number of peaks per unit of time
omega = N_peaks_max*np.pi*torch.rand_like(lmd_ij) # in [0, N_peaks_max*pi]
# Phase --> cos2 value at t=0
phases = 0.5*np.pi*torch.rand_like(lmd_ij) # in [0, 0.5*pi]


def Ka_t(mg,t): return 1.
# def A0_t(mg,t):
#     if t<0.5: C = 1.5
#     else: C = 2.3
#     return C - 1./ (1 + np.exp(20*(t-0.3)) ) 
def A0_t(mg,t): return 2.3
def Kp_t(mg,t): return 0.003
def P0_t(mg,t): return 0.
def Lambda_t(mg,t): return lmd_ij*torch.cos(omega*t+phases)**2 + base_lmd_ij

# %%
sim.sample_trajectory?
# Out:
# Signature:
# sim.sample_trajectory(
#     T=1000,
#     delta_T=0.001,
#     sample_freq=10,
#     print_freq=100,
# )
# Docstring:
# Run simulation for `T` time steps and sample vertex trajectories with frequency `sample_freq`.
# - T  : total number of time steps
# - delta_T: step size (e.g. for the numerical integration using Euler's method)
# - sample_freq: trajectory sampling frequency. Use `assert (T % sample_freq == 0)` in your implementation.
#
# Returns:
# t_samples, x_t, Energy_and_maxSpeed:
# - t_samples, x_t : time and vertex positions lists with len(x_t)==len(t_samples).
# - Energy_and_maxSpeed: tuple (t_Energy, Es, maxSpeed), where `Es` and `maxSpeed` are total energies and
# maximum vertex speeds (movements) for each time period in `t_Energy`.
# File:      ~/mbi-toast/kubeflow/codes/simgnn/nbs/vertex_simulation/simulation.py
# Type:      method

# %%
sim_params = {'Ka':Ka_t, 'A0':A0_t, 'Kp':Kp_t, 'P0':P0_t, 'Lambda_ij':Lambda_t}

m.vertices.requires_grad_(True) # grad tracking
m.to_(device) # to cuda or cpu
sim = Simulation_Honda_t(m = m, params = sim_params)

t, verts_t, Energies_maxSpeeds = sim.sample_trajectory(T=12000, delta_T=0.00164, sample_freq=100, print_freq=200)

# convert torch.Tensors to [Time x Vertices x 2] numpy array
# verts_t = np.array([vt.numpy() for vt in verts_t])
# Out:
# iter:200; t=0.326: E=262.1; max_spd = 5.2
# iter:400; t=0.654: E=253.5; max_spd = 1.7
# iter:600; t=0.982: E=262.3; max_spd = 2.4
# iter:800; t=1.310: E=277.3; max_spd = 6.3
# iter:1000; t=1.638: E=279.8; max_spd = 5.8
# iter:1200; t=1.966: E=271.1; max_spd = 5.9
# iter:1400; t=2.294: E=265.3; max_spd = 5.8
# iter:1600; t=2.622: E=267.3; max_spd = 4.9
# iter:1800; t=2.950: E=274.6; max_spd =   6
# iter:2000; t=3.278: E=  282; max_spd = 6.4
# iter:2200; t=3.606: E=  280; max_spd = 5.6
# iter:2400; t=3.934: E=271.9; max_spd = 5.6
# iter:2600; t=4.262: E=267.9; max_spd = 5.6
# iter:2800; t=4.590: E=270.3; max_spd = 6.6
# iter:3000; t=4.918: E=273.8; max_spd = 6.9
# iter:3200; t=5.246: E=275.6; max_spd = 6.1
# iter:3400; t=5.574: E=273.1; max_spd = 4.9
# iter:3600; t=5.902: E=269.3; max_spd = 7.1
# iter:3800; t=6.230: E=269.6; max_spd = 5.8
# iter:4000; t=6.558: E=270.7; max_spd = 6.3
# iter:4200; t=6.886: E=270.8; max_spd = 6.4
# iter:4400; t=7.214: E=270.6; max_spd = 6.5
# iter:4600; t=7.542: E=268.4; max_spd = 5.3
# iter:4800; t=7.870: E=264.4; max_spd =   5
# iter:5000; t=8.198: E=265.3; max_spd = 4.8
# iter:5200; t=8.526: E=265.8; max_spd = 6.3
# iter:5400; t=8.854: E=263.3; max_spd = 6.1
# iter:5600; t=9.182: E=266.5; max_spd = 6.4
# iter:5800; t=9.510: E=265.2; max_spd = 6.8
# iter:6000; t=9.838: E=264.7; max_spd = 5.8
# iter:6200; t=10.166: E=272.2; max_spd = 5.6
# iter:6400; t=10.494: E=272.9; max_spd = 6.3
# iter:6600; t=10.822: E=  268; max_spd = 4.7
# iter:6800; t=11.150: E=269.4; max_spd = 4.5
# iter:7000; t=11.478: E=270.2; max_spd = 4.4
# iter:7200; t=11.806: E=271.4; max_spd = 5.8
# iter:7400; t=12.134: E=272.8; max_spd = 5.6
# iter:7600; t=12.462: E=266.9; max_spd = 5.7
# iter:7800; t=12.790: E=263.7; max_spd = 5.3
# iter:8000; t=13.118: E=264.9; max_spd = 5.4
# iter:8200; t=13.446: E=264.5; max_spd =   5
# iter:8400; t=13.774: E=267.9; max_spd = 4.4
# iter:8600; t=14.102: E=271.4; max_spd = 6.2
# iter:8800; t=14.430: E=270.4; max_spd = 6.6
# iter:9000; t=14.758: E=271.1; max_spd = 5.1
# iter:9200; t=15.086: E=271.9; max_spd = 4.1
# iter:9400; t=15.414: E=273.7; max_spd = 5.8
# iter:9600; t=15.742: E=278.5; max_spd = 6.8
# iter:9800; t=16.070: E=277.1; max_spd = 6.6
# iter:10000; t=16.398: E=273.6; max_spd = 5.2
# iter:10200; t=16.726: E=270.5; max_spd = 6.5
# iter:10400; t=17.054: E=267.4; max_spd = 2.9
# iter:10600; t=17.382: E=268.9; max_spd = 4.1
# iter:10800; t=17.710: E=  271; max_spd = 6.1
# iter:11000; t=18.038: E=272.1; max_spd = 5.6
# iter:11200; t=18.366: E=273.1; max_spd = 6.8
# iter:11400; t=18.694: E=268.1; max_spd = 6.3
# iter:11600; t=19.022: E=264.1; max_spd = 6.1
# iter:11800; t=19.350: E=268.3; max_spd = 5.7
# iter:12000; t=19.678: E=273.1; max_spd = 5.8

# %% [markdown]
# Save simulation results and param-s:

# %%
sim_name = datetime.datetime.now().strftime('%d%m%Y_%H%M%S')+'_test'
dataDir = path.join('simgnn_data','test2025',sim_name)
mknewdir(dataDir);

# save simulation results
write_array(path.join(dataDir,'t_Energy_maxSpeed.npy'), np.array(Energies_maxSpeeds))
write_array(path.join(dataDir,'simul_t.npy'), np.array(t))
write_array(path.join(dataDir,'simul_vtxpos.npy'), np.array([vt.numpy() for vt in verts_t]))

# save monolayer's graph and cells
write_graph(path.join(dataDir,'graph_dict.pkl'), m)

# disable grad tracking
m.vertices.requires_grad_(False) # grad tracking
# move to cpu, assuming Simul-n param-s don't depend on vertices
m.to_(torch.device('cpu')) # to cuda or cpu

# cell shape parameters: area, perimeter, edge lengths
cell_params = {k:[] for k in ['Area', 'Perimeter', 'Length']} 
sim_param_vals = {k:[] for k in sim_params.keys()}
# (re-)compute areas and perimeters for sampled frames
for ti,vx in zip(t, verts_t):
    m.vertices.x = vx.cpu() # set new vertex positions
    # cell params for vx, t:
    cell_params['Area'].append(m.area().cpu().numpy())
    cell_params['Perimeter'].append(m.perimeter().cpu().numpy())
    cell_params['Length'].append(m.length().cpu().numpy())
    # simulation params for vx,t (usually depend only on t)
    for k in sim_param_vals:
        # here sim_params[k] doesn't depend on `m`, otherwise compute on "device"
        k_val = sim_params[k](m, ti)
        if isinstance(k_val, torch.Tensor):
            k_val = k_val.cpu().numpy()
        sim_param_vals[k].append(k_val)
        
# maybe can move some of the operations to the "Simulation" class' trajectory sampling
# convert lists of arrays to nd-arrays
cell_params = {k:np.array(cell_params[k]) for k in cell_params}
sim_param_vals = {k:np.array(sim_param_vals[k]) for k in sim_param_vals}

print('Please, re-check and verify that arrays in `sim_param_vals` are saved correctly')

for p in [cell_params, sim_param_vals]:
    # p: parameters (either cell or simulation)
    for k in p:
        # k: name of param
        write_array(path.join(dataDir,f'simul_{k}.npy'),p[k])
# Out:
# Please, re-check and verify that arrays in `sim_param_vals` are saved correctly

# %%
# load_array(path.join(dataDir,'t_Energy_maxSpeed.npy')).shape

# %% [markdown]
# ## Loading simulation results and params:

# %%
dataDir
# Out:
# 'simgnn_data/test2025/20012025_073724_test'

# %%
# dataDir = path.join('./simgnn_data/unimodal_wbasetens_sims/train/raw/','28052021_sim000')

# save simulation results
Energies_maxSpeeds = load_array(path.join(dataDir,'t_Energy_maxSpeed.npy'))
t = load_array(path.join(dataDir,'simul_t.npy')).tolist()
verts_t = load_array(path.join(dataDir,'simul_vtxpos.npy'))
verts_t = [torch.from_numpy(vx_t) for vx_t in verts_t]

# save monolayer's graph and cells
m_graph = load_graph(path.join(dataDir,'graph_dict.pkl'))
m = Monolayer(vertices=Vertex(verts_t[0]),
          edges=torch.tensor(m_graph['edges'],dtype=torch.long),
         cells = m_graph['cells'])

# # cell shape parameters: area, perimeter, edge lengths
# cell_params = {k:[] for k in ['Area', 'Perimeter', 'Length']} 
# sim_param_vals = {k:[] for k in sim_params.keys()}

# for ti,vx in zip(t, verts_t):
#     m.vertices.x = vx.cpu() # set new vertex positions
#     # cell params for vx, t:
#     cell_params['Area'].append(m.area().cpu().numpy())
#     cell_params['Perimeter'].append(m.perimeter().cpu().numpy())
#     cell_params['Length'].append(m.length().cpu().numpy())
#     # simulation params for vx,t (usually depend only on t)
#     for k in sim_param_vals:
#         # here sim_params[k] doesn't depend on `m`, otherwise compute on "device"
#         k_val = sim_params[k](m, ti)
#         if isinstance(k_val, torch.Tensor):
#             k_val = k_val.cpu().numpy()
#         sim_param_vals[k].append(k_val)

# cell_params = {k:np.array(cell_params[k]) for k in cell_params}
# sim_param_vals = {k:np.array(sim_param_vals[k]) for k in sim_param_vals}

# %% [markdown]
# ## Saving and Displaying Simulation Movies

# %% [markdown]
# `draw_graph`: **Function for plotting frames** (animation function)

# %%
import networkx as nx
from vertex_simulation.primitives import graph2networkx_with_pos
# as a networkx graph
Gnx,pos=graph2networkx_with_pos(m)
def draw_graph(i):
    '''Draw monolayer frames using networkx draw func-n. Assumes. Static graph, i.e. the graph `Gnx` is constant.
    We pass this function to matplotlib.animation obj.'''
    if isinstance(verts_t[i],  torch.Tensor):
        pos = dict(zip(range(verts_t[i].shape[0]),verts_t[i].numpy()))
    else:
        pos = dict(zip(range(verts_t[i].shape[0]),verts_t[i]))
    ax.cla()
    ax.axis('off')
    ax.set_title(f'Time : {t[i]:5.1f} mins',fontsize=50)
    nx.draw(Gnx,pos,node_size=20,width=8,ax=ax,node_color='#FF00FF',edge_color='#51C5FF')

# %%
# Test Drawing one of the frames:

fig = plt.figure(figsize=[10,10],dpi=40)
fig.clf()
ax = fig.subplots()
ax.axis(False);
draw_graph(len(verts_t)-1)
plt.show()

# %% [markdown]
# ### Option 1: Use PIL to save as GIF or TIFF

# %%
import PIL
pil_images=[]
for i in range(0,len(verts_t)):
    fig = plt.figure(figsize=[15,15],dpi=40)
    fig.clf()
    ax = fig.subplots()
    ax.axis(False);
    draw_graph(i)
    #     plt.show()
    canvas = plt.get_current_fig_manager().canvas
    canvas.draw()
    pil_images.append(PIL.Image.frombytes('RGB', canvas.get_width_height(), canvas.tostring_rgb()) )
    plt.close()
# duration:duration of each frame [s]
# loop : loop the video, see options
dataDir
pil_images[0].save(dataDir+'.gif', format='GIF',
               append_images=pil_images[1:], save_all=True, duration=0.1, loop=0)
# Out:
# /tmp/ipykernel_4526/2613531432.py:12: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   pil_images.append(PIL.Image.frombytes('RGB', canvas.get_width_height(), canvas.tostring_rgb()) )

# %%
# ```![](./sim_oscill_10x10.gif)```
from IPython.display import HTML
# HTML('<img src="./sim_oscill_10x10.gif" width=512>')
# HTML('<img src="./sim_oscill_8x8.gif" width=512>')

# HTML(f'<img src=\"{dataDir+".gif"}\" width=256>')

# %%
# !ls -lh $dataDir/..
# Out:
# total 2.0M
# drwxr-sr-x 2 jovyan 2001 4.0K Jan 20 07:21 20012025_072333_test
# -rw-r--r-- 1 jovyan 2001 2.0M Jan 20 07:22 20012025_072333_test.gif

# %% [markdown]
# ### Option 2: HTML video (for displaying) or Save as mp4

# %% [markdown]
# Display as HTML video or save as mp4 using matplotlit (+ffmpeg)
# ```python
# import matplotlib.animation as animation
# from IPython.display import HTML
# # create a figure
# fig = plt.figure(figsize=[10,10])
# fig.clf()
# # display (check your drawing/animation function)
# ax = fig.subplots()
# ax.axis(False);
# draw_graph(0)
# plt.show()
# plt.close()
# # Create an animation
# anim = animation.FuncAnimation(fig, draw_graph, interval=200, frames = range(50,len(verts_t)))
# # Convert animation to HTML repr-n and display w/ IPython
# HTML(anim.to_jshtml())
# ```

# %% [markdown]
# # Multiple Simulation Runs

# %%
import numpy as np
import torch
from os import path
import datetime

from vertex_simulation.primitives import unit_hexagons, VoronoiRegions2Edges, Vertex, Monolayer
from vertex_simulation.simulation import Simulation_Honda, Simulation_Honda_t
from simgnn.datautils import *

device = torch.device('cpu')
if torch.cuda.is_available():
    device = torch.device('cuda')
dtype = torch.float32
print(f'Defaults:\n |-device: {device}\n |-dtype : {dtype}')
# Out:
# Defaults:
#  |-device: cuda
#  |-dtype : torch.float32

# %%
__SIM_NAME__= 'unimodal_wbasetens_sims'
mknewdir(path.join('./simgnn_data',__SIM_NAME__))

SIM_SAVE_DIR = path.join('./simgnn_data',__SIM_NAME__,'raw')
mknewdir(SIM_SAVE_DIR)
print('Outputs will be saved in \n',SIM_SAVE_DIR)

N_sim_runs = 7

seed_seq = np.random.SeedSequence(42+3)
rngs = [np.random.Generator( np.random.PCG64(s)) for s in seed_seq.spawn(N_sim_runs)] # RNGs

# Simulation  Prop-s
T=6100 # total number of iter-s
delta_T=0.00164 # time step 
sample_freq=100 # movie frame_rate = sample_freq x delta_T

# Edge oscillations
#   unit_of_time = 1 min = 1/Dt ; Dt=simulation time step size
N_peaks_max = 0.6 # maximum number of peaks per unit of time


for sim_k in range(N_sim_runs):
    torch.manual_seed(42+3 + sim_k);
    
    sim_name = datetime.datetime.now().strftime('%d%m%Y')+f'_sim{sim_k:03}'
    tissue_shape = rngs[sim_k].choice([8,10],(2,))

    v_x,regions = unit_hexagons(tissue_shape[0], tissue_shape[1]) # unit hexagons
    v_x += rngs[0].standard_normal(size=(v_x.shape[0], v_x.shape[1]))*.2 #perturb vertices
    
    edge_list,cells = VoronoiRegions2Edges(regions) #convert Voronoi regions to cells & edges
    # Define cell monolayer
    m = Monolayer(vertices = Vertex( v_x.copy().tolist(), dtype = dtype),
                  edges = torch.tensor(edge_list),
                  cells = cells)

    # # # Cell param-s # # #
    Ka_cells = torch.normal(mean=1.0,std=0.1,size=(len(m.cells),) ).clamp_(0.75,1.25).type(dtype).to(device)
    A0_cells = torch.normal(mean=2.3,std=0.25,size=(len(m.cells),) ).clamp_(1.6,3).type(dtype).to(device)
    P0_cells = torch.normal(mean=0,std=0.15,size=(len(m.cells),1) ).clamp_(0,).type(dtype).to(device)
    Kp_cells = torch.normal(mean=0.003,std=0.001,size=(len(m.cells),1) ).clamp_(0.0001,).type(dtype).to(device)

    # "lambda_ij" amplitudes ~ Normal(mu=2.1,s.d.=.5) [clamped]
    # oscillation freq-s; unit_of_time = 1 min = 1/Dt : Dt:simulation time step size
    lmd_ij = torch.normal(mean=1.0,std=1.0,size=( m.edges.size(0),1) ).clamp_(0,6).type(dtype).to(device)
    base_lmd_ij = 0.4+1.2*torch.rand((m.edges.size(0),1)).to(device)
    omega_ij = N_peaks_max*np.pi*torch.rand_like(lmd_ij) # in [0, N_peaks_max*pi]
    phase_ij = 0.5*np.pi*torch.rand_like(lmd_ij) # in [0, 0.5*pi]; Phase --> cos2 value at t=0
    
    sim_params = {'Ka': lambda mg,t: Ka_cells, 'A0': lambda mg,t: A0_cells,
                  'Kp': lambda mg,t: Kp_cells, 'P0': lambda mg,t: P0_cells,
                  'Lambda_ij': lambda mg,t: base_lmd_ij + lmd_ij*torch.cos(omega_ij*t+phase_ij)**2 }

    m.vertices.requires_grad_(True) # grad tracking
    m.to_(device) # to cuda or cpu
    sim = Simulation_Honda_t(m = m, params = sim_params)
    
    print(f'\n{sim_name} {tissue_shape[0]}x{tissue_shape[1]}')
    t, verts_t, Energies_maxSpeeds = sim.sample_trajectory(T=T, delta_T=delta_T, sample_freq=sample_freq, print_freq=sample_freq)
    
    # convert torch.Tensors to [Time x Vertices x 2] numpy array
    # verts_t = np.array([vt.numpy() for vt in verts_t])
    
    dataDir = path.join(SIM_SAVE_DIR,sim_name)
    mknewdir(dataDir);
    print(f'Saving in {dataDir}')
    
    # save simulation results
    write_array(path.join(dataDir,'t_Energy_maxSpeed.npy'), np.array(Energies_maxSpeeds))
    write_array(path.join(dataDir,'simul_t.npy'), np.array(t))
    write_array(path.join(dataDir,'simul_vtxpos.npy'), np.array([vt.numpy() for vt in verts_t]))

    # save monolayer's graph and cells
    write_graph(path.join(dataDir,'graph_dict.pkl'), m)

    # disable grad tracking
    m.vertices.requires_grad_(False) # grad tracking
    # move to cpu, assuming Simul-n param-s don't depend on vertices
    m.to_(torch.device('cpu')) # to cuda or cpu

    # cell shape parameters: area, perimeter, edge lengths
    cell_params = {k:[] for k in ['Area', 'Perimeter', 'Length']} 
    sim_param_vals = {k:[] for k in sim_params.keys()}
    # (re-)compute areas and perimeters for sampled frames
    for ti,vx in zip(t, verts_t):
        m.vertices.x = vx.cpu() # set new vertex positions
        # cell params for vx, t:
        cell_params['Area'].append(m.area().cpu().numpy())
        cell_params['Perimeter'].append(m.perimeter().cpu().numpy())
        cell_params['Length'].append(m.length().cpu().numpy())
        # simulation params for vx,t (usually depend only on t)
        for k in sim_param_vals:
            # here sim_params[k] doesn't depend on `m`, otherwise compute on "device"
            k_val = sim_params[k](m, ti)
            if isinstance(k_val, torch.Tensor):
                k_val = k_val.cpu().numpy()
            sim_param_vals[k].append(k_val)

    # maybe can move some of the operations to the "Simulation" class' trajectory sampling
    # convert lists of arrays to nd-arrays
    cell_params = {k:np.array(cell_params[k]) for k in cell_params}
    sim_param_vals = {k:np.array(sim_param_vals[k]) for k in sim_param_vals}

    print('Please, re-check and verify that arrays in `sim_param_vals` are saved correctly')

    for p in [cell_params, sim_param_vals]:
        # p: parameters (either cell or simulation)
        for k in p:
            # k: name of param
            write_array(path.join(dataDir,f'simul_{k}.npy'),p[k])

print('--- Done ---')
# Out:
# Directory already exists.
# Directory already exists.
# Outputs will be saved in
#  ./simgnn_data/unimodal_wbasetens_sims/raw
#
# 28052021_sim000 10x10
# iter:100; t=0.162: E=465.9; max_spd = 4.8
# iter:200; t=0.326: E=414.1; max_spd = 5.8
# iter:300; t=0.490: E=391.6; max_spd = 6.2
# iter:400; t=0.654: E=386.2; max_spd = 5.7
# iter:500; t=0.818: E=390.2; max_spd = 4.6
# iter:600; t=0.982: E=399.3; max_spd = 5.9
# iter:700; t=1.146: E=411.2; max_spd = 6.4
# iter:800; t=1.310: E=426.3; max_spd = 5.7
# iter:900; t=1.474: E=437.2; max_spd = 5.2
# iter:1000; t=1.638: E=442.3; max_spd = 4.9
# iter:1100; t=1.802: E=440.6; max_spd = 7.4
# iter:1200; t=1.966: E=434.8; max_spd = 7.2
# iter:1300; t=2.130: E=427.9; max_spd = 5.8
# iter:1400; t=2.294: E=422.6; max_spd = 5.6
# iter:1500; t=2.458: E=420.6; max_spd =   6
# iter:1600; t=2.622: E=421.6; max_spd =   8
# iter:1700; t=2.786: E=424.8; max_spd = 3.7
# iter:1800; t=2.950: E=428.3; max_spd = 4.6
# iter:1900; t=3.114: E=429.7; max_spd =   8
# iter:2000; t=3.278: E=430.8; max_spd =   6
# iter:2100; t=3.442: E=430.8; max_spd = 6.9
# iter:2200; t=3.606: E=428.4; max_spd = 7.7
# iter:2300; t=3.770: E=423.7; max_spd = 7.8
# iter:2400; t=3.934: E=419.1; max_spd = 7.2
# iter:2500; t=4.098: E=415.1; max_spd = 6.4
# iter:2600; t=4.262: E=413.6; max_spd = 6.9
# iter:2700; t=4.426: E=415.5; max_spd = 4.9
# iter:2800; t=4.590: E=418.7; max_spd = 7.1
# iter:2900; t=4.754: E=419.6; max_spd = 6.2
# iter:3000; t=4.918: E=418.7; max_spd = 4.7
# iter:3100; t=5.082: E=415.4; max_spd = 6.9
# iter:3200; t=5.246: E=411.7; max_spd =   5
# iter:3300; t=5.410: E=409.8; max_spd = 6.8
# iter:3400; t=5.574: E=409.5; max_spd = 6.8
# iter:3500; t=5.738: E=410.8; max_spd = 6.9
# iter:3600; t=5.902: E=412.7; max_spd = 6.7
# iter:3700; t=6.066: E=416.4; max_spd = 7.5
# iter:3800; t=6.230: E=  421; max_spd = 4.8
# iter:3900; t=6.394: E=423.7; max_spd =   5
# iter:4000; t=6.558: E=422.6; max_spd = 5.1
# iter:4100; t=6.722: E=418.8; max_spd =   5
# iter:4200; t=6.886: E=414.4; max_spd = 7.2
# iter:4300; t=7.050: E=411.3; max_spd = 6.5
# iter:4400; t=7.214: E=410.3; max_spd = 6.5
# iter:4500; t=7.378: E=409.7; max_spd = 5.7
# iter:4600; t=7.542: E=408.8; max_spd = 5.7
# iter:4700; t=7.706: E=407.9; max_spd = 6.7
# iter:4800; t=7.870: E=407.4; max_spd = 4.5
# iter:4900; t=8.034: E=407.6; max_spd = 6.7
# iter:5000; t=8.198: E=410.5; max_spd = 4.7
# iter:5100; t=8.362: E=415.1; max_spd = 7.5
# iter:5200; t=8.526: E=417.6; max_spd = 6.4
# iter:5300; t=8.690: E=416.3; max_spd =   7
# iter:5400; t=8.854: E=413.1; max_spd =   7
# iter:5500; t=9.018: E=409.3; max_spd = 6.3
# iter:5600; t=9.182: E=407.2; max_spd = 6.6
# iter:5700; t=9.346: E=407.7; max_spd = 4.1
# iter:5800; t=9.510: E=409.9; max_spd = 7.3
# iter:5900; t=9.674: E=412.3; max_spd = 7.2
# iter:6000; t=9.838: E=  413; max_spd =   7
# iter:6100; t=10.002: E=  413; max_spd = 7.5
# Saving in ./simgnn_data/unimodal_wbasetens_sims/raw/28052021_sim000
# Please, re-check and verify that arrays in `sim_param_vals` are saved correctly
#
# 29052021_sim001 8x8
# iter:100; t=0.162: E=291.3; max_spd = 3.2
# iter:200; t=0.326: E=258.3; max_spd = 2.8
# iter:300; t=0.490: E=  246; max_spd = 5.4
# iter:400; t=0.654: E=  245; max_spd = 5.1
# iter:500; t=0.818: E=249.8; max_spd = 5.6
# iter:600; t=0.982: E=258.5; max_spd = 8.6
# iter:700; t=1.146: E=268.3; max_spd = 7.6
# iter:800; t=1.310: E=275.9; max_spd = 9.4
# iter:900; t=1.474: E=279.2; max_spd = 6.7
# iter:1000; t=1.638: E=276.7; max_spd = 9.5
# iter:1100; t=1.802: E=271.2; max_spd = 6.5
# iter:1200; t=1.966: E=264.9; max_spd = 7.4
# iter:1300; t=2.130: E=258.8; max_spd = 6.8
# iter:1400; t=2.294: E=255.1; max_spd =   7
# iter:1500; t=2.458: E=  254; max_spd = 6.2
# iter:1600; t=2.622: E=255.4; max_spd = 5.6
# iter:1700; t=2.786: E=258.4; max_spd = 5.7
# iter:1800; t=2.950: E=  261; max_spd =   6
# iter:1900; t=3.114: E=263.4; max_spd = 4.6
# iter:2000; t=3.278: E=265.3; max_spd = 6.3
# iter:2100; t=3.442: E=266.4; max_spd = 6.4
# iter:2200; t=3.606: E=266.2; max_spd = 5.8
# iter:2300; t=3.770: E=264.9; max_spd = 5.4
# iter:2400; t=3.934: E=263.5; max_spd = 5.9
# iter:2500; t=4.098: E=262.3; max_spd = 5.8
# iter:2600; t=4.262: E=260.5; max_spd =   9
# iter:2700; t=4.426: E=260.2; max_spd = 5.9
# iter:2800; t=4.590: E=261.3; max_spd = 5.4
# iter:2900; t=4.754: E=261.4; max_spd = 5.5
# iter:3000; t=4.918: E=260.3; max_spd = 5.6
# iter:3100; t=5.082: E=257.7; max_spd =   5
# iter:3200; t=5.246: E=254.5; max_spd = 6.6
# iter:3300; t=5.410: E=  253; max_spd = 6.5
# iter:3400; t=5.574: E=253.5; max_spd = 6.8
# iter:3500; t=5.738: E=254.7; max_spd = 5.1
# iter:3600; t=5.902: E=255.4; max_spd = 7.2
# iter:3700; t=6.066: E=256.4; max_spd = 8.2
# iter:3800; t=6.230: E=257.9; max_spd = 8.4
# iter:3900; t=6.394: E=259.8; max_spd = 7.8
# iter:4000; t=6.558: E=261.4; max_spd = 5.2
# iter:4100; t=6.722: E=261.7; max_spd = 5.2
# iter:4200; t=6.886: E=260.4; max_spd =   6
# iter:4300; t=7.050: E=258.4; max_spd = 4.5
# iter:4400; t=7.214: E=257.5; max_spd = 7.3
# iter:4500; t=7.378: E=257.8; max_spd = 7.9
# iter:4600; t=7.542: E=258.9; max_spd = 8.2
# iter:4700; t=7.706: E=  260; max_spd = 7.7
# iter:4800; t=7.870: E=261.3; max_spd = 6.7
# iter:4900; t=8.034: E=261.6; max_spd = 5.6
# iter:5000; t=8.198: E=259.9; max_spd = 5.8
# iter:5100; t=8.362: E=257.2; max_spd = 5.7
# iter:5200; t=8.526: E=253.9; max_spd = 5.4
# iter:5300; t=8.690: E=251.5; max_spd =   5
# iter:5400; t=8.854: E=251.7; max_spd = 7.2
# iter:5500; t=9.018: E=254.7; max_spd = 7.1
# iter:5600; t=9.182: E=257.5; max_spd = 5.4
# iter:5700; t=9.346: E=259.4; max_spd = 5.8
# iter:5800; t=9.510: E=261.3; max_spd = 6.8
# iter:5900; t=9.674: E=262.3; max_spd = 6.8
# iter:6000; t=9.838: E=263.5; max_spd = 6.6
# iter:6100; t=10.002: E=264.4; max_spd = 5.8
# Saving in ./simgnn_data/unimodal_wbasetens_sims/raw/29052021_sim001
# Please, re-check and verify that arrays in `sim_param_vals` are saved correctly
#
# 29052021_sim002 8x8
# iter:100; t=0.162: E=302.4; max_spd = 3.1
# iter:200; t=0.326: E=271.5; max_spd = 4.8
# iter:300; t=0.490: E=257.9; max_spd =   4
# iter:400; t=0.654: E=254.3; max_spd =   3
# iter:500; t=0.818: E=256.1; max_spd = 3.9
# iter:600; t=0.982: E=260.9; max_spd = 4.7
# iter:700; t=1.146: E=266.3; max_spd = 7.4
# iter:800; t=1.310: E=271.1; max_spd = 6.6
# iter:900; t=1.474: E=  274; max_spd = 6.6
# iter:1000; t=1.638: E=274.5; max_spd = 6.2
# iter:1100; t=1.802: E=272.4; max_spd = 4.8
# iter:1200; t=1.966: E=268.9; max_spd = 5.4
# iter:1300; t=2.130: E=265.4; max_spd = 4.9
# iter:1400; t=2.294: E=263.2; max_spd = 7.3
# iter:1500; t=2.458: E=262.6; max_spd = 5.7
# iter:1600; t=2.622: E=263.7; max_spd = 6.4
# iter:1700; t=2.786: E=266.2; max_spd = 6.6
# iter:1800; t=2.950: E=268.5; max_spd = 6.6
# iter:1900; t=3.114: E=  269; max_spd = 6.2
# iter:2000; t=3.278: E=  268; max_spd = 6.1
# iter:2100; t=3.442: E=266.1; max_spd = 6.1
# iter:2200; t=3.606: E=264.3; max_spd = 4.8
# iter:2300; t=3.770: E=262.9; max_spd =   4
# iter:2400; t=3.934: E=  262; max_spd = 3.1
# iter:2500; t=4.098: E=261.3; max_spd = 3.2
# iter:2600; t=4.262: E=260.1; max_spd = 5.3
# iter:2700; t=4.426: E=258.3; max_spd = 6.5
# iter:2800; t=4.590: E=257.1; max_spd = 7.5
# iter:2900; t=4.754: E=257.1; max_spd = 3.3
# iter:3000; t=4.918: E=257.4; max_spd = 7.6
# iter:3100; t=5.082: E=257.9; max_spd = 5.6
# iter:3200; t=5.246: E=257.6; max_spd = 5.7
# iter:3300; t=5.410: E=256.4; max_spd = 6.7
# iter:3400; t=5.574: E=255.4; max_spd = 6.2
# iter:3500; t=5.738: E=  255; max_spd = 5.6
# iter:3600; t=5.902: E=255.7; max_spd = 5.5
# iter:3700; t=6.066: E=  258; max_spd = 5.3
# iter:3800; t=6.230: E=260.5; max_spd = 5.1
# iter:3900; t=6.394: E=263.4; max_spd = 4.9
# iter:4000; t=6.558: E=266.5; max_spd = 4.9
# iter:4100; t=6.722: E=269.3; max_spd = 4.8
# iter:4200; t=6.886: E=271.2; max_spd = 4.7
# iter:4300; t=7.050: E=271.7; max_spd = 7.2
# iter:4400; t=7.214: E=271.1; max_spd = 5.6
# iter:4500; t=7.378: E=270.7; max_spd = 4.1
# iter:4600; t=7.542: E=270.4; max_spd =   4
# iter:4700; t=7.706: E=270.3; max_spd = 4.1
# iter:4800; t=7.870: E=270.2; max_spd =   5
# iter:4900; t=8.034: E=269.6; max_spd = 3.5
# iter:5000; t=8.198: E=268.2; max_spd = 5.8
# iter:5100; t=8.362: E=265.6; max_spd = 3.5
# iter:5200; t=8.526: E=262.3; max_spd = 4.3
# iter:5300; t=8.690: E=259.8; max_spd = 5.6
# iter:5400; t=8.854: E=258.6; max_spd = 4.4
# iter:5500; t=9.018: E=258.9; max_spd = 6.1
# iter:5600; t=9.182: E=260.9; max_spd = 4.4
# iter:5700; t=9.346: E=263.5; max_spd = 3.4
# iter:5800; t=9.510: E=265.7; max_spd = 3.8
# iter:5900; t=9.674: E=267.8; max_spd = 4.7
# iter:6000; t=9.838: E=269.7; max_spd = 4.1
# iter:6100; t=10.002: E=270.7; max_spd = 4.2
# Saving in ./simgnn_data/unimodal_wbasetens_sims/raw/29052021_sim002
# Please, re-check and verify that arrays in `sim_param_vals` are saved correctly
#
# 29052021_sim003 10x8
# iter:100; t=0.162: E=368.6; max_spd = 2.4
# iter:200; t=0.326: E=327.7; max_spd = 3.9
# iter:300; t=0.490: E=307.7; max_spd = 3.5
# iter:400; t=0.654: E=  301; max_spd = 2.6
# iter:500; t=0.818: E=302.7; max_spd = 2.9
# iter:600; t=0.982: E=309.5; max_spd = 6.6
# iter:700; t=1.146: E=318.6; max_spd = 4.6
# iter:800; t=1.310: E=329.1; max_spd = 6.8
# iter:900; t=1.474: E=338.2; max_spd = 5.7
# iter:1000; t=1.638: E=342.7; max_spd = 6.6
# iter:1100; t=1.802: E=341.7; max_spd = 3.7
# iter:1200; t=1.966: E=  337; max_spd = 4.9
# iter:1300; t=2.130: E=330.8; max_spd = 5.8
# iter:1400; t=2.294: E=325.1; max_spd =   7
# iter:1500; t=2.458: E=320.9; max_spd = 5.4
# iter:1600; t=2.622: E=  319; max_spd = 4.7
# iter:1700; t=2.786: E=  318; max_spd = 4.8
# iter:1800; t=2.950: E=  317; max_spd = 6.5
# iter:1900; t=3.114: E=316.2; max_spd = 4.6
# iter:2000; t=3.278: E=  316; max_spd = 5.2
# iter:2100; t=3.442: E=315.9; max_spd = 4.5
# iter:2200; t=3.606: E=316.2; max_spd = 5.5
# iter:2300; t=3.770: E=317.2; max_spd =   5
# iter:2400; t=3.934: E=319.2; max_spd = 4.6
# iter:2500; t=4.098: E=321.9; max_spd =   5
# iter:2600; t=4.262: E=323.9; max_spd = 5.8
# iter:2700; t=4.426: E=324.6; max_spd =   5
# iter:2800; t=4.590: E=323.9; max_spd = 4.1
# iter:2900; t=4.754: E=322.4; max_spd = 4.4
# iter:3000; t=4.918: E=320.8; max_spd = 5.8
# iter:3100; t=5.082: E=319.7; max_spd =   6
# iter:3200; t=5.246: E=318.4; max_spd = 5.3
# iter:3300; t=5.410: E=316.7; max_spd = 5.6
# iter:3400; t=5.574: E=  315; max_spd = 3.3
# iter:3500; t=5.738: E=315.1; max_spd = 4.9
# iter:3600; t=5.902: E=317.3; max_spd = 6.6
# iter:3700; t=6.066: E=320.2; max_spd = 5.9
# iter:3800; t=6.230: E=323.2; max_spd = 3.6
# iter:3900; t=6.394: E=326.3; max_spd = 4.2
# iter:4000; t=6.558: E=329.2; max_spd = 4.1
# iter:4100; t=6.722: E=330.7; max_spd = 6.3
# iter:4200; t=6.886: E=  329; max_spd = 5.5
# iter:4300; t=7.050: E=325.1; max_spd = 6.6
# iter:4400; t=7.214: E=321.1; max_spd = 6.1
# iter:4500; t=7.378: E=  318; max_spd = 5.8
# iter:4600; t=7.542: E=316.6; max_spd = 5.3
# iter:4700; t=7.706: E=315.6; max_spd = 6.3
# iter:4800; t=7.870: E=314.1; max_spd = 5.9
# iter:4900; t=8.034: E=311.8; max_spd = 5.5
# iter:5000; t=8.198: E=  310; max_spd = 5.4
# iter:5100; t=8.362: E=308.6; max_spd = 4.2
# iter:5200; t=8.526: E=307.3; max_spd = 5.6
# iter:5300; t=8.690: E=306.4; max_spd = 6.3
# iter:5400; t=8.854: E=306.7; max_spd = 6.2
# iter:5500; t=9.018: E=307.7; max_spd = 5.1
# iter:5600; t=9.182: E=308.6; max_spd = 6.4
# iter:5700; t=9.346: E=310.3; max_spd = 5.9
# iter:5800; t=9.510: E=312.6; max_spd = 4.7
# iter:5900; t=9.674: E=314.2; max_spd =   7
# iter:6000; t=9.838: E=314.1; max_spd =   7
# iter:6100; t=10.002: E=313.1; max_spd = 7.5
# Saving in ./simgnn_data/unimodal_wbasetens_sims/raw/29052021_sim003
# Please, re-check and verify that arrays in `sim_param_vals` are saved correctly
#
# 29052021_sim004 10x10
# iter:100; t=0.162: E=490.7; max_spd = 7.2
# iter:200; t=0.326: E=439.1; max_spd = 5.9
# iter:300; t=0.490: E=414.6; max_spd = 5.7
# iter:400; t=0.654: E=408.2; max_spd =   5
# iter:500; t=0.818: E=412.5; max_spd =   4
# iter:600; t=0.982: E=421.8; max_spd = 6.2
# iter:700; t=1.146: E=433.6; max_spd = 4.8
# iter:800; t=1.310: E=444.4; max_spd = 5.5
# iter:900; t=1.474: E=452.7; max_spd =   6
# iter:1000; t=1.638: E=456.5; max_spd =   8
# iter:1100; t=1.802: E=455.1; max_spd = 6.3
# iter:1200; t=1.966: E=449.5; max_spd = 5.6
# iter:1300; t=2.130: E=441.6; max_spd = 6.7
# iter:1400; t=2.294: E=434.6; max_spd = 4.7
# iter:1500; t=2.458: E=431.8; max_spd = 6.5
# iter:1600; t=2.622: E=433.3; max_spd = 6.2
# iter:1700; t=2.786: E=437.3; max_spd = 6.1
# iter:1800; t=2.950: E=440.9; max_spd = 5.3
# iter:1900; t=3.114: E=443.6; max_spd = 6.1
# iter:2000; t=3.278: E=445.9; max_spd = 6.9
# iter:2100; t=3.442: E=446.4; max_spd = 6.6
# iter:2200; t=3.606: E=445.6; max_spd = 5.7
# iter:2300; t=3.770: E=443.5; max_spd = 5.3
# iter:2400; t=3.934: E=440.1; max_spd = 4.8
# iter:2500; t=4.098: E=435.3; max_spd = 6.5
# iter:2600; t=4.262: E=430.9; max_spd = 7.6
# iter:2700; t=4.426: E=428.1; max_spd = 8.4
# iter:2800; t=4.590: E=427.1; max_spd = 7.1
# iter:2900; t=4.754: E=427.2; max_spd = 7.1
# iter:3000; t=4.918: E=428.5; max_spd =   6
# iter:3100; t=5.082: E=429.6; max_spd = 6.6
# iter:3200; t=5.246: E=430.2; max_spd = 4.6
# iter:3300; t=5.410: E=429.7; max_spd = 4.8
# iter:3400; t=5.574: E=428.9; max_spd =   6
# iter:3500; t=5.738: E=428.4; max_spd = 7.4
# iter:3600; t=5.902: E=429.3; max_spd =   6
# iter:3700; t=6.066: E=432.9; max_spd = 6.9
# iter:3800; t=6.230: E=  438; max_spd =   9
# iter:3900; t=6.394: E=441.5; max_spd = 9.1
# iter:4000; t=6.558: E=440.8; max_spd = 9.2
# iter:4100; t=6.722: E=436.3; max_spd = 9.2
# iter:4200; t=6.886: E=  429; max_spd =   9
# iter:4300; t=7.050: E=421.9; max_spd = 7.7
# iter:4400; t=7.214: E=  417; max_spd =   7
# iter:4500; t=7.378: E=415.3; max_spd = 7.5
# iter:4600; t=7.542: E=417.2; max_spd = 3.9
# iter:4700; t=7.706: E=420.8; max_spd = 6.4
# iter:4800; t=7.870: E=425.5; max_spd = 6.3
# iter:4900; t=8.034: E=431.1; max_spd = 5.7
# iter:5000; t=8.198: E=435.2; max_spd = 4.1
# iter:5100; t=8.362: E=436.9; max_spd = 6.9
# iter:5200; t=8.526: E=438.1; max_spd = 5.4
# iter:5300; t=8.690: E=439.6; max_spd = 5.9
# iter:5400; t=8.854: E=  441; max_spd = 5.9
# iter:5500; t=9.018: E=442.2; max_spd = 6.8
# iter:5600; t=9.182: E=  443; max_spd = 7.3
# iter:5700; t=9.346: E=443.4; max_spd = 6.3
# iter:5800; t=9.510: E=444.8; max_spd = 5.7
# iter:5900; t=9.674: E=447.2; max_spd = 6.8
# iter:6000; t=9.838: E=448.8; max_spd = 6.7
# iter:6100; t=10.002: E=447.1; max_spd = 6.9
# Saving in ./simgnn_data/unimodal_wbasetens_sims/raw/29052021_sim004
# Please, re-check and verify that arrays in `sim_param_vals` are saved correctly
#
# 29052021_sim005 10x10
# iter:100; t=0.162: E=454.3; max_spd = 2.3
# iter:200; t=0.326: E=407.5; max_spd =   2
# iter:300; t=0.490: E=386.2; max_spd =   7
# iter:400; t=0.654: E=  381; max_spd = 5.2
# iter:500; t=0.818: E=384.8; max_spd = 1.9
# iter:600; t=0.982: E=  392; max_spd = 3.8
# iter:700; t=1.146: E=400.2; max_spd = 5.4
# iter:800; t=1.310: E=406.8; max_spd = 4.8
# iter:900; t=1.474: E=410.9; max_spd = 5.7
# iter:1000; t=1.638: E=411.8; max_spd = 5.7
# iter:1100; t=1.802: E=408.3; max_spd = 6.8
# iter:1200; t=1.966: E=401.5; max_spd = 4.3
# iter:1300; t=2.130: E=392.4; max_spd = 4.7
# iter:1400; t=2.294: E=384.4; max_spd = 6.9
# iter:1500; t=2.458: E=381.3; max_spd = 4.8
# iter:1600; t=2.622: E=383.6; max_spd = 6.2
# iter:1700; t=2.786: E=389.8; max_spd = 5.4
# iter:1800; t=2.950: E=397.2; max_spd = 6.1
# iter:1900; t=3.114: E=402.6; max_spd = 4.1
# iter:2000; t=3.278: E=405.2; max_spd = 5.1
# iter:2100; t=3.442: E=404.4; max_spd = 3.8
# iter:2200; t=3.606: E=401.3; max_spd = 6.2
# iter:2300; t=3.770: E=396.9; max_spd = 5.6
# iter:2400; t=3.934: E=392.8; max_spd = 5.3
# iter:2500; t=4.098: E=389.4; max_spd = 4.7
# iter:2600; t=4.262: E=386.8; max_spd = 4.7
# iter:2700; t=4.426: E=384.8; max_spd = 5.9
# iter:2800; t=4.590: E=384.7; max_spd = 8.3
# iter:2900; t=4.754: E=386.9; max_spd = 5.9
# iter:3000; t=4.918: E=390.1; max_spd = 6.3
# iter:3100; t=5.082: E=  393; max_spd = 6.5
# iter:3200; t=5.246: E=393.6; max_spd = 6.5
# iter:3300; t=5.410: E=392.4; max_spd = 6.4
# iter:3400; t=5.574: E=390.9; max_spd = 5.7
# iter:3500; t=5.738: E=390.3; max_spd = 5.2
# iter:3600; t=5.902: E=391.3; max_spd = 6.6
# iter:3700; t=6.066: E=393.5; max_spd = 6.2
# iter:3800; t=6.230: E=394.8; max_spd = 4.3
# iter:3900; t=6.394: E=394.8; max_spd = 5.3
# iter:4000; t=6.558: E=392.8; max_spd = 6.5
# iter:4100; t=6.722: E=389.6; max_spd = 6.4
# iter:4200; t=6.886: E=386.3; max_spd =   7
# iter:4300; t=7.050: E=384.5; max_spd = 5.2
# iter:4400; t=7.214: E=  383; max_spd = 4.3
# iter:4500; t=7.378: E=382.4; max_spd = 7.2
# iter:4600; t=7.542: E=382.7; max_spd = 7.1
# iter:4700; t=7.706: E=384.3; max_spd = 5.9
# iter:4800; t=7.870: E=385.4; max_spd = 6.5
# iter:4900; t=8.034: E=386.2; max_spd = 5.5
# iter:5000; t=8.198: E=386.7; max_spd = 7.6
# iter:5100; t=8.362: E=387.3; max_spd = 7.8
# iter:5200; t=8.526: E=387.1; max_spd = 5.5
# iter:5300; t=8.690: E=385.9; max_spd = 5.3
# iter:5400; t=8.854: E=384.7; max_spd = 5.9
# iter:5500; t=9.018: E=385.4; max_spd = 4.5
# iter:5600; t=9.182: E=387.2; max_spd = 4.7
# iter:5700; t=9.346: E=389.2; max_spd = 6.4
# iter:5800; t=9.510: E=390.1; max_spd = 5.7
# iter:5900; t=9.674: E=389.5; max_spd = 6.2
# iter:6000; t=9.838: E=387.7; max_spd = 5.4
# iter:6100; t=10.002: E=385.5; max_spd = 4.9
# Saving in ./simgnn_data/unimodal_wbasetens_sims/raw/29052021_sim005
# Please, re-check and verify that arrays in `sim_param_vals` are saved correctly
#
# 29052021_sim006 10x8
# iter:100; t=0.162: E=392.9; max_spd = 2.8
# iter:200; t=0.326: E=348.5; max_spd =   6
# iter:300; t=0.490: E=  327; max_spd = 6.2
# iter:400; t=0.654: E=320.3; max_spd = 2.2
# iter:500; t=0.818: E=322.3; max_spd = 4.5
# iter:600; t=0.982: E=328.6; max_spd = 5.9
# iter:700; t=1.146: E=336.4; max_spd = 5.4
# iter:800; t=1.310: E=342.7; max_spd = 5.7
# iter:900; t=1.474: E=345.6; max_spd = 5.7
# iter:1000; t=1.638: E=  346; max_spd = 5.2
# iter:1100; t=1.802: E=342.9; max_spd =   7
# iter:1200; t=1.966: E=337.2; max_spd =   5
# iter:1300; t=2.130: E=333.2; max_spd = 6.9
# iter:1400; t=2.294: E=332.5; max_spd = 5.8
# iter:1500; t=2.458: E=334.5; max_spd = 5.8
# iter:1600; t=2.622: E=  340; max_spd = 5.6
# iter:1700; t=2.786: E=346.5; max_spd = 6.2
# iter:1800; t=2.950: E=352.2; max_spd =   6
# iter:1900; t=3.114: E=356.3; max_spd = 4.9
# iter:2000; t=3.278: E=356.8; max_spd = 5.5
# iter:2100; t=3.442: E=353.3; max_spd = 6.1
# iter:2200; t=3.606: E=346.3; max_spd = 7.6
# iter:2300; t=3.770: E=  339; max_spd = 6.6
# iter:2400; t=3.934: E=334.4; max_spd = 6.4
# iter:2500; t=4.098: E=  334; max_spd = 6.4
# iter:2600; t=4.262: E=336.2; max_spd = 6.2
# iter:2700; t=4.426: E=338.9; max_spd = 5.1
# iter:2800; t=4.590: E=340.9; max_spd = 5.3
# iter:2900; t=4.754: E=342.9; max_spd = 7.3
# iter:3000; t=4.918: E=344.7; max_spd = 6.6
# iter:3100; t=5.082: E=344.9; max_spd = 6.2
# iter:3200; t=5.246: E=343.2; max_spd =   7
# iter:3300; t=5.410: E=  340; max_spd = 6.5
# iter:3400; t=5.574: E=336.9; max_spd = 6.2
# iter:3500; t=5.738: E=336.1; max_spd = 6.4
# iter:3600; t=5.902: E=338.1; max_spd = 4.5
# iter:3700; t=6.066: E=341.5; max_spd = 6.2
# iter:3800; t=6.230: E=  345; max_spd = 5.2
# iter:3900; t=6.394: E=347.3; max_spd = 4.6
# iter:4000; t=6.558: E=348.9; max_spd = 5.1
# iter:4100; t=6.722: E=347.7; max_spd = 6.1
# iter:4200; t=6.886: E=  343; max_spd = 5.8
# iter:4300; t=7.050: E=337.6; max_spd = 6.4
# iter:4400; t=7.214: E=333.2; max_spd = 5.2
# iter:4500; t=7.378: E=330.6; max_spd = 5.7
# iter:4600; t=7.542: E=330.5; max_spd = 5.6
# iter:4700; t=7.706: E=332.4; max_spd = 5.1
# iter:4800; t=7.870: E=335.8; max_spd = 5.7
# iter:4900; t=8.034: E=338.5; max_spd = 5.2
# iter:5000; t=8.198: E=  339; max_spd = 4.9
# iter:5100; t=8.362: E=337.6; max_spd = 5.6
# iter:5200; t=8.526: E=335.4; max_spd = 6.3
# iter:5300; t=8.690: E=333.1; max_spd = 5.9
# iter:5400; t=8.854: E=331.3; max_spd = 5.4
# iter:5500; t=9.018: E=331.6; max_spd = 5.4
# iter:5600; t=9.182: E=334.6; max_spd = 4.9
# iter:5700; t=9.346: E=339.1; max_spd =   6
# iter:5800; t=9.510: E=  344; max_spd = 5.6
# iter:5900; t=9.674: E=349.3; max_spd = 6.1
# iter:6000; t=9.838: E=353.5; max_spd = 4.4
# iter:6100; t=10.002: E=355.1; max_spd = 7.6
# Saving in ./simgnn_data/unimodal_wbasetens_sims/raw/29052021_sim006
# Please, re-check and verify that arrays in `sim_param_vals` are saved correctly
# --- Done ---

# %% [markdown]
# ---
# Load saved simulations:

# %%
dataDir = path.join('./simgnn_data/single_distr_sims/raw','27052021_sim000')

# save simulation results
Energies_maxSpeeds = load_array(path.join(dataDir,'t_Energy_maxSpeed.npy'))
t = load_array(path.join(dataDir,'simul_t.npy')).tolist()
verts_t = load_array(path.join(dataDir,'simul_vtxpos.npy'))
verts_t = [torch.from_numpy(vx_t) for vx_t in verts_t]

# save monolayer's graph and cells
m_graph = load_graph(path.join(dataDir,'graph_dict.pkl'))
m = Monolayer(vertices=Vertex(verts_t[0]),
          edges=torch.tensor(m_graph['edges'],dtype=torch.long),
         cells = m_graph['cells'])

# # cell shape parameters: area, perimeter, edge lengths
# cell_params = {k:[] for k in ['Area', 'Perimeter', 'Length']} 
# sim_param_vals = {k:[] for k in sim_params.keys()}

# for ti,vx in zip(t, verts_t):
#     m.vertices.x = vx.cpu() # set new vertex positions
#     # cell params for vx, t:
#     cell_params['Area'].append(m.area().cpu().numpy())
#     cell_params['Perimeter'].append(m.perimeter().cpu().numpy())
#     cell_params['Length'].append(m.length().cpu().numpy())
#     # simulation params for vx,t (usually depend only on t)
#     for k in sim_param_vals:
#         # here sim_params[k] doesn't depend on `m`, otherwise compute on "device"
#         k_val = sim_params[k](m, ti)
#         if isinstance(k_val, torch.Tensor):
#             k_val = k_val.cpu().numpy()
#         sim_param_vals[k].append(k_val)

# cell_params = {k:np.array(cell_params[k]) for k in cell_params}
# sim_param_vals = {k:np.array(sim_param_vals[k]) for k in sim_param_vals}

# %% [markdown]
# # Analysis of Simulated Dataset

# %%
# %ls ./simgnn_data/

# %% [markdown]
# **!!!** Load modules in ***Section 1*** before continuing

# %%
import numpy as np
import torch
from os import path
import datetime

import networkx as nx
from simgnn.datautils import load_array, load_graph
from simgnn.datasets import VertexDynamics

import matplotlib.pyplot as plt
import matplotlib
plt.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10,10) # use larger for presentation
matplotlib.rcParams['font.size']= 12 # use 14 for presentation

# %%
data_dirs_ = [path.join('simgnn_data', k, 'train') for k in ['unimodal_wbasetens_sims', 'single_distr_sims'] ]

# for k in data_dirs_:
#     print(k)
#     %ls $k
#     print('---')

sim_train_data = {0: ['28052021_sim000', '29052021_sim002', '29052021_sim004', '29052021_sim001', '29052021_sim003'],
                  1: ['27052021_sim000', '27052021_sim002', '27052021_sim004', '27052021_sim001', '27052021_sim003'] }

sim_train_data
# Out:
# {0: ['28052021_sim000',
#   '29052021_sim002',
#   '29052021_sim004',
#   '29052021_sim001',
#   '29052021_sim003'],
#  1: ['27052021_sim000',
#   '27052021_sim002',
#   '27052021_sim004',
#   '27052021_sim001',
#   '27052021_sim003']}

# %% [markdown]
# ## Recalculating Edge Tensions from Raw Data

# %% [markdown]
# Calculate edge tensions yourself using:
# - Edge tensions
# $$T_{edge:(i,j)} = \Lambda_{ij}(t)+2\cdot\sum_{k\in\{cells\ for\ (i,j)\}}K_p^{(k)}(p^{(k)}-p_0^{(k)})$$
# - (Cell pressures $\pi_{cell:k} = -2K_a^{(k)}(a^{(k)}-a_0^{(k)})$ )
#
# or use `VertexDynamics` (which loads all movies in folder `raw` and calculates edge tensions using the same equation above for all frames starting with frame `window_size`)

# %%
DATASET_id = 0
MOVIE_id = 0

# %%
# VertexDynamics (preprocessed data)
unimodal_dataset = VertexDynamics(data_dirs_[DATASET_id])
window_size = unimodal_dataset.window_size
print(f'VertexDynamics\n---\nw:{unimodal_dataset.window_size}\n---\n',
      f'starting three frames, first frame is frame `w:{unimodal_dataset.window_size}` in a original movie:\n',
      unimodal_dataset.processed_file_names[:3],'\n')
# Out:
# VertexDynamics
# ---
# w:5
# ---
#  starting three frames, first frame is frame `w:5` in a original movie:
#  ['data_28052021_sim000_0.pt', 'data_28052021_sim000_1.pt', 'data_28052021_sim000_2.pt']

# %%
# RAW DATASET
movie_path_ = path.join(data_dirs_[DATASET_id], 'raw', sim_train_data[DATASET_id][MOVIE_id])
print('Raw dataset\n---\n',
      'Loading data from :\n--->\t',movie_path_)

print('\n---\nFrames before index=`window_size` are removed to match `VertexDynamics` indexing\n---')
p_ci = load_array(path.join(movie_path_,'simul_Perimeter.npy'))[window_size:-1]
p_ci = p_ci.reshape(p_ci.shape[0], -1)
Kp_ci = load_array(path.join(movie_path_,'simul_Kp.npy'))[window_size:-1].reshape(p_ci.shape[0], -1)
p0_ci = load_array(path.join(movie_path_,'simul_P0.npy'))[window_size:-1].reshape(p_ci.shape[0], -1)
lamb_ij = load_array(path.join(movie_path_,'simul_Lambda_ij.npy'))[window_size:-1].reshape(p_ci.shape[0], -1)

print(f'\nlamb_ij:{lamb_ij.shape};\nKp_ci:{Kp_ci.shape};\np0_ci: {p0_ci.shape};\np_ci:{p_ci.shape}')

# For aggregating cells w.r.t. edges
m_graph = load_graph(path.join(movie_path_, 'graph_dict.pkl')) # monolayer_graph

edge_cells = {ei: [] for ei in range(len(m_graph['edges']))}
for ci in m_graph['cells']:
    for ei in np.abs(m_graph['cells'][ci]) - 1:
        edge_cells[ei].append(ci)
# Out:
# Raw dataset
# ---
#  Loading data from :
# --->	 simgnn_data/unimodal_wbasetens_sims/train/raw/28052021_sim000
#
# ---
# Frames before index=`window_size` are removed to match `VertexDynamics` indexing
# ---
#
# lamb_ij:(56, 339);
# Kp_ci:(56, 100);
# p0_ci: (56, 100);
# p_ci:(56, 100)

# %%
Tmem_ci = 2.0*Kp_ci*( p_ci - p0_ci)
Tij_from_raw = lamb_ij + np.concatenate([Tmem_ci[:, edge_cells[ei]].sum(axis=1, keepdims=True) for ei in edge_cells], axis=1)
print('Absolute differences between Tij re-calculated',
      'from raw and calculted in VertexDynamics dataset:\n(must be zero; frame=w)\n')
# Tij_from_raw now starts with frame "window_size"
print(np.sum(np.abs(unimodal_dataset[0].edge_tensions.numpy() - Tij_from_raw[0])))
# Out:
# Absolute differences between Tij re-calculated from raw and calculted in VertexDynamics dataset:
# (must be zero; frame=w)
#
# 0.0

# %% [markdown]
# ## Edge Tension Dynamics

# %%
vtxdatasets = { path.basename(path.abspath(path.join(data_dirs_[k],path.pardir))): VertexDynamics(data_dirs_[k])
               for k in range(len(data_dirs_))}
vtxdatasets
# Out:
# {'unimodal_wbasetens_sims': VertexDynamics(280),
#  'single_distr_sims': VertexDynamics(280)}

# %% [markdown]
# - Select **simulation** date and **movie**:

# %%
vtx_sim = vtxdatasets['unimodal_wbasetens_sims']
sim_file_ids = [k.split('_')[2] for k in vtx_sim.processed_file_names]
sim_names = {k:ki for ki, k in enumerate(np.unique(sim_file_ids).tolist())}
sim_ids = np.array([sim_names[k] for k in sim_file_ids])

k = 0
mov_k = vtx_sim[torch.from_numpy(sim_ids==k)]

# %%
Tij_mov_k = np.concatenate([d.edge_tensions.numpy().reshape(1,-1) for d in mov_k],axis=0)
print('Tij_mov_k', Tij_mov_k.shape)

# for k in [10,20,25,30,50]:
#     plt.plot(Tij_mov_k[:,k])
# Out:
# Tij_mov_k (56, 339)

# %%
lenij_mov_k = np.concatenate([torch.linalg.norm(d.pos[d.edge_index[1]] - d.pos[d.edge_index[0]], axis=1).numpy().reshape(1,-1) for d in mov_k],axis=0)
dLdt = np.diff(lenij_mov_k,axis=0)
print('lenij_mov_k', lenij_mov_k.shape)

# for k in [10,20,25,30,50]:
#     plt.plot(lenij_mov_k[:,k])
# Out:
# lenij_mov_k (56, 339)

# %%
len_limits = [np.quantile(lenij_mov_k, 0.01), np.quantile(lenij_mov_k, 0.995)]
dlen_limits = [np.quantile(dLdt, 0.01), np.quantile(dLdt, 0.995)]

# %% [markdown]
# ---

# %%
e_ijs = np.random.choice(lenij_mov_k.shape[1], size=(9,), replace=False)

# %%
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=[17,15], sharex=True, sharey=True)
fig.tight_layout(h_pad=5, w_pad=8)

for k,ax in zip(e_ijs, axs.ravel()):
    p1, = ax.plot(Tij_mov_k[:,k], lenij_mov_k[:,k], c='teal', alpha=0.7, lw=3, label=r'$L$')
    
    ax2 = ax.twinx()
    p2, = ax2.plot(Tij_mov_k[:,k][:-1], np.diff(lenij_mov_k[:,k]), c='tomato', alpha=0.5, lw=3,
                   label=r'$\Delta{}L$')
    
    ax.set_xlabel(f'{k} : Tension')
    ax.set_ylabel(r'$Length$', color=p1.get_color())
    ax.tick_params(axis='y', labelcolor=p1.get_color())
    ax.set_ylim(len_limits[0], len_limits[1])
    
    ax2.set_ylabel(r'$\Delta{}Length$', color=p2.get_color())
    ax2.tick_params(axis='y', labelcolor=p2.get_color())
    ax2.set_ylim(dlen_limits[0], dlen_limits[1])
    
    ax.legend(loc='upper left')
    ax2.legend(loc='upper right')
    
plt.suptitle('Tension, Length and Deformation Speed', y=1.01 , fontsize=24);
# plt.savefig('tension_dynamics_phasediagram.png',dpi=100, bbox_inches="tight")

# %%
frames = np.arange(Tij_mov_k.shape[0])

fig, axs = plt.subplots(nrows=3, ncols=3, figsize=[23,17], sharex=True, sharey=True, gridspec_kw={'wspace':.8, 'hspace':.2})

for k,ax in zip(e_ijs, axs.ravel()):
    p1, = ax.plot(frames, Tij_mov_k[:,k], c='royalblue', alpha=0.7, lw=3, label=r'$T$')

    ax2 = ax.twinx()
    p2, = ax2.plot(frames, lenij_mov_k[:,k], c='crimson', alpha=0.7, lw=3, label=r'$L$')

    ax3 = ax.twinx()
    ax3.spines.right.set_position(("axes", 1.3))
    p3, = ax3.plot(frames[:-1], dLdt[:,k], c='darkorange', alpha=.7, lw=3, label=r'$\Delta{}L$')

    ax.set_xlabel(f'{k} : Frames')
    ax.set_ylabel(r'Tension', color=p1.get_color())
    ax.tick_params(axis='y', labelcolor=p1.get_color())
    
    ax2.set_ylabel(r'$Length$', color=p2.get_color())
    ax2.tick_params(axis='y', labelcolor=p2.get_color())
    ax2.set_ylim(len_limits[0], len_limits[1])
    
    ax3.set_ylabel(r'$\Delta{}Length$', color=p3.get_color())
    ax3.tick_params(axis='y', labelcolor=p3.get_color())
    ax3.spines.right.set_color(p3.get_color())
    ax3.set_ylim(dlen_limits[0], dlen_limits[1])
    
    ax2.legend(loc='upper center')
    ax3.legend(loc='upper right')
    ax.legend(loc='upper left')

plt.suptitle('Tension and Length Dynamics', y=0.92 , fontsize=24);
# plt.savefig('tension_dynamics.png',dpi=100, bbox_inches="tight")

# %%
# _, axs = plt.subplots(nrows=5, ncols=5, figsize=[30,32],  sharex=True, sharey=True)

# for k,ax in zip(e_ijs, axs.ravel()):
#     ax.plot(Tij_mov_k[:,k], lenij_mov_k[:,k], c='teal', alpha=0.5, lw=3, label=f'{k}')
#     ax.set_xlabel('Tension')
#     ax.set_ylabel(r'$Length$')
#     ax.legend()
# plt.suptitle('Edge Length vs Tension', y=0.9, fontsize=24)
# # plt.savefig('tension_dynamics_edgelen.png',dpi=100)

# %%
# fig, axs = plt.subplots(nrows=4, ncols=4, figsize=[20,17], sharex=True, sharey=True)
# fig.tight_layout(h_pad=5, w_pad=8)

# frames = np.arange(Tij_mov_k.shape[0])

# for k,ax in zip(e_ijs, axs.ravel()):
#     p1, = ax.plot(frames, Tij_mov_k[:,k], c='royalblue', alpha=0.7, lw=3, label=r'$T$')
    
#     ax2 = ax.twinx()
#     p2, = ax2.plot(frames, lenij_mov_k[:,k], c='salmon', alpha=0.5, lw=3, label=r'$L$')
    
#     ax.set_xlabel(f'{k} : Frames')
#     ax.set_ylabel(r'Tension', color=p1.get_color())
#     ax.tick_params(axis='y', labelcolor=p1.get_color())
#     ax2.set_ylabel(r'$Length$', color=p2.get_color())
#     ax2.tick_params(axis='y', labelcolor=p2.get_color())
#     ax.legend(loc='upper left')
#     ax2.legend(loc='upper right')
    
# plt.suptitle('Tension and Length Dynamics', y=1.01 , fontsize=24);
# # plt.savefig('tension_dynamics.png',dpi=100, bbox_inches="tight")

# %%
# _, axs = plt.subplots(nrows=6, ncols=5, figsize=[30,32],  sharex=True, sharey=True)

# for k,ax in zip(e_ijs, axs.ravel()):
#     ax.plot(Tij_mov_k[:,k], c='teal', alpha=0.5, lw=3, label=f'{k}')
#     ax.set_ylabel('Tension')
#     ax.set_xlabel('Frames')
#     ax.legend()
# plt.suptitle('Edge Tension', y=0.9, fontsize=24)
# # plt.savefig('tension_dynamics_tension.png',dpi=50)

# %%
# _, axs = plt.subplots(nrows=6, ncols=5, figsize=[30,32],  sharex=True, sharey=True)

# for k,ax in zip(e_ijs, axs.ravel()):
#     ax.plot(lenij_mov_k[:,k], c='teal', alpha=0.5, lw=3, label=f'{k}')
#     ax.set_ylabel('Length')
#     ax.set_xlabel('Frames')
#     ax.legend()
# plt.suptitle('Edge Lengths', y=0.9, fontsize=24)
# # plt.savefig('tension_dynamics_length_dyns.png',dpi=50)
