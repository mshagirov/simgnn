# %% [markdown]
# # Velocity Sim2real Transfer: Learning to Filter Noise
# ---
# > Training velocity GNN(1) model with noisy input features

# %% [markdown]
# - All simulated movies, regardless of their simulation param-s, use the same *normalisation constants*.
# - Hara movies (node velocity data) and ablation (recoil data) movies have different spatio-temporal resolutions:
#     - After scaling them to the same length scale and frame rate (microns/10s), we use the average edge length to normalise spatial variables (displacement and position; frame rate is assumed to be 10s for all movies including the simulated movies)
#
# |Dataset | Details | Shortname| Avg. edge len.| Transforms (Normalisation)|
# |:---:|:---|:---|---:|:---|
# |Synthetic datasets     | vertex dynamics simulations| "train" and "val"| 1.0 a.u.| `[Pos2Vec(scale=10*1.0)`, `ScaleVelocity(0.5*1.0)`, `ScaleTension(0.634,shift=0.6)`, `ScalePressure(0.33,shift=0.1)]`|
# |Hara movies    | no force information       | "hara"| 26.32 pixels|`[Pos2Vec(scale=10*26.32)`,`ScaleVelocity(0.5*26.32)]`|
# |Hara ablation | short movies w/ recoil data| "abln"| 26.32*0.4/0.21 pixels | (not used for testing velocity) |

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import torch
from os import path
import datetime

from torch_geometric.data import Data, DataLoader
import torch_geometric.transforms as T

from torch_geometric.utils import to_networkx, from_networkx
import networkx as nx
from simgnn.datautils import load_array, load_graph

import matplotlib.pyplot as plt
import matplotlib
plt.style.use(['seaborn-paper', 'seaborn-ticks'])
# import seaborn as sns
# sns.set_theme(context='paper', style='ticks')

# %matplotlib inline
# matplotlib.rcParams['figure.figsize'] = (10,10) # use larger for presentation
# matplotlib.rcParams['font.size']= 16 # use 14 for presentation

# %%
from simgnn.datasets import persistence_loss, VertexDynamics, HaraMovies
from simgnn.train import train_model, write_log, load_log, predict, predict_batch
from simgnn.train import plot_velocity_predictions, plot_losses
from simgnn.transforms import Pos2Vec, ScaleVelocity, Reshape_x, AddPosNoise #, ScaleTension, ScalePressure,
# from torch_geometric.utils import to_undirected as T_undir

# %%
device = torch.device('cpu')
if torch.cuda.is_available():
    device = torch.device('cuda')
dtype = torch.float32
print(f'Defaults:\n |-- device: {device}\n |-- dtype : {dtype}')
# Out:
# Defaults:
#  |-- device: cuda
#  |-- dtype : torch.float32

# %% [markdown]
# ---

# %% [markdown]
# # GNN(1) Training w/ Noisy Simul-n Data

# %% [markdown]
# ## Datasets

# %% [markdown]
# `CellData` prop-s (graph data objects):
# - `x` : `(#nodes, WindowWidth, 2)` *node features*
# - `y` : `(#nodes, 2)` *node targets (velocities)*.
# - `pos` : `(#nodes, 2)` *node positions*.
# - `edge_attr` : `(#edges, 2)` or `(#edges, #edge_features)` *edge features  (relative Cartesian positions of connected nodes)*.
# - `edge_index` : `(2, #edges)` *edge indices*.
# - `edge_tensions` : `(#edges,)` *edge targets (line tensions)*.
# - `node2cell_index` : `(2, #cell2node_edges)`, `node2cell`-> *first row is node indices and second row is cell indices;
# - `cell2node_index` : `(2, #cell2node_edges)`, `cell2node`-> *first row is cell indices and second row is node indices*.
# - `cell_pressures` : `(#cells,)` *cell targets (cell pressures)*.

# %%
def clear_processed_datasets():
    # !rm -dr simgnn_data/single_distr_sims/train/processed
    # !rm -dr simgnn_data/single_distr_sims/val/processed

    # !rm -dr simgnn_data/unimodal_wbasetens_sims/train/processed
    # !rm -dr simgnn_data/unimodal_wbasetens_sims/val/processed

    # !rm -dr simgnn_data/hara_movies_as_sep_datasets/hara_seg001/processed/
    # !rm -dr simgnn_data/hara_movies_as_sep_datasets/hara_seg003/processed/
    # !rm -dr simgnn_data/hara_movies_as_sep_datasets/hara_seg005/processed/
    
    # !rm -dr simgnn_data/hara_movies_as_sep_datasets_copy/hara_seg001/processed/
    # !rm -dr simgnn_data/hara_movies_as_sep_datasets_copy/hara_seg003/processed/
    # !rm -dr simgnn_data/hara_movies_as_sep_datasets_copy/hara_seg005/processed/

# %%
# clear_processed_datasets()

# %% [markdown]
# - Average lengths

# %%
window_size = 5
n_hidden_layers = 10

sma_lag_time = 4

# average edge lengths
l_0 = {'sim':1.0, 'single_distr_sims':1.1, 'unimodal_wbasetens_sims':0.91, 'hara':26.32, 'abln':50.13}

# %%
# Noise for training data
pos_noise = torch.normal
noise_args= [0, 0.03] #[0,1]
frac  = 1 # 100%*frac of nodes
coeffs = {'x': np.sqrt(2)*l_0['sim'], 'pos':1.0*l_0['sim']}
# coeffs = l_0['sim']
coeff_name = 'cxSqrt2' if isinstance(coeffs, dict) else ''

# %%
# Normalisation: for simulated data (simul params ~ normal distr-s): l0=1.0, Hara_movie: l0=26.32
# Tnorm = T.Compose([Pos2Vec(scale=1.0*10.0) , ScaleVelocity(1.0*0.5), Reshape_x((-1,window_size*2)) ] )
# Hara movie normalisation
# Tnorm_hara = T.Compose([Pos2Vec(scale=10*26.32) , ScaleVelocity(0.5*26.32), Reshape_x((-1,window_size*2))])

# Use mean edge len w/o additional scaling for vel-y and edge len-s
Tnorms = {}

Tnorms['hara'] = T.Compose([ Pos2Vec(scale=l_0['hara']), ScaleVelocity(l_0['hara']), Reshape_x((-1,window_size*2))])

Tnorms['sim'] = T.Compose([ AddPosNoise(pos_noise, frac=frac, coeffs=coeffs, noise_args=noise_args),
                         Pos2Vec(scale=l_0['sim']) , ScaleVelocity(l_0['sim']), Reshape_x((-1,window_size*2)) ] )

Tnorms['sim_val'] = T.Compose([ Pos2Vec(scale=l_0['sim']) , ScaleVelocity(l_0['sim']), Reshape_x((-1,window_size*2)) ] )

velocity_scale = {'train':l_0['sim'], 'val':l_0['sim'], 'val2':l_0['sim'], 'hara':l_0['hara']}

# %%
clear_processed_datasets()

# Hara movie datasets (denoised)
seg001 = HaraMovies('simgnn_data/hara_movies_as_sep_datasets/hara_seg001/', window_size=window_size,
                    transform=Tnorms['hara'], smoothing=True, sma_lag_time=sma_lag_time)
# seg003 = HaraMovies('simgnn_data/hara_movies_as_sep_datasets/hara_seg003/', window_size=window_size,
#                     transform=Tnorms['hara'],smoothing=True, sma_lag_time=sma_lag_time)
# seg005 = HaraMovies('simgnn_data/hara_movies_as_sep_datasets/hara_seg005/', window_size=window_size,
#                     transform=Tnorms['hara'],smoothing=True, sma_lag_time=sma_lag_time)

seg001_raw = HaraMovies('simgnn_data/hara_movies_as_sep_datasets_copy/hara_seg001/', window_size=window_size,
                    transform=Tnorms['hara'], smoothing=False)

# Simulation datasets
sim1 = VertexDynamics('./simgnn_data/unimodal_wbasetens_sims/train/', window_size=window_size, transform=Tnorms['sim'])
sim1_val = VertexDynamics('./simgnn_data/unimodal_wbasetens_sims/val/', window_size=window_size, transform=Tnorms['sim_val'])
# sim2 = VertexDynamics('./simgnn_data/single_distr_sims/train/', window_size=window_size, transform=Tnorms['sim'])
sim2_val = VertexDynamics('./simgnn_data/single_distr_sims/val/', window_size=window_size, transform=Tnorms['sim_val'])

datasets_dict = {'train': sim1,
                 'val': sim1_val,
                 'val2' : sim2_val,
                 'H1' : seg001,
                 'H1raw' : seg001_raw,
#                  'hara' : hara,
                }
dataset_legend={'train': 'Train($\mathcal{H}_1$)',
                'val': 'Supervised($\mathcal{D}_{sim1}$)',
                'val2': 'Sim2sim($\mathcal{D}_{sim2}$)',
                'H1': 'Sim2real($\mathcal{H}_1$)',
                'H1raw': 'Sim2real($\mathcal{H}_1$); raw'
                }
# Out:
# rm: cannot remove 'simgnn_data/single_distr_sims/train/processed': No such file or directory
# rm: cannot remove 'simgnn_data/hara_movies_as_sep_datasets/hara_seg003/processed/': No such file or directory
# rm: cannot remove 'simgnn_data/hara_movies_as_sep_datasets/hara_seg005/processed/': No such file or directory
# rm: cannot remove 'simgnn_data/hara_movies_as_sep_datasets_copy/hara_seg003/processed/': No such file or directory
# rm: cannot remove 'simgnn_data/hara_movies_as_sep_datasets_copy/hara_seg005/processed/': No such file or directory
# Processing...
# Done!
# Processing...
# Done!
# Processing...
# Done!
# Processing...
# Done!
# Processing...
# Done!

# %%
# datasets_dict[k][0].pos.numpy() - datasets_dict[k][0].pos.numpy()

# %%
# datasets_dict['train'].processed_file_names

# %%
# k='train'
# print('{} : {}\nsize:{}\n\nFrame 1:\n{}'.format(k,datasets_dict[k],len(datasets_dict[k]),datasets_dict[k][0]))
# plt.figure(figsize=[2.5,2.5])
# nx.draw(to_networkx(datasets_dict[k][0]),pos=dict(enumerate(datasets_dict[k][0].pos.numpy())), node_size=10)

# %% [markdown]
# ## Single Message Passing Step
# > Single MP step, uses graph and relative node positions w.r.t. connected neighbouring nodes

# %% [markdown]
# - Single MP step w/ a very simple Update mlp. Update stage is equivalent to the node model (plain mlp) w/ an additional edge features as messages.

# %%
from simgnn.models import Single_MP_step

# %%
dropout_p = 0.1
num_epochs = 1000
lr = 0.001

bs = 2

loaders = {'train' : DataLoader(datasets_dict['train'], batch_size=bs, shuffle=True),
           'val': DataLoader(datasets_dict['val'], batch_size=bs),
#            'val2': DataLoader(datasets_dict['val2'], batch_size=bs),
#           'hara': DataLoader(datasets_dict['hara'], batch_size=bs)
          }

model_states = list(loaders.keys())
use_force_loss = {k:[False,False] for k in loaders}

loss_func = torch.nn.MSELoss(reduction='mean')

GNN_save_dir = './simgnn_data/saved_models/thesis/2C_dp_sim2real_learning_noise/'

# %% [markdown]
# ### GNN(1) aka single graph layer (message and update) sizes
# > The output layer of the message MLP in a 1-layer GNN model counted as a hidden layer

# %%
torch.manual_seed(42)

msg_dim = 32  # message MLP latent dim-s
upd_dim = 128  # update MLP latent dim-s

upd_h_layers = max([0, n_hidden_layers//2])# Update MLP hidden_layers
update_hidden_dims=[upd_dim for k in range(upd_h_layers-1)]+[16]

msg_h_layers = max([0, n_hidden_layers - upd_h_layers])# Message MLP hidden_layers
message_hidden_dims = [msg_dim for k in range(msg_h_layers-1)] # assume output layer is hidden for MP step model


print(f'{k}: N(h_dims)={n_hidden_layers}')

net = Single_MP_step(node_in_features=window_size*2, node_out_features=2, edge_in_features=2,
                     message_out_features=msg_dim, message_hidden_dims=message_hidden_dims,
                     aggr='mean', update_hidden_dims=update_hidden_dims,
                     dropout_p=dropout_p).to(device)

opt = torch.optim.Adam(net.parameters(), lr=lr)
scheduler = None

return_best = False
model_name = f'{net.__class__.__name__}_sd{noise_args[1]}f{frac}{coeff_name}_epochs{num_epochs}'

print(model_name,end='\n---\n')
net, train_log = train_model(net, loaders, opt, num_epochs=num_epochs, scheduler=None, device=device,
                             model_states = model_states, loss_func = loss_func,
                             use_force_loss=use_force_loss, return_best=return_best)

# plot losses
plot_losses(train_log, loaders, dataset_legend, figsize=[7,4]); plt.show()


# MODEL SAVING:

write_log(f'{path.join(GNN_save_dir, model_name)}_log.pkl',train_log)
model_save_path = path.join(GNN_save_dir, model_name+'.pkl')
torch.save(net.state_dict(), model_save_path)
print(f'Model weights saved in \n{model_save_path}\n---\n')

# %%
pred_loaders = {
#     'train' : DataLoader(datasets_dict['train'], batch_size=bs, shuffle=True),
                'val': DataLoader(datasets_dict['val'], batch_size=bs),
                'val2': DataLoader(datasets_dict['val2'], batch_size=bs),
                'H1': DataLoader(datasets_dict['H1'], batch_size=bs),
                'H1raw': DataLoader(datasets_dict['H1raw'], batch_size=bs),
               }
# compute predictions and plot them
pred_out, tgt_out, sample_losses = predict_batch(net, pred_loaders,
                                                 loss_func=torch.nn.MSELoss(reduction='sum'),
                                                 use_force_loss = {k: False for k in pred_loaders},
                                                 return_losses = True, device=device)
print(''.join([f'- {k} ={sample_losses[k]};\n' for k in sample_losses]))

plot_velocity_predictions(pred_out[0], tgt_out[0], dataset_legend, subplots_kw={'figsize':[8,3.5]})

# %% [markdown]
# ```
# coeff = {'x': np.sqrt(2)*l_0['sim'], 'pos':1.0*l_0['sim']}
# f=0.3; sd=0.01
# - val_loss_y =0.00014772496279573182;
# - val2_loss_y =0.0002205065226801124;
# - H1_loss_y =0.00010273008609392955;
# - H1raw_loss_y =0.0018718269209639724;
# f=1.0; sd=0.03 # HIGH BIAS--> Noise injection acts as a regularisation constraint!
# - val_loss_y =0.0005726190656179448;
# - val2_loss_y =0.0006900143062511644;
# - H1_loss_y =0.00016935544290854504;
# - H1raw_loss_y =0.0011007516915412278;
# ```

# %% [markdown]
# ---
# ```
# f=0.2; sd=0.001;
# - val_loss_y =0.00011222623120798079;
# - val2_loss_y =0.00017364779707683615;
# - H1_loss_y =0.00021233829832790696;
# - H1raw_loss_y =0.005644451527796405;
#
# sd=0.01
# - val_loss_y =0.0001295140943200685;
# - val2_loss_y =0.00019427845789873793;
# - H1_loss_y =0.00010998991613344449;
# - H1raw_loss_y =0.0028997599814260615;
# sd=0.03
# - val_loss_y =0.0001380167705303505;
# - val2_loss_y =0.00021085752404923926;
# - H1_loss_y =0.00011749314949610282;
# - H1raw_loss_y =0.0013095034364850452;
# sd=0.1
# - val_loss_y =0.00014190938946855686;
# - val2_loss_y =0.0002178387277124297;
# - H1_loss_y =0.00016547521852997612;
# - H1raw_loss_y =0.0018628526057742388;
# sd=0.3
# - val_loss_y =0.00013540205493847672;
# - val2_loss_y =0.00021272544872680157;
# - H1_loss_y =0.00018553323548146732;
# - H1raw_loss_y =0.003279668165416252;
# ```

# %% [markdown]
# ---
# ```
# f=0.05; sd=0.01
# - val_loss_y =0.000117523342948944;
# - val2_loss_y =0.0001772897342016837;
# - H1_loss_y =0.00015277827154440256;
# - H1raw_loss_y =0.003758851361116126;
# f=0.1
# - val_loss_y =0.00012324319625710325;
# - val2_loss_y =0.00018600442813629077;
# - H1_loss_y =0.00013637467413446855;
# - H1raw_loss_y =0.0032307971475393966;
# f=0.3
# - val_loss_y =0.00014252006564518805;
# - val2_loss_y =0.00021017055733354536;
# - H1_loss_y =9.706326886317683e-05;
# - H1raw_loss_y =0.0027630896367413504;
# f=0.5
# - val_loss_y =0.00015945568910237222;
# - val2_loss_y =0.00023085957185214895;
# - H1_loss_y =8.360448844747375e-05;
# - H1raw_loss_y =0.002515228730347627;
# f=1.0
# - val_loss_y =0.00019442476622081638;
# - val2_loss_y =0.00027197577328510135;
# - H1_loss_y =8.42321765280748e-05;
# - H1raw_loss_y =0.002145789206820951;
# ```

# %% [markdown]
# ## Longer training test for corrupting a smaller portion

# %% [markdown]
# ```
# s.d.=0.03;
# ========================
# f=0.3; sd=0.03
# Single_MP_step_sd0.03f0.3cxSqrt2_epochs1000.pkl
# ---
# - val_loss_y =0.00014857835332261274;
# - val2_loss_y =0.00022444450288589034;
# - H1_loss_y =0.00014537067798910014;
# - H1raw_loss_y =0.0011164773693370185;
#
# f=0.5; sd=0.03
# Single_MP_step_sd0.03f0.5cxSqrt2_epochs1000.pkl
# ---
# - val_loss_y =0.00015593221857240557;
# - val2_loss_y =0.00023825398830512723;
# - H1_loss_y =0.00014722830411501047;
# - H1raw_loss_y =0.0011049167379043054;
#
# f=1.0; sd=0.03
# Single_MP_step_sd0.03f1.0cxSqrt2_epochs1000.pkl
# ---
# - val_loss_y =0.0006464833307029925;
# - val2_loss_y =0.0007694661404720224;
# - H1_loss_y =0.00017218155303181144;
# - H1raw_loss_y =0.001068703876498533;
# ```
# ---

# %% [markdown]
# ```
# s.d.=0.01
# =====================
# f=0.3; sd=0.01
# Single_MP_step_sd0.01f0.3cxSqrt2_epochs1000
# ---
# - val_loss_y =0.0001441355108687481;
# - val2_loss_y =0.00021719141286228637;
# - H1_loss_y =9.621794453250067e-05;
# - H1raw_loss_y =0.0016382031390513654;
#
# f=0.5; sd=0.01
# Single_MP_step_sd0.01f0.5cxSqrt2_epochs1000
# ---
# - val_loss_y =0.00016951497258474443;
# - val2_loss_y =0.00024519116827936263;
# - H1_loss_y =9.498214163299146e-05;
# - H1raw_loss_y =0.0015609788722843923;
#
# f=1.0; sd=0.01
# Single_MP_step_sd0.01f1.0cxSqrt2_epochs1000
# ---
# - val_loss_y =0.0003499815171538104;
# - val2_loss_y =0.0004319380728696376;
# - H1_loss_y =9.988545235700724e-05;
# - H1raw_loss_y =0.0014628166865615253;
# ```

# %%
from simgnn.models import Single_MP_step

# %%
# Noise for training data
pos_noise = torch.normal
noise_args= [0, 0.01] #[0,1]
fracs  = [0.3, 0.5, 1.0] # 100%*frac of nodes
coeffs = {'x': np.sqrt(2)*l_0['sim'], 'pos':1.0*l_0['sim']}
coeff_name = 'cxSqrt2' if isinstance(coeffs, dict) else ''

velocity_scale = {'train':l_0['sim'], 'val':l_0['sim'], 'val2':l_0['sim'], 'hara':l_0['hara']}

# %%
for k, frac in enumerate(fracs):
    # clear_processed_datasets()
    # Use mean edge len w/o additional scaling for vel-y and edge len-s
    Tnorms = {}

    Tnorms['hara'] = T.Compose([ Pos2Vec(scale=l_0['hara']), ScaleVelocity(l_0['hara']), Reshape_x((-1,window_size*2))])

    Tnorms['sim'] = T.Compose([ AddPosNoise(pos_noise, frac=frac, coeffs=coeffs, noise_args=noise_args),
                             Pos2Vec(scale=l_0['sim']) , ScaleVelocity(l_0['sim']), Reshape_x((-1,window_size*2)) ] )

    Tnorms['sim_val'] = T.Compose([ Pos2Vec(scale=l_0['sim']) , ScaleVelocity(l_0['sim']), Reshape_x((-1,window_size*2)) ] )

    # Hara movie datasets (denoised)
    seg001 = HaraMovies('simgnn_data/hara_movies_as_sep_datasets/hara_seg001/', window_size=window_size,
                        transform=Tnorms['hara'], smoothing=True, sma_lag_time=sma_lag_time)
    # seg003 = HaraMovies('simgnn_data/hara_movies_as_sep_datasets/hara_seg003/', window_size=window_size,
    #                     transform=Tnorms['hara'],smoothing=True, sma_lag_time=sma_lag_time)
    # seg005 = HaraMovies('simgnn_data/hara_movies_as_sep_datasets/hara_seg005/', window_size=window_size,
    #                     transform=Tnorms['hara'],smoothing=True, sma_lag_time=sma_lag_time)

    seg001_raw = HaraMovies('simgnn_data/hara_movies_as_sep_datasets_copy/hara_seg001/', window_size=window_size,
                        transform=Tnorms['hara'], smoothing=False)

    # Simulation datasets
    sim1 = VertexDynamics('./simgnn_data/unimodal_wbasetens_sims/train/', window_size=window_size, transform=Tnorms['sim'])
    sim1_val = VertexDynamics('./simgnn_data/unimodal_wbasetens_sims/val/', window_size=window_size, transform=Tnorms['sim_val'])
    # sim2 = VertexDynamics('./simgnn_data/single_distr_sims/train/', window_size=window_size, transform=Tnorms['sim'])
    sim2_val = VertexDynamics('./simgnn_data/single_distr_sims/val/', window_size=window_size, transform=Tnorms['sim_val'])

    datasets_dict = {'train': sim1,
                     'val': sim1_val,
                     'val2' : sim2_val,
                     'H1' : seg001,
                     'H1raw' : seg001_raw,
    #                  'hara' : hara,
                    }
    dataset_legend={'train': 'Train($\mathcal{H}_1$)',
                    'val': 'Supervised($\mathcal{D}_{sim1}$)',
                    'val2': 'Sim2sim($\mathcal{D}_{sim2}$)',
                    'H1': 'Sim2real($\mathcal{H}_1$)',
                    'H1raw': 'Sim2real($\mathcal{H}_1$); raw'
                    }
    
    torch.manual_seed(420+k)

    dropout_p = 0.1
    num_epochs = 1000
    lr = 0.001
    bs = 2
    
    loaders = {'train' : DataLoader(datasets_dict['train'], batch_size=bs, shuffle=True),
               'val': DataLoader(datasets_dict['val'], batch_size=bs)}

    model_states = list(loaders.keys())
    use_force_loss = {k:[False,False] for k in loaders}

    loss_func = torch.nn.MSELoss(reduction='mean')

    GNN_save_dir = './simgnn_data/saved_models/thesis/2C_dp_sim2real_learning_noise/sd0.01_1000epochs/'

    # # # #

    msg_dim = 32  # message MLP latent dim-s
    upd_dim = 128  # update MLP latent dim-s

    upd_h_layers = max([0, n_hidden_layers//2])# Update MLP hidden_layers
    update_hidden_dims=[upd_dim for k in range(upd_h_layers-1)]+[16]

    msg_h_layers = max([0, n_hidden_layers - upd_h_layers])# Message MLP hidden_layers
    message_hidden_dims = [msg_dim for k in range(msg_h_layers-1)] # assume output layer is hidden for MP step model


    print(f'{k}: N(h_dims)={n_hidden_layers}')

    net = Single_MP_step(node_in_features=window_size*2, node_out_features=2, edge_in_features=2,
                         message_out_features=msg_dim, message_hidden_dims=message_hidden_dims,
                         aggr='mean', update_hidden_dims=update_hidden_dims,
                         dropout_p=dropout_p).to(device)

    opt = torch.optim.Adam(net.parameters(), lr=lr)
    scheduler = None

    return_best = False
    model_name = f'{net.__class__.__name__}_sd{noise_args[1]}f{frac}{coeff_name}_epochs{num_epochs}'

    print(model_name,end='\n---\n')
    net, train_log = train_model(net, loaders, opt, num_epochs=num_epochs, scheduler=None, device=device,
                                 model_states = model_states, loss_func = loss_func,
                                 use_force_loss=use_force_loss, return_best=return_best)

    # plot losses
    plot_losses(train_log, loaders, dataset_legend, figsize=[7,4]); plt.show()


    # MODEL SAVING:

    write_log(f'{path.join(GNN_save_dir, model_name)}_log.pkl',train_log)
    model_save_path = path.join(GNN_save_dir, model_name+'.pkl')
    torch.save(net.state_dict(), model_save_path)
    print(f'Model weights saved in \n{model_save_path}\n---\n')
    
    pred_loaders = {
    #     'train' : DataLoader(datasets_dict['train'], batch_size=bs, shuffle=True),
                    'val': DataLoader(datasets_dict['val'], batch_size=bs),
                    'val2': DataLoader(datasets_dict['val2'], batch_size=bs),
                    'H1': DataLoader(datasets_dict['H1'], batch_size=bs),
                    'H1raw': DataLoader(datasets_dict['H1raw'], batch_size=bs),
                   }
    # compute predictions and plot them
    pred_out, tgt_out, sample_losses = predict_batch(net, pred_loaders,
                                                     loss_func=torch.nn.MSELoss(reduction='sum'),
                                                     use_force_loss = {k: False for k in pred_loaders},
                                                     return_losses = True, device=device)
    print(''.join([f'- {k} ={sample_losses[k]};\n' for k in sample_losses]))

    plot_velocity_predictions(pred_out[0], tgt_out[0], dataset_legend, subplots_kw={'figsize':[8,3.5]})
# Out:
# 0: N(h_dims)=10
# Single_MP_step_sd0.01f0.3cxSqrt2_epochs1000
# ---
# Training param-s: #epochs=1000, metric=MSELoss(), batch_size=2, optim=Adam, sch-r=none, return_best=False
# ---
# Epoch 0/999: train_loss_tot=0.004826; train_loss_y=0.004826; |val_loss_tot=0.001293; |3s
# Epoch 1/999: train_loss_tot=0.001765; train_loss_y=0.001765; |val_loss_tot=0.0005297; |7s
# Epoch 2/999: train_loss_tot=0.001079; train_loss_y=0.001079; |val_loss_tot=0.0003696; |10s
# Epoch 3/999: train_loss_tot=0.0008959; train_loss_y=0.0008959; |val_loss_tot=0.0003856; |13s
# Epoch 4/999: train_loss_tot=0.0007884; train_loss_y=0.0007884; |val_loss_tot=0.0003293; |16s
# Epoch 5/999: train_loss_tot=0.0007072; train_loss_y=0.0007072; |val_loss_tot=0.000291; |19s
# Epoch 6/999: train_loss_tot=0.0006495; train_loss_y=0.0006495; |val_loss_tot=0.000295; |22s
# Epoch 7/999: train_loss_tot=0.0006096; train_loss_y=0.0006096; |val_loss_tot=0.0002863; |26s
# Epoch 8/999: train_loss_tot=0.0005754; train_loss_y=0.0005754; |val_loss_tot=0.0002786; |29s
# Epoch 9/999: train_loss_tot=0.0005585; train_loss_y=0.0005585; |val_loss_tot=0.0002675; |32s
# Epoch 10/999: train_loss_tot=0.000534; train_loss_y=0.000534; |val_loss_tot=0.0002625; |35s
# Epoch 11/999: train_loss_tot=0.0005195; train_loss_y=0.0005195; |val_loss_tot=0.0002793; |38s
# Epoch 12/999: train_loss_tot=0.0004947; train_loss_y=0.0004947; |val_loss_tot=0.0002587; |41s
# Epoch 13/999: train_loss_tot=0.0004968; train_loss_y=0.0004968; |val_loss_tot=0.0002823; |44s
# Epoch 14/999: train_loss_tot=0.0004831; train_loss_y=0.0004831; |val_loss_tot=0.0002465; |47s
# Epoch 15/999: train_loss_tot=0.0004742; train_loss_y=0.0004742; |val_loss_tot=0.0002287; |50s
# Epoch 16/999: train_loss_tot=0.0004608; train_loss_y=0.0004608; |val_loss_tot=0.000233; |54s
# Epoch 17/999: train_loss_tot=0.0004551; train_loss_y=0.0004551; |val_loss_tot=0.000209; |57s
# Epoch 18/999: train_loss_tot=0.0004432; train_loss_y=0.0004432; |val_loss_tot=0.000212; |60s
# Epoch 19/999: train_loss_tot=0.0004374; train_loss_y=0.0004374; |val_loss_tot= 0.00029; |63s
# Epoch 20/999: train_loss_tot=0.0004511; train_loss_y=0.0004511; |val_loss_tot=0.0002016; |66s
# Epoch 21/999: train_loss_tot=0.0004451; train_loss_y=0.0004451; |val_loss_tot=0.0001888; |69s
# Epoch 22/999: train_loss_tot=0.0004252; train_loss_y=0.0004252; |val_loss_tot=0.0002021; |72s
# Epoch 23/999: train_loss_tot=0.0004261; train_loss_y=0.0004261; |val_loss_tot=0.0002048; |75s
# Epoch 24/999: train_loss_tot=0.0004258; train_loss_y=0.0004258; |val_loss_tot=0.0001897; |79s
# Epoch 25/999: train_loss_tot=0.0004144; train_loss_y=0.0004144; |val_loss_tot=0.0002134; |82s
# Epoch 26/999: train_loss_tot=0.0004166; train_loss_y=0.0004166; |val_loss_tot=0.0002164; |85s
# Epoch 27/999: train_loss_tot=0.0004085; train_loss_y=0.0004085; |val_loss_tot=0.0001853; |88s
# Epoch 28/999: train_loss_tot=0.0004055; train_loss_y=0.0004055; |val_loss_tot=0.0001784; |91s
# Epoch 29/999: train_loss_tot=0.000405; train_loss_y=0.000405; |val_loss_tot=0.000174; |94s
# Epoch 30/999: train_loss_tot=0.0003955; train_loss_y=0.0003955; |val_loss_tot=0.0002066; |97s
# Epoch 31/999: train_loss_tot=0.0003959; train_loss_y=0.0003959; |val_loss_tot=0.0002319; |100s
# Epoch 32/999: train_loss_tot=0.0003941; train_loss_y=0.0003941; |val_loss_tot=0.0002314; |103s
# Epoch 33/999: train_loss_tot=0.0003921; train_loss_y=0.0003921; |val_loss_tot=0.0001709; |107s
# Epoch 34/999: train_loss_tot=0.000399; train_loss_y=0.000399; |val_loss_tot=0.0001762; |110s
# Epoch 35/999: train_loss_tot=0.000391; train_loss_y=0.000391; |val_loss_tot=0.000203; |117s
# Epoch 36/999: train_loss_tot=0.0003888; train_loss_y=0.0003888; |val_loss_tot=0.0001828; |120s
# Epoch 37/999: train_loss_tot=0.0003885; train_loss_y=0.0003885; |val_loss_tot=0.0001794; |124s
# Epoch 38/999: train_loss_tot=0.0003872; train_loss_y=0.0003872; |val_loss_tot=0.0001615; |127s
# Epoch 39/999: train_loss_tot=0.0003808; train_loss_y=0.0003808; |val_loss_tot=0.0001636; |130s
# Epoch 40/999: train_loss_tot=0.0003828; train_loss_y=0.0003828; |val_loss_tot=0.000177; |133s
# Epoch 41/999: train_loss_tot=0.0003844; train_loss_y=0.0003844; |val_loss_tot=0.0001731; |136s
# Epoch 42/999: train_loss_tot=0.0003868; train_loss_y=0.0003868; |val_loss_tot=0.0001611; |139s
# Epoch 43/999: train_loss_tot=0.000393; train_loss_y=0.000393; |val_loss_tot=0.0001749; |142s
# Epoch 44/999: train_loss_tot=0.0003798; train_loss_y=0.0003798; |val_loss_tot=0.0001778; |145s
# Epoch 45/999: train_loss_tot=0.0003772; train_loss_y=0.0003772; |val_loss_tot=0.0001705; |149s
# Epoch 46/999: train_loss_tot=0.0003862; train_loss_y=0.0003862; |val_loss_tot=0.0001558; |152s
# Epoch 47/999: train_loss_tot=0.0003795; train_loss_y=0.0003795; |val_loss_tot=0.0001735; |155s
# Epoch 48/999: train_loss_tot=0.0003758; train_loss_y=0.0003758; |val_loss_tot=0.0001684; |158s
# Epoch 49/999: train_loss_tot=0.0003802; train_loss_y=0.0003802; |val_loss_tot= 0.00017; |161s
# Epoch 50/999: train_loss_tot=0.0003742; train_loss_y=0.0003742; |val_loss_tot=0.0001836; |164s
# Epoch 51/999: train_loss_tot=0.0003705; train_loss_y=0.0003705; |val_loss_tot=0.0002045; |167s
# Epoch 52/999: train_loss_tot=0.0003808; train_loss_y=0.0003808; |val_loss_tot=0.0001702; |170s
# Epoch 53/999: train_loss_tot=0.0003711; train_loss_y=0.0003711; |val_loss_tot=0.0001962; |173s
# Epoch 54/999: train_loss_tot=0.0003691; train_loss_y=0.0003691; |val_loss_tot=0.0001604; |176s
# Epoch 55/999: train_loss_tot=0.0003689; train_loss_y=0.0003689; |val_loss_tot=0.000156; |179s
# Epoch 56/999: train_loss_tot=0.0003751; train_loss_y=0.0003751; |val_loss_tot=0.0001515; |183s
# Epoch 57/999: train_loss_tot=0.0003668; train_loss_y=0.0003668; |val_loss_tot=0.0001916; |186s
# Epoch 58/999: train_loss_tot=0.0003684; train_loss_y=0.0003684; |val_loss_tot=0.0001502; |189s
# Epoch 59/999: train_loss_tot=0.0003747; train_loss_y=0.0003747; |val_loss_tot=0.0001715; |192s
# Epoch 60/999: train_loss_tot=0.0003685; train_loss_y=0.0003685; |val_loss_tot=0.0001623; |195s
# Epoch 61/999: train_loss_tot=0.0003651; train_loss_y=0.0003651; |val_loss_tot=0.0001488; |198s
# Epoch 62/999: train_loss_tot=0.0003594; train_loss_y=0.0003594; |val_loss_tot=0.0002368; |201s
# Epoch 63/999: train_loss_tot=0.0003645; train_loss_y=0.0003645; |val_loss_tot=0.0001545; |205s
# Epoch 64/999: train_loss_tot=0.0003667; train_loss_y=0.0003667; |val_loss_tot=0.0001743; |207s
# Epoch 65/999: train_loss_tot=0.0003645; train_loss_y=0.0003645; |val_loss_tot=0.0001606; |211s
# Epoch 66/999: train_loss_tot=0.0003606; train_loss_y=0.0003606; |val_loss_tot=0.0001659; |214s
# Epoch 67/999: train_loss_tot=0.0003635; train_loss_y=0.0003635; |val_loss_tot=0.0001551; |217s
# Epoch 68/999: train_loss_tot=0.000364; train_loss_y=0.000364; |val_loss_tot=0.000153; |220s
# Epoch 69/999: train_loss_tot=0.0003591; train_loss_y=0.0003591; |val_loss_tot=0.0001486; |223s
# Epoch 70/999: train_loss_tot=0.0003598; train_loss_y=0.0003598; |val_loss_tot=0.0001481; |226s
# Epoch 71/999: train_loss_tot=0.000357; train_loss_y=0.000357; |val_loss_tot=0.0001503; |229s
# Epoch 72/999: train_loss_tot=0.000358; train_loss_y=0.000358; |val_loss_tot=0.0001566; |233s
# Epoch 73/999: train_loss_tot=0.0003705; train_loss_y=0.0003705; |val_loss_tot=0.0001564; |236s
# Epoch 74/999: train_loss_tot=0.0003616; train_loss_y=0.0003616; |val_loss_tot=0.0001473; |239s
# Epoch 75/999: train_loss_tot=0.0003571; train_loss_y=0.0003571; |val_loss_tot=0.0001536; |242s
# Epoch 76/999: train_loss_tot=0.0003589; train_loss_y=0.0003589; |val_loss_tot=0.0001454; |245s
# Epoch 77/999: train_loss_tot=0.0003521; train_loss_y=0.0003521; |val_loss_tot=0.0001684; |248s
# Epoch 78/999: train_loss_tot=0.0003582; train_loss_y=0.0003582; |val_loss_tot=0.0001812; |251s
# Epoch 79/999: train_loss_tot=0.0003549; train_loss_y=0.0003549; |val_loss_tot=0.0001655; |254s
# Epoch 80/999: train_loss_tot=0.0003566; train_loss_y=0.0003566; |val_loss_tot=0.0001468; |258s
# Epoch 81/999: train_loss_tot=0.0003647; train_loss_y=0.0003647; |val_loss_tot=0.0001539; |265s
# Epoch 82/999: train_loss_tot=0.000361; train_loss_y=0.000361; |val_loss_tot=0.0001375; |268s
# Epoch 83/999: train_loss_tot=0.0003532; train_loss_y=0.0003532; |val_loss_tot=0.0001422; |272s
# Epoch 84/999: train_loss_tot=0.0003506; train_loss_y=0.0003506; |val_loss_tot=0.0001453; |275s
# Epoch 85/999: train_loss_tot=0.0003515; train_loss_y=0.0003515; |val_loss_tot=0.0001455; |278s
# Epoch 86/999: train_loss_tot=0.0003468; train_loss_y=0.0003468; |val_loss_tot=0.000208; |281s
# Epoch 87/999: train_loss_tot=0.0003496; train_loss_y=0.0003496; |val_loss_tot=0.0002803; |284s
# Epoch 88/999: train_loss_tot=0.0003563; train_loss_y=0.0003563; |val_loss_tot=0.0001467; |288s
# Epoch 89/999: train_loss_tot=0.0003553; train_loss_y=0.0003553; |val_loss_tot=0.0001393; |291s
# Epoch 90/999: train_loss_tot=0.0003535; train_loss_y=0.0003535; |val_loss_tot=0.0001459; |294s
# Epoch 91/999: train_loss_tot=0.0003501; train_loss_y=0.0003501; |val_loss_tot=0.000146; |298s
# Epoch 92/999: train_loss_tot=0.0003488; train_loss_y=0.0003488; |val_loss_tot=0.0001448; |301s
# Epoch 93/999: train_loss_tot=0.000351; train_loss_y=0.000351; |val_loss_tot=0.0001705; |304s
# Epoch 94/999: train_loss_tot=0.0003482; train_loss_y=0.0003482; |val_loss_tot=0.0001405; |307s
# Epoch 95/999: train_loss_tot=0.0003494; train_loss_y=0.0003494; |val_loss_tot=0.0001587; |311s
# Epoch 96/999: train_loss_tot=0.0003478; train_loss_y=0.0003478; |val_loss_tot=0.0001463; |314s
# Epoch 97/999: train_loss_tot=0.0003511; train_loss_y=0.0003511; |val_loss_tot=0.0001429; |317s
# Epoch 98/999: train_loss_tot=0.000346; train_loss_y=0.000346; |val_loss_tot=0.0001426; |320s
# Epoch 99/999: train_loss_tot=0.000347; train_loss_y=0.000347; |val_loss_tot=0.0001407; |324s
# Epoch 100/999: train_loss_tot=0.0003538; train_loss_y=0.0003538; |val_loss_tot=0.0001378; |327s
# Epoch 101/999: train_loss_tot=0.0003494; train_loss_y=0.0003494; |val_loss_tot=0.0001472; |330s
# Epoch 102/999: train_loss_tot=0.0003499; train_loss_y=0.0003499; |val_loss_tot=0.0001502; |334s
# Epoch 103/999: train_loss_tot=0.0003456; train_loss_y=0.0003456; |val_loss_tot=0.0001402; |337s
# Epoch 104/999: train_loss_tot=0.0003457; train_loss_y=0.0003457; |val_loss_tot=0.0001979; |340s
# Epoch 105/999: train_loss_tot=0.000347; train_loss_y=0.000347; |val_loss_tot=0.000159; |343s
# Epoch 106/999: train_loss_tot=0.0003456; train_loss_y=0.0003456; |val_loss_tot=0.000203; |346s
# Epoch 107/999: train_loss_tot=0.0003526; train_loss_y=0.0003526; |val_loss_tot=0.0001382; |350s
# Epoch 108/999: train_loss_tot=0.0003485; train_loss_y=0.0003485; |val_loss_tot=0.0001479; |353s
# Epoch 109/999: train_loss_tot=0.0003427; train_loss_y=0.0003427; |val_loss_tot=0.0001429; |356s
# Epoch 110/999: train_loss_tot=0.0003435; train_loss_y=0.0003435; |val_loss_tot=0.000136; |359s
# Epoch 111/999: train_loss_tot=0.0003456; train_loss_y=0.0003456; |val_loss_tot=0.0001384; |363s
# Epoch 112/999: train_loss_tot=0.0003443; train_loss_y=0.0003443; |val_loss_tot=0.0002061; |366s
# Epoch 113/999: train_loss_tot=0.0003404; train_loss_y=0.0003404; |val_loss_tot=0.0001366; |369s
# Epoch 114/999: train_loss_tot=0.0003435; train_loss_y=0.0003435; |val_loss_tot=0.0001378; |372s
# Epoch 115/999: train_loss_tot=0.0003436; train_loss_y=0.0003436; |val_loss_tot=0.0001439; |375s
# Epoch 116/999: train_loss_tot=0.0003399; train_loss_y=0.0003399; |val_loss_tot=0.0001389; |378s
# Epoch 117/999: train_loss_tot=0.0003433; train_loss_y=0.0003433; |val_loss_tot=0.0001322; |381s
# Epoch 118/999: train_loss_tot=0.0003417; train_loss_y=0.0003417; |val_loss_tot=0.000133; |384s
# Epoch 119/999: train_loss_tot=0.0003373; train_loss_y=0.0003373; |val_loss_tot=0.0001423; |388s
# Epoch 120/999: train_loss_tot=0.000346; train_loss_y=0.000346; |val_loss_tot=0.0001398; |391s
# Epoch 121/999: train_loss_tot=0.0003362; train_loss_y=0.0003362; |val_loss_tot=0.0001328; |394s
# Epoch 122/999: train_loss_tot=0.000342; train_loss_y=0.000342; |val_loss_tot=0.0001326; |397s
# Epoch 123/999: train_loss_tot=0.0003389; train_loss_y=0.0003389; |val_loss_tot=0.0001595; |400s
# Epoch 124/999: train_loss_tot=0.0003368; train_loss_y=0.0003368; |val_loss_tot=0.0001339; |403s
# Epoch 125/999: train_loss_tot=0.0003417; train_loss_y=0.0003417; |val_loss_tot=0.0001394; |408s
# Epoch 126/999: train_loss_tot=0.0003469; train_loss_y=0.0003469; |val_loss_tot=0.0001467; |412s
# Epoch 127/999: train_loss_tot=0.0003402; train_loss_y=0.0003402; |val_loss_tot=0.0001337; |415s
# Epoch 128/999: train_loss_tot=0.0003371; train_loss_y=0.0003371; |val_loss_tot=0.0001534; |418s
# Epoch 129/999: train_loss_tot=0.000336; train_loss_y=0.000336; |val_loss_tot=0.0001537; |421s
# Epoch 130/999: train_loss_tot=0.0003341; train_loss_y=0.0003341; |val_loss_tot=0.0001806; |424s
# Epoch 131/999: train_loss_tot=0.0003372; train_loss_y=0.0003372; |val_loss_tot=0.0001618; |427s
# Epoch 132/999: train_loss_tot=0.0003379; train_loss_y=0.0003379; |val_loss_tot=0.0001927; |430s
# Epoch 133/999: train_loss_tot=0.0003445; train_loss_y=0.0003445; |val_loss_tot=0.0001494; |433s
# Epoch 134/999: train_loss_tot=0.0003342; train_loss_y=0.0003342; |val_loss_tot= 0.00018; |437s
# Epoch 135/999: train_loss_tot=0.0003338; train_loss_y=0.0003338; |val_loss_tot=0.0001331; |440s
# Epoch 136/999: train_loss_tot=0.0003393; train_loss_y=0.0003393; |val_loss_tot=0.0001318; |443s
# Epoch 137/999: train_loss_tot=0.0003326; train_loss_y=0.0003326; |val_loss_tot=0.0001264; |446s
# Epoch 138/999: train_loss_tot=0.0003347; train_loss_y=0.0003347; |val_loss_tot=0.0001489; |449s
# Epoch 139/999: train_loss_tot=0.0003345; train_loss_y=0.0003345; |val_loss_tot=0.0001583; |452s
# Epoch 140/999: train_loss_tot=0.0003335; train_loss_y=0.0003335; |val_loss_tot=0.000162; |455s
# Epoch 141/999: train_loss_tot=0.0003389; train_loss_y=0.0003389; |val_loss_tot=0.000128; |458s
# Epoch 142/999: train_loss_tot=0.0003355; train_loss_y=0.0003355; |val_loss_tot=0.0001623; |461s
# Epoch 143/999: train_loss_tot=0.0003339; train_loss_y=0.0003339; |val_loss_tot=0.0001382; |464s
# Epoch 144/999: train_loss_tot=0.0003341; train_loss_y=0.0003341; |val_loss_tot=0.0001269; |468s
# Epoch 145/999: train_loss_tot=0.0003388; train_loss_y=0.0003388; |val_loss_tot=0.000163; |471s
# Epoch 146/999: train_loss_tot=0.0003326; train_loss_y=0.0003326; |val_loss_tot=0.0001354; |474s
# Epoch 147/999: train_loss_tot=0.0003389; train_loss_y=0.0003389; |val_loss_tot=0.0001938; |477s
# Epoch 148/999: train_loss_tot=0.0003305; train_loss_y=0.0003305; |val_loss_tot=0.000137; |480s
# Epoch 149/999: train_loss_tot=0.0003406; train_loss_y=0.0003406; |val_loss_tot=0.0001416; |483s
# Epoch 150/999: train_loss_tot=0.0003255; train_loss_y=0.0003255; |val_loss_tot=0.0001448; |486s
# Epoch 151/999: train_loss_tot=0.0003359; train_loss_y=0.0003359; |val_loss_tot=0.0001302; |489s
# Epoch 152/999: train_loss_tot=0.000332; train_loss_y=0.000332; |val_loss_tot=0.0001373; |492s
# Epoch 153/999: train_loss_tot=0.0003286; train_loss_y=0.0003286; |val_loss_tot=0.0001325; |496s
# Epoch 154/999: train_loss_tot=0.0003352; train_loss_y=0.0003352; |val_loss_tot=0.0002287; |499s
# Epoch 155/999: train_loss_tot=0.0003325; train_loss_y=0.0003325; |val_loss_tot=0.000147; |502s
# Epoch 156/999: train_loss_tot=0.0003271; train_loss_y=0.0003271; |val_loss_tot=0.0001925; |505s
# Epoch 157/999: train_loss_tot=0.0003331; train_loss_y=0.0003331; |val_loss_tot=0.0001284; |509s
# Epoch 158/999: train_loss_tot=0.000329; train_loss_y=0.000329; |val_loss_tot=0.0001335; |512s
# Epoch 159/999: train_loss_tot=0.0003327; train_loss_y=0.0003327; |val_loss_tot=0.0001295; |515s
# Epoch 160/999: train_loss_tot=0.0003285; train_loss_y=0.0003285; |val_loss_tot=0.0001638; |518s
# Epoch 161/999: train_loss_tot=0.0003281; train_loss_y=0.0003281; |val_loss_tot=0.0001507; |521s
# Epoch 162/999: train_loss_tot=0.0003258; train_loss_y=0.0003258; |val_loss_tot=0.0001553; |524s
# Epoch 163/999: train_loss_tot=0.0003402; train_loss_y=0.0003402; |val_loss_tot=0.0001327; |527s
# Epoch 164/999: train_loss_tot=0.0003405; train_loss_y=0.0003405; |val_loss_tot=0.0001341; |530s
# Epoch 165/999: train_loss_tot=0.0003329; train_loss_y=0.0003329; |val_loss_tot=0.000133; |533s
# Epoch 166/999: train_loss_tot=0.0003338; train_loss_y=0.0003338; |val_loss_tot=0.0001301; |536s
# Epoch 167/999: train_loss_tot=0.0003279; train_loss_y=0.0003279; |val_loss_tot=0.0001281; |540s
# Epoch 168/999: train_loss_tot=0.0003324; train_loss_y=0.0003324; |val_loss_tot=0.0001767; |543s
# Epoch 169/999: train_loss_tot=0.0003285; train_loss_y=0.0003285; |val_loss_tot=0.0001462; |546s
# Epoch 170/999: train_loss_tot=0.0003285; train_loss_y=0.0003285; |val_loss_tot=0.000179; |549s
# Epoch 171/999: train_loss_tot=0.000329; train_loss_y=0.000329; |val_loss_tot=0.0001264; |552s
# Epoch 172/999: train_loss_tot=0.0003386; train_loss_y=0.0003386; |val_loss_tot=0.0001362; |555s
# Epoch 173/999: train_loss_tot=0.0003222; train_loss_y=0.0003222; |val_loss_tot=0.0001373; |559s
# Epoch 174/999: train_loss_tot=0.0003259; train_loss_y=0.0003259; |val_loss_tot=0.000124; |564s
# Epoch 175/999: train_loss_tot=0.0003243; train_loss_y=0.0003243; |val_loss_tot=0.0001291; |567s
# Epoch 176/999: train_loss_tot=0.0003225; train_loss_y=0.0003225; |val_loss_tot=0.0001321; |571s
# Epoch 177/999: train_loss_tot=0.0003266; train_loss_y=0.0003266; |val_loss_tot=0.0001262; |574s
# Epoch 178/999: train_loss_tot=0.0003304; train_loss_y=0.0003304; |val_loss_tot=0.0001262; |577s
# Epoch 179/999: train_loss_tot=0.0003274; train_loss_y=0.0003274; |val_loss_tot=0.0001447; |580s
# Epoch 180/999: train_loss_tot=0.000331; train_loss_y=0.000331; |val_loss_tot=0.0001435; |583s
# Epoch 181/999: train_loss_tot=0.0003323; train_loss_y=0.0003323; |val_loss_tot=0.0001334; |587s
# Epoch 182/999: train_loss_tot=0.0003247; train_loss_y=0.0003247; |val_loss_tot=0.0001297; |590s
# Epoch 183/999: train_loss_tot=0.000325; train_loss_y=0.000325; |val_loss_tot=0.0001876; |593s
# Epoch 184/999: train_loss_tot=0.0003282; train_loss_y=0.0003282; |val_loss_tot=0.0001442; |596s
# Epoch 185/999: train_loss_tot=0.0003298; train_loss_y=0.0003298; |val_loss_tot=0.0001368; |600s
# Epoch 186/999: train_loss_tot=0.0003263; train_loss_y=0.0003263; |val_loss_tot=0.0001251; |603s
# Epoch 187/999: train_loss_tot=0.0003256; train_loss_y=0.0003256; |val_loss_tot=0.0001225; |606s
# Epoch 188/999: train_loss_tot=0.0003254; train_loss_y=0.0003254; |val_loss_tot=0.0001276; |610s
# Epoch 189/999: train_loss_tot=0.0003272; train_loss_y=0.0003272; |val_loss_tot=0.0001455; |613s
# Epoch 190/999: train_loss_tot=0.0003304; train_loss_y=0.0003304; |val_loss_tot=0.000182; |616s
# Epoch 191/999: train_loss_tot=0.0003256; train_loss_y=0.0003256; |val_loss_tot=0.0001268; |619s
# Epoch 192/999: train_loss_tot=0.000326; train_loss_y=0.000326; |val_loss_tot=0.0001322; |623s
# Epoch 193/999: train_loss_tot=0.0003232; train_loss_y=0.0003232; |val_loss_tot=0.0001232; |626s
# Epoch 194/999: train_loss_tot=0.0003277; train_loss_y=0.0003277; |val_loss_tot=0.0001349; |629s
# Epoch 195/999: train_loss_tot=0.000322; train_loss_y=0.000322; |val_loss_tot=0.0001427; |632s
# Epoch 196/999: train_loss_tot=0.0003234; train_loss_y=0.0003234; |val_loss_tot=0.0001382; |636s
# Epoch 197/999: train_loss_tot=0.0003248; train_loss_y=0.0003248; |val_loss_tot=0.0001412; |639s
# Epoch 198/999: train_loss_tot=0.0003321; train_loss_y=0.0003321; |val_loss_tot=0.0001347; |642s
# Epoch 199/999: train_loss_tot=0.0003225; train_loss_y=0.0003225; |val_loss_tot=0.0001197; |645s
# Epoch 200/999: train_loss_tot=0.0003254; train_loss_y=0.0003254; |val_loss_tot=0.0001421; |648s
# Epoch 201/999: train_loss_tot=0.0003283; train_loss_y=0.0003283; |val_loss_tot=0.0001379; |651s
# Epoch 202/999: train_loss_tot=0.0003249; train_loss_y=0.0003249; |val_loss_tot=0.0001277; |654s
# Epoch 203/999: train_loss_tot=0.0003235; train_loss_y=0.0003235; |val_loss_tot=0.0001309; |658s
# Epoch 204/999: train_loss_tot=0.0003321; train_loss_y=0.0003321; |val_loss_tot=0.0001335; |661s
# Epoch 205/999: train_loss_tot=0.0003238; train_loss_y=0.0003238; |val_loss_tot=0.0001284; |664s
# Epoch 206/999: train_loss_tot=0.0003212; train_loss_y=0.0003212; |val_loss_tot=0.000132; |667s
# Epoch 207/999: train_loss_tot=0.0003201; train_loss_y=0.0003201; |val_loss_tot=0.0001227; |670s
# Epoch 208/999: train_loss_tot=0.0003266; train_loss_y=0.0003266; |val_loss_tot=0.0001395; |673s
# Epoch 209/999: train_loss_tot=0.0003238; train_loss_y=0.0003238; |val_loss_tot=0.0001328; |676s
# Epoch 210/999: train_loss_tot=0.000321; train_loss_y=0.000321; |val_loss_tot=0.000128; |679s
# Epoch 211/999: train_loss_tot=0.0003314; train_loss_y=0.0003314; |val_loss_tot=0.0001626; |682s
# Epoch 212/999: train_loss_tot=0.0003252; train_loss_y=0.0003252; |val_loss_tot=0.0001332; |685s
# Epoch 213/999: train_loss_tot=0.0003245; train_loss_y=0.0003245; |val_loss_tot=0.0001857; |688s
# Epoch 214/999: train_loss_tot=0.0003219; train_loss_y=0.0003219; |val_loss_tot=0.0001358; |692s
# Epoch 215/999: train_loss_tot=0.0003256; train_loss_y=0.0003256; |val_loss_tot=0.0001565; |695s
# Epoch 216/999: train_loss_tot=0.0003243; train_loss_y=0.0003243; |val_loss_tot=0.0001937; |698s
# Epoch 217/999: train_loss_tot=0.0003229; train_loss_y=0.0003229; |val_loss_tot=0.0001484; |701s
# Epoch 218/999: train_loss_tot=0.0003276; train_loss_y=0.0003276; |val_loss_tot=0.0001306; |704s
# Epoch 219/999: train_loss_tot=0.0003269; train_loss_y=0.0003269; |val_loss_tot=0.0001441; |707s
# Epoch 220/999: train_loss_tot=0.0003205; train_loss_y=0.0003205; |val_loss_tot=0.0001278; |710s
# Epoch 221/999: train_loss_tot=0.0003207; train_loss_y=0.0003207; |val_loss_tot=0.0001244; |718s
# Epoch 222/999: train_loss_tot=0.0003247; train_loss_y=0.0003247; |val_loss_tot=0.0001299; |721s
# Epoch 223/999: train_loss_tot=0.0003218; train_loss_y=0.0003218; |val_loss_tot=0.0001491; |724s
# Epoch 224/999: train_loss_tot=0.000324; train_loss_y=0.000324; |val_loss_tot=0.0001464; |727s
# Epoch 225/999: train_loss_tot=0.0003236; train_loss_y=0.0003236; |val_loss_tot=0.0001283; |731s
# Epoch 226/999: train_loss_tot=0.0003251; train_loss_y=0.0003251; |val_loss_tot=0.0001347; |734s
# Epoch 227/999: train_loss_tot=0.0003216; train_loss_y=0.0003216; |val_loss_tot=0.000127; |737s
# Epoch 228/999: train_loss_tot=0.0003195; train_loss_y=0.0003195; |val_loss_tot=0.0001373; |740s
# Epoch 229/999: train_loss_tot=0.0003238; train_loss_y=0.0003238; |val_loss_tot=0.0001286; |743s
# Epoch 230/999: train_loss_tot=0.0003298; train_loss_y=0.0003298; |val_loss_tot=0.0001257; |746s
# Epoch 231/999: train_loss_tot=0.0003224; train_loss_y=0.0003224; |val_loss_tot=0.0001354; |749s
# Epoch 232/999: train_loss_tot=0.0003268; train_loss_y=0.0003268; |val_loss_tot=0.000142; |752s
# Epoch 233/999: train_loss_tot=0.0003217; train_loss_y=0.0003217; |val_loss_tot=0.0001269; |756s
# Epoch 234/999: train_loss_tot=0.0003198; train_loss_y=0.0003198; |val_loss_tot=0.0001246; |759s
# Epoch 235/999: train_loss_tot=0.0003227; train_loss_y=0.0003227; |val_loss_tot=0.0001229; |762s
# Epoch 236/999: train_loss_tot=0.0003229; train_loss_y=0.0003229; |val_loss_tot=0.0001379; |765s
# Epoch 237/999: train_loss_tot=0.0003173; train_loss_y=0.0003173; |val_loss_tot=0.0001346; |768s
# Epoch 238/999: train_loss_tot=0.0003232; train_loss_y=0.0003232; |val_loss_tot=0.000125; |771s
# Epoch 239/999: train_loss_tot=0.0003233; train_loss_y=0.0003233; |val_loss_tot=0.0001374; |774s
# Epoch 240/999: train_loss_tot=0.0003246; train_loss_y=0.0003246; |val_loss_tot= 0.00013; |778s
# Epoch 241/999: train_loss_tot= 0.00032; train_loss_y= 0.00032; |val_loss_tot=0.0001255; |781s
# Epoch 242/999: train_loss_tot=0.0003172; train_loss_y=0.0003172; |val_loss_tot=0.0001354; |784s
# Epoch 243/999: train_loss_tot=0.0003138; train_loss_y=0.0003138; |val_loss_tot=0.0001422; |787s
# Epoch 244/999: train_loss_tot=0.0003205; train_loss_y=0.0003205; |val_loss_tot=0.0001215; |790s
# Epoch 245/999: train_loss_tot=0.0003221; train_loss_y=0.0003221; |val_loss_tot=0.0001269; |793s
# Epoch 246/999: train_loss_tot=0.000322; train_loss_y=0.000322; |val_loss_tot=0.0001365; |797s
# Epoch 247/999: train_loss_tot=0.0003178; train_loss_y=0.0003178; |val_loss_tot=0.0001277; |800s
# Epoch 248/999: train_loss_tot=0.0003235; train_loss_y=0.0003235; |val_loss_tot=0.0001532; |803s
# Epoch 249/999: train_loss_tot=0.0003261; train_loss_y=0.0003261; |val_loss_tot=0.0001248; |806s
# Epoch 250/999: train_loss_tot=0.0003145; train_loss_y=0.0003145; |val_loss_tot=0.0001439; |809s
# Epoch 251/999: train_loss_tot=0.0003179; train_loss_y=0.0003179; |val_loss_tot=0.000137; |812s
# Epoch 252/999: train_loss_tot=0.0003259; train_loss_y=0.0003259; |val_loss_tot=0.0001261; |815s
# Epoch 253/999: train_loss_tot=0.000316; train_loss_y=0.000316; |val_loss_tot=0.0001274; |818s
# Epoch 254/999: train_loss_tot=0.000317; train_loss_y=0.000317; |val_loss_tot=0.0001411; |821s
# Epoch 255/999: train_loss_tot=0.0003185; train_loss_y=0.0003185; |val_loss_tot=0.0001228; |824s
# Epoch 256/999: train_loss_tot=0.0003215; train_loss_y=0.0003215; |val_loss_tot=0.0001235; |827s
# Epoch 257/999: train_loss_tot=0.000326; train_loss_y=0.000326; |val_loss_tot=0.0001222; |830s
# Epoch 258/999: train_loss_tot=0.0003156; train_loss_y=0.0003156; |val_loss_tot= 0.00014; |833s
# Epoch 259/999: train_loss_tot=0.0003237; train_loss_y=0.0003237; |val_loss_tot=0.0001293; |837s
# Epoch 260/999: train_loss_tot=0.000324; train_loss_y=0.000324; |val_loss_tot=0.0001265; |840s
# Epoch 261/999: train_loss_tot=0.0003197; train_loss_y=0.0003197; |val_loss_tot=0.0001245; |843s
# Epoch 262/999: train_loss_tot=0.0003138; train_loss_y=0.0003138; |val_loss_tot=0.000128; |846s
# Epoch 263/999: train_loss_tot=0.0003171; train_loss_y=0.0003171; |val_loss_tot=0.0001852; |849s
# Epoch 264/999: train_loss_tot=0.0003176; train_loss_y=0.0003176; |val_loss_tot=0.0001479; |852s
# Epoch 265/999: train_loss_tot=0.0003141; train_loss_y=0.0003141; |val_loss_tot=0.0001217; |855s
# Epoch 266/999: train_loss_tot=0.0003182; train_loss_y=0.0003182; |val_loss_tot=0.0001307; |859s
# Epoch 267/999: train_loss_tot=0.0003174; train_loss_y=0.0003174; |val_loss_tot=0.000121; |862s
# Epoch 268/999: train_loss_tot=0.0003169; train_loss_y=0.0003169; |val_loss_tot=0.0001267; |865s
# Epoch 269/999: train_loss_tot=0.0003199; train_loss_y=0.0003199; |val_loss_tot=0.0001233; |872s
# Epoch 270/999: train_loss_tot=0.0003186; train_loss_y=0.0003186; |val_loss_tot=0.0001249; |876s
# Epoch 271/999: train_loss_tot=0.0003175; train_loss_y=0.0003175; |val_loss_tot=0.0001279; |879s
# Epoch 272/999: train_loss_tot=0.0003179; train_loss_y=0.0003179; |val_loss_tot=0.000128; |883s
# Epoch 273/999: train_loss_tot=0.0003139; train_loss_y=0.0003139; |val_loss_tot=0.000131; |886s
# Epoch 274/999: train_loss_tot=0.0003171; train_loss_y=0.0003171; |val_loss_tot=0.0001265; |889s
# Epoch 275/999: train_loss_tot=0.0003153; train_loss_y=0.0003153; |val_loss_tot=0.0001218; |892s
# Epoch 276/999: train_loss_tot=0.0003167; train_loss_y=0.0003167; |val_loss_tot=0.0001325; |896s
# Epoch 277/999: train_loss_tot=0.0003174; train_loss_y=0.0003174; |val_loss_tot=0.0001339; |899s
# Epoch 278/999: train_loss_tot=0.0003192; train_loss_y=0.0003192; |val_loss_tot=0.0001367; |903s
# Epoch 279/999: train_loss_tot=0.0003175; train_loss_y=0.0003175; |val_loss_tot=0.0001522; |906s
# Epoch 280/999: train_loss_tot=0.000316; train_loss_y=0.000316; |val_loss_tot=0.0001628; |909s
# Epoch 281/999: train_loss_tot=0.0003148; train_loss_y=0.0003148; |val_loss_tot=0.0001241; |912s
# Epoch 282/999: train_loss_tot=0.0003149; train_loss_y=0.0003149; |val_loss_tot=0.0001424; |915s
# Epoch 283/999: train_loss_tot=0.0003242; train_loss_y=0.0003242; |val_loss_tot=0.0001248; |918s
# Epoch 284/999: train_loss_tot=0.0003143; train_loss_y=0.0003143; |val_loss_tot=0.000123; |922s
# Epoch 285/999: train_loss_tot=0.0003181; train_loss_y=0.0003181; |val_loss_tot=0.0001359; |925s
# Epoch 286/999: train_loss_tot=0.0003165; train_loss_y=0.0003165; |val_loss_tot=0.0001375; |928s
# Epoch 287/999: train_loss_tot=0.0003199; train_loss_y=0.0003199; |val_loss_tot=0.0001324; |931s
# Epoch 288/999: train_loss_tot=0.0003141; train_loss_y=0.0003141; |val_loss_tot=0.0001354; |935s
# Epoch 289/999: train_loss_tot=0.0003148; train_loss_y=0.0003148; |val_loss_tot=0.0001341; |938s
# Epoch 290/999: train_loss_tot=0.0003196; train_loss_y=0.0003196; |val_loss_tot=0.0001217; |941s
# Epoch 291/999: train_loss_tot=0.0003205; train_loss_y=0.0003205; |val_loss_tot=0.0001298; |944s
# Epoch 292/999: train_loss_tot=0.0003125; train_loss_y=0.0003125; |val_loss_tot=0.0001472; |947s
# Epoch 293/999: train_loss_tot=0.0003162; train_loss_y=0.0003162; |val_loss_tot=0.0001309; |951s
# Epoch 294/999: train_loss_tot=0.0003141; train_loss_y=0.0003141; |val_loss_tot=0.0001182; |954s
# Epoch 295/999: train_loss_tot=0.0003207; train_loss_y=0.0003207; |val_loss_tot=0.0001283; |957s
# Epoch 296/999: train_loss_tot=0.0003249; train_loss_y=0.0003249; |val_loss_tot=0.0001646; |960s
# Epoch 297/999: train_loss_tot=0.000317; train_loss_y=0.000317; |val_loss_tot=0.0001198; |964s
# Epoch 298/999: train_loss_tot=0.0003147; train_loss_y=0.0003147; |val_loss_tot=0.0001292; |967s
# Epoch 299/999: train_loss_tot=0.0003166; train_loss_y=0.0003166; |val_loss_tot=0.0001299; |970s
# Epoch 300/999: train_loss_tot=0.0003203; train_loss_y=0.0003203; |val_loss_tot=0.0001271; |973s
# Epoch 301/999: train_loss_tot=0.0003164; train_loss_y=0.0003164; |val_loss_tot=0.0001272; |976s
# Epoch 302/999: train_loss_tot=0.0003164; train_loss_y=0.0003164; |val_loss_tot=0.000127; |980s
# Epoch 303/999: train_loss_tot=0.0003197; train_loss_y=0.0003197; |val_loss_tot=0.000129; |983s
# Epoch 304/999: train_loss_tot=0.0003194; train_loss_y=0.0003194; |val_loss_tot=0.0001336; |986s
# Epoch 305/999: train_loss_tot=0.0003152; train_loss_y=0.0003152; |val_loss_tot=0.0001297; |989s
# Epoch 306/999: train_loss_tot=0.0003155; train_loss_y=0.0003155; |val_loss_tot=0.0002063; |992s
# Epoch 307/999: train_loss_tot=0.0003128; train_loss_y=0.0003128; |val_loss_tot=0.0001311; |996s
# Epoch 308/999: train_loss_tot=0.0003144; train_loss_y=0.0003144; |val_loss_tot=0.0001318; |999s
# Epoch 309/999: train_loss_tot=0.0003125; train_loss_y=0.0003125; |val_loss_tot=0.0001543; |1002s
# Epoch 310/999: train_loss_tot=0.0003147; train_loss_y=0.0003147; |val_loss_tot=0.0001363; |1005s
# Epoch 311/999: train_loss_tot=0.0003132; train_loss_y=0.0003132; |val_loss_tot=0.0001242; |1008s
# Epoch 312/999: train_loss_tot=0.0003148; train_loss_y=0.0003148; |val_loss_tot=0.0001292; |1012s
# Epoch 313/999: train_loss_tot=0.0003126; train_loss_y=0.0003126; |val_loss_tot=0.000127; |1019s
# Epoch 314/999: train_loss_tot=0.0003197; train_loss_y=0.0003197; |val_loss_tot=0.0001243; |1022s
# Epoch 315/999: train_loss_tot=0.0003181; train_loss_y=0.0003181; |val_loss_tot=0.0001297; |1025s
# Epoch 316/999: train_loss_tot=0.0003149; train_loss_y=0.0003149; |val_loss_tot=0.0001279; |1028s
# Epoch 317/999: train_loss_tot=0.0003148; train_loss_y=0.0003148; |val_loss_tot=0.0001473; |1031s
# Epoch 318/999: train_loss_tot=0.0003151; train_loss_y=0.0003151; |val_loss_tot=0.0001339; |1035s
# Epoch 319/999: train_loss_tot=0.0003128; train_loss_y=0.0003128; |val_loss_tot= 0.00012; |1038s
# Epoch 320/999: train_loss_tot=0.0003175; train_loss_y=0.0003175; |val_loss_tot=0.0001837; |1041s
# Epoch 321/999: train_loss_tot=0.0003106; train_loss_y=0.0003106; |val_loss_tot=0.0001247; |1044s
# Epoch 322/999: train_loss_tot=0.0003148; train_loss_y=0.0003148; |val_loss_tot=0.0001239; |1047s
# Epoch 323/999: train_loss_tot=0.0003191; train_loss_y=0.0003191; |val_loss_tot=0.0001324; |1050s
# Epoch 324/999: train_loss_tot=0.0003176; train_loss_y=0.0003176; |val_loss_tot=0.0001213; |1054s
# Epoch 325/999: train_loss_tot=0.0003149; train_loss_y=0.0003149; |val_loss_tot=0.0001442; |1057s
# Epoch 326/999: train_loss_tot=0.0003146; train_loss_y=0.0003146; |val_loss_tot=0.0001231; |1060s
# Epoch 327/999: train_loss_tot=0.0003109; train_loss_y=0.0003109; |val_loss_tot=0.0001266; |1063s
# Epoch 328/999: train_loss_tot=0.0003188; train_loss_y=0.0003188; |val_loss_tot=0.0001216; |1066s
# Epoch 329/999: train_loss_tot=0.000312; train_loss_y=0.000312; |val_loss_tot=0.0001249; |1069s
# Epoch 330/999: train_loss_tot=0.0003185; train_loss_y=0.0003185; |val_loss_tot=0.0001512; |1072s
# Epoch 331/999: train_loss_tot=0.0003157; train_loss_y=0.0003157; |val_loss_tot=0.0001196; |1076s
# Epoch 332/999: train_loss_tot=0.0003137; train_loss_y=0.0003137; |val_loss_tot=0.000133; |1079s
# Epoch 333/999: train_loss_tot=0.0003163; train_loss_y=0.0003163; |val_loss_tot=0.0001316; |1082s
# Epoch 334/999: train_loss_tot=0.0003144; train_loss_y=0.0003144; |val_loss_tot=0.000134; |1085s
# Epoch 335/999: train_loss_tot=0.0003258; train_loss_y=0.0003258; |val_loss_tot=0.0002144; |1088s
# Epoch 336/999: train_loss_tot=0.0003224; train_loss_y=0.0003224; |val_loss_tot=0.0001696; |1091s
# Epoch 337/999: train_loss_tot=0.0003147; train_loss_y=0.0003147; |val_loss_tot=0.0001219; |1094s
# Epoch 338/999: train_loss_tot=0.0003136; train_loss_y=0.0003136; |val_loss_tot=0.0001323; |1098s
# Epoch 339/999: train_loss_tot=0.0003162; train_loss_y=0.0003162; |val_loss_tot=0.0001387; |1101s
# Epoch 340/999: train_loss_tot=0.000311; train_loss_y=0.000311; |val_loss_tot=0.000118; |1104s
# Epoch 341/999: train_loss_tot=0.0003158; train_loss_y=0.0003158; |val_loss_tot=0.0001215; |1107s
# Epoch 342/999: train_loss_tot=0.0003117; train_loss_y=0.0003117; |val_loss_tot=0.0001404; |1110s
# Epoch 343/999: train_loss_tot=0.0003135; train_loss_y=0.0003135; |val_loss_tot=0.0001358; |1114s
# Epoch 344/999: train_loss_tot=0.0003173; train_loss_y=0.0003173; |val_loss_tot=0.0001676; |1117s
# Epoch 345/999: train_loss_tot=0.0003116; train_loss_y=0.0003116; |val_loss_tot=0.0001714; |1120s
# Epoch 346/999: train_loss_tot=0.0003147; train_loss_y=0.0003147; |val_loss_tot=0.0001241; |1123s
# Epoch 347/999: train_loss_tot=0.0003178; train_loss_y=0.0003178; |val_loss_tot=0.0001417; |1126s
# Epoch 348/999: train_loss_tot=0.0003116; train_loss_y=0.0003116; |val_loss_tot=0.0001787; |1129s
# Epoch 349/999: train_loss_tot=0.0003148; train_loss_y=0.0003148; |val_loss_tot=0.0001187; |1132s
# Epoch 350/999: train_loss_tot=0.0003114; train_loss_y=0.0003114; |val_loss_tot=0.0001651; |1135s
# Epoch 351/999: train_loss_tot=0.000312; train_loss_y=0.000312; |val_loss_tot=0.0001394; |1138s
# Epoch 352/999: train_loss_tot=0.0003136; train_loss_y=0.0003136; |val_loss_tot=0.0001245; |1142s
# Epoch 353/999: train_loss_tot=0.0003156; train_loss_y=0.0003156; |val_loss_tot=0.0001263; |1145s
# Epoch 354/999: train_loss_tot=0.0003155; train_loss_y=0.0003155; |val_loss_tot=0.0001568; |1148s
# Epoch 355/999: train_loss_tot=0.0003128; train_loss_y=0.0003128; |val_loss_tot=0.0001226; |1151s
# Epoch 356/999: train_loss_tot=0.0003151; train_loss_y=0.0003151; |val_loss_tot=0.0001229; |1154s
# Epoch 357/999: train_loss_tot=0.000313; train_loss_y=0.000313; |val_loss_tot=0.0001393; |1157s
# Epoch 358/999: train_loss_tot=0.0003144; train_loss_y=0.0003144; |val_loss_tot=0.000164; |1160s
# Epoch 359/999: train_loss_tot=0.0003112; train_loss_y=0.0003112; |val_loss_tot=0.0001292; |1164s
# Epoch 360/999: train_loss_tot=0.0003124; train_loss_y=0.0003124; |val_loss_tot=0.0001311; |1169s
# Epoch 361/999: train_loss_tot=0.0003117; train_loss_y=0.0003117; |val_loss_tot=0.0001284; |1172s
# Epoch 362/999: train_loss_tot=0.0003134; train_loss_y=0.0003134; |val_loss_tot=0.0001379; |1175s
# Epoch 363/999: train_loss_tot=0.0003095; train_loss_y=0.0003095; |val_loss_tot=0.0001452; |1179s
# Epoch 364/999: train_loss_tot=0.0003163; train_loss_y=0.0003163; |val_loss_tot=0.0001444; |1182s
# Epoch 365/999: train_loss_tot=0.0003164; train_loss_y=0.0003164; |val_loss_tot=0.0001241; |1185s
# Epoch 366/999: train_loss_tot=0.0003175; train_loss_y=0.0003175; |val_loss_tot=0.0001293; |1189s
# Epoch 367/999: train_loss_tot=0.0003132; train_loss_y=0.0003132; |val_loss_tot=0.0001203; |1192s
# Epoch 368/999: train_loss_tot=0.0003112; train_loss_y=0.0003112; |val_loss_tot=0.0001339; |1195s
# Epoch 369/999: train_loss_tot=0.0003191; train_loss_y=0.0003191; |val_loss_tot=0.0001261; |1199s
# Epoch 370/999: train_loss_tot=0.0003141; train_loss_y=0.0003141; |val_loss_tot=0.0001178; |1202s
# Epoch 371/999: train_loss_tot=0.0003115; train_loss_y=0.0003115; |val_loss_tot=0.000117; |1205s
# Epoch 372/999: train_loss_tot=0.0003133; train_loss_y=0.0003133; |val_loss_tot=0.0001348; |1208s
# Epoch 373/999: train_loss_tot=0.0003056; train_loss_y=0.0003056; |val_loss_tot=0.0001326; |1212s
# Epoch 374/999: train_loss_tot=0.0003113; train_loss_y=0.0003113; |val_loss_tot=0.0001306; |1215s
# Epoch 375/999: train_loss_tot=0.0003128; train_loss_y=0.0003128; |val_loss_tot=0.0001451; |1218s
# Epoch 376/999: train_loss_tot=0.0003166; train_loss_y=0.0003166; |val_loss_tot=0.0001211; |1221s
# Epoch 377/999: train_loss_tot=0.0003136; train_loss_y=0.0003136; |val_loss_tot=0.0001317; |1224s
# Epoch 378/999: train_loss_tot=0.0003172; train_loss_y=0.0003172; |val_loss_tot=0.0001291; |1228s
# Epoch 379/999: train_loss_tot=0.0003082; train_loss_y=0.0003082; |val_loss_tot=0.0001257; |1231s
# Epoch 380/999: train_loss_tot=0.0003073; train_loss_y=0.0003073; |val_loss_tot=0.0001287; |1234s
# Epoch 381/999: train_loss_tot=0.0003067; train_loss_y=0.0003067; |val_loss_tot=0.0001265; |1237s
# Epoch 382/999: train_loss_tot=0.000313; train_loss_y=0.000313; |val_loss_tot=0.000127; |1240s
# Epoch 383/999: train_loss_tot=0.0003157; train_loss_y=0.0003157; |val_loss_tot=0.000126; |1243s
# Epoch 384/999: train_loss_tot=0.0003112; train_loss_y=0.0003112; |val_loss_tot=0.0001476; |1246s
# Epoch 385/999: train_loss_tot=0.0003094; train_loss_y=0.0003094; |val_loss_tot=0.0001401; |1249s
# Epoch 386/999: train_loss_tot=0.0003116; train_loss_y=0.0003116; |val_loss_tot=0.0001675; |1252s
# Epoch 387/999: train_loss_tot=0.0003095; train_loss_y=0.0003095; |val_loss_tot=0.0001456; |1256s
# Epoch 388/999: train_loss_tot=0.0003159; train_loss_y=0.0003159; |val_loss_tot=0.0001259; |1259s
# Epoch 389/999: train_loss_tot=0.000312; train_loss_y=0.000312; |val_loss_tot=0.0002795; |1262s
# Epoch 390/999: train_loss_tot=0.000315; train_loss_y=0.000315; |val_loss_tot=0.0001271; |1265s
# Epoch 391/999: train_loss_tot=0.0003159; train_loss_y=0.0003159; |val_loss_tot=0.0001358; |1268s
# Epoch 392/999: train_loss_tot=0.0003103; train_loss_y=0.0003103; |val_loss_tot=0.0001268; |1271s
# Epoch 393/999: train_loss_tot= 0.00031; train_loss_y= 0.00031; |val_loss_tot=0.0001242; |1274s
# Epoch 394/999: train_loss_tot=0.0003093; train_loss_y=0.0003093; |val_loss_tot=0.0001448; |1277s
# Epoch 395/999: train_loss_tot=0.0003084; train_loss_y=0.0003084; |val_loss_tot=0.0001376; |1280s
# Epoch 396/999: train_loss_tot=0.0003109; train_loss_y=0.0003109; |val_loss_tot=0.0001383; |1284s
# Epoch 397/999: train_loss_tot=0.0003101; train_loss_y=0.0003101; |val_loss_tot=0.0002417; |1287s
# Epoch 398/999: train_loss_tot=0.0003171; train_loss_y=0.0003171; |val_loss_tot=0.0001446; |1290s
# Epoch 399/999: train_loss_tot=0.0003095; train_loss_y=0.0003095; |val_loss_tot=0.0001333; |1293s
# Epoch 400/999: train_loss_tot=0.0003069; train_loss_y=0.0003069; |val_loss_tot=0.0001182; |1296s
# Epoch 401/999: train_loss_tot=0.0003149; train_loss_y=0.0003149; |val_loss_tot=0.0001262; |1299s
# Epoch 402/999: train_loss_tot=0.0003115; train_loss_y=0.0003115; |val_loss_tot=0.0001336; |1303s
# Epoch 403/999: train_loss_tot=0.0003178; train_loss_y=0.0003178; |val_loss_tot=0.0001211; |1306s
# Epoch 404/999: train_loss_tot=0.0003154; train_loss_y=0.0003154; |val_loss_tot=0.000126; |1309s
# Epoch 405/999: train_loss_tot=0.0003088; train_loss_y=0.0003088; |val_loss_tot=0.0001292; |1314s
# Epoch 406/999: train_loss_tot=0.0003121; train_loss_y=0.0003121; |val_loss_tot=0.0001329; |1318s
# Epoch 407/999: train_loss_tot=0.0003107; train_loss_y=0.0003107; |val_loss_tot=0.000122; |1321s
# Epoch 408/999: train_loss_tot=0.0003118; train_loss_y=0.0003118; |val_loss_tot=0.000189; |1324s
# Epoch 409/999: train_loss_tot=0.0003086; train_loss_y=0.0003086; |val_loss_tot=0.000128; |1327s
# Epoch 410/999: train_loss_tot=0.0003119; train_loss_y=0.0003119; |val_loss_tot=0.0001194; |1330s
# Epoch 411/999: train_loss_tot=0.0003065; train_loss_y=0.0003065; |val_loss_tot=0.0001449; |1333s
# Epoch 412/999: train_loss_tot=0.0003112; train_loss_y=0.0003112; |val_loss_tot=0.0001291; |1336s
# Epoch 413/999: train_loss_tot=0.0003132; train_loss_y=0.0003132; |val_loss_tot=0.0001305; |1340s
# Epoch 414/999: train_loss_tot=0.000312; train_loss_y=0.000312; |val_loss_tot=0.0001205; |1343s
# Epoch 415/999: train_loss_tot=0.0003157; train_loss_y=0.0003157; |val_loss_tot=0.0001258; |1346s
# Epoch 416/999: train_loss_tot=0.0003148; train_loss_y=0.0003148; |val_loss_tot=0.0001209; |1349s
# Epoch 417/999: train_loss_tot=0.0003083; train_loss_y=0.0003083; |val_loss_tot=0.0001314; |1352s
# Epoch 418/999: train_loss_tot=0.0003118; train_loss_y=0.0003118; |val_loss_tot=0.0001325; |1355s
# Epoch 419/999: train_loss_tot=0.000315; train_loss_y=0.000315; |val_loss_tot=0.000124; |1358s
# Epoch 420/999: train_loss_tot=0.0003046; train_loss_y=0.0003046; |val_loss_tot=0.000127; |1361s
# Epoch 421/999: train_loss_tot=0.0003073; train_loss_y=0.0003073; |val_loss_tot=0.000127; |1364s
# Epoch 422/999: train_loss_tot=0.000313; train_loss_y=0.000313; |val_loss_tot=0.0001295; |1367s
# Epoch 423/999: train_loss_tot=0.0003081; train_loss_y=0.0003081; |val_loss_tot=0.0001508; |1371s
# Epoch 424/999: train_loss_tot=0.000309; train_loss_y=0.000309; |val_loss_tot=0.0001305; |1374s
# Epoch 425/999: train_loss_tot=0.0003108; train_loss_y=0.0003108; |val_loss_tot=0.0001522; |1377s
# Epoch 426/999: train_loss_tot=0.0003096; train_loss_y=0.0003096; |val_loss_tot=0.0001286; |1380s
# Epoch 427/999: train_loss_tot=0.0003132; train_loss_y=0.0003132; |val_loss_tot=0.0001302; |1383s
# Epoch 428/999: train_loss_tot=0.0003103; train_loss_y=0.0003103; |val_loss_tot=0.0001745; |1387s
# Epoch 429/999: train_loss_tot=0.0003143; train_loss_y=0.0003143; |val_loss_tot=0.0001202; |1390s
# Epoch 430/999: train_loss_tot=0.0003056; train_loss_y=0.0003056; |val_loss_tot=0.0001254; |1393s
# Epoch 431/999: train_loss_tot=0.0003125; train_loss_y=0.0003125; |val_loss_tot=0.0001695; |1396s
# Epoch 432/999: train_loss_tot=0.0003076; train_loss_y=0.0003076; |val_loss_tot=0.000136; |1399s
# Epoch 433/999: train_loss_tot=0.0003104; train_loss_y=0.0003104; |val_loss_tot=0.0001447; |1402s
# Epoch 434/999: train_loss_tot=0.0003094; train_loss_y=0.0003094; |val_loss_tot=0.0001302; |1405s
# Epoch 435/999: train_loss_tot=0.0003092; train_loss_y=0.0003092; |val_loss_tot=0.000122; |1409s
# Epoch 436/999: train_loss_tot=0.0003099; train_loss_y=0.0003099; |val_loss_tot=0.0001472; |1412s
# Epoch 437/999: train_loss_tot=0.0003114; train_loss_y=0.0003114; |val_loss_tot=0.0001526; |1415s
# Epoch 438/999: train_loss_tot=0.0003058; train_loss_y=0.0003058; |val_loss_tot=0.0001212; |1418s
# Epoch 439/999: train_loss_tot=0.0003083; train_loss_y=0.0003083; |val_loss_tot=0.0001428; |1421s
# Epoch 440/999: train_loss_tot=0.0003064; train_loss_y=0.0003064; |val_loss_tot=0.0001255; |1424s
# Epoch 441/999: train_loss_tot=0.0003064; train_loss_y=0.0003064; |val_loss_tot=0.0001323; |1427s
# Epoch 442/999: train_loss_tot=0.0003079; train_loss_y=0.0003079; |val_loss_tot=0.000156; |1431s
# Epoch 443/999: train_loss_tot=0.0003116; train_loss_y=0.0003116; |val_loss_tot=0.0001263; |1434s
# Epoch 444/999: train_loss_tot=0.0003099; train_loss_y=0.0003099; |val_loss_tot=0.0001296; |1437s
# Epoch 445/999: train_loss_tot= 0.00031; train_loss_y= 0.00031; |val_loss_tot=0.0001542; |1440s
# Epoch 446/999: train_loss_tot=0.0003087; train_loss_y=0.0003087; |val_loss_tot= 0.00012; |1443s
# Epoch 447/999: train_loss_tot=0.0003113; train_loss_y=0.0003113; |val_loss_tot=0.0001306; |1446s
# Epoch 448/999: train_loss_tot=0.0003109; train_loss_y=0.0003109; |val_loss_tot=0.0001231; |1450s
# Epoch 449/999: train_loss_tot= 0.00031; train_loss_y= 0.00031; |val_loss_tot=0.0001383; |1453s
# Epoch 450/999: train_loss_tot=0.0003114; train_loss_y=0.0003114; |val_loss_tot=0.0001229; |1456s
# Epoch 451/999: train_loss_tot=0.0003111; train_loss_y=0.0003111; |val_loss_tot= 0.00014; |1462s
# Epoch 452/999: train_loss_tot=0.0003067; train_loss_y=0.0003067; |val_loss_tot=0.0001229; |1465s
# Epoch 453/999: train_loss_tot=0.0003109; train_loss_y=0.0003109; |val_loss_tot=0.0001226; |1468s
# Epoch 454/999: train_loss_tot=0.0003119; train_loss_y=0.0003119; |val_loss_tot=0.0001462; |1471s
# Epoch 455/999: train_loss_tot=0.000307; train_loss_y=0.000307; |val_loss_tot=0.0001419; |1474s
# Epoch 456/999: train_loss_tot=0.000309; train_loss_y=0.000309; |val_loss_tot=0.0001189; |1478s
# Epoch 457/999: train_loss_tot=0.0003074; train_loss_y=0.0003074; |val_loss_tot=0.0001392; |1481s
# Epoch 458/999: train_loss_tot=0.0003105; train_loss_y=0.0003105; |val_loss_tot=0.0001804; |1484s
# Epoch 459/999: train_loss_tot=0.0003136; train_loss_y=0.0003136; |val_loss_tot=0.0001338; |1488s
# Epoch 460/999: train_loss_tot=0.0003061; train_loss_y=0.0003061; |val_loss_tot=0.0001278; |1491s
# Epoch 461/999: train_loss_tot=0.0003097; train_loss_y=0.0003097; |val_loss_tot=0.0001486; |1494s
# Epoch 462/999: train_loss_tot=0.0003117; train_loss_y=0.0003117; |val_loss_tot=0.0001523; |1497s
# Epoch 463/999: train_loss_tot=0.0003059; train_loss_y=0.0003059; |val_loss_tot=0.0001565; |1501s
# Epoch 464/999: train_loss_tot=0.0003033; train_loss_y=0.0003033; |val_loss_tot=0.0001304; |1504s
# Epoch 465/999: train_loss_tot=0.000316; train_loss_y=0.000316; |val_loss_tot=0.0001265; |1507s
# Epoch 466/999: train_loss_tot=0.0003098; train_loss_y=0.0003098; |val_loss_tot=0.0001828; |1510s
# Epoch 467/999: train_loss_tot=0.0003142; train_loss_y=0.0003142; |val_loss_tot=0.0001937; |1513s
# Epoch 468/999: train_loss_tot=0.0003126; train_loss_y=0.0003126; |val_loss_tot=0.000125; |1516s
# Epoch 469/999: train_loss_tot=0.0003109; train_loss_y=0.0003109; |val_loss_tot=0.0001224; |1519s
# Epoch 470/999: train_loss_tot=0.0003089; train_loss_y=0.0003089; |val_loss_tot=0.0001261; |1523s
# Epoch 471/999: train_loss_tot=0.0003081; train_loss_y=0.0003081; |val_loss_tot=0.0001297; |1526s
# Epoch 472/999: train_loss_tot=0.0003117; train_loss_y=0.0003117; |val_loss_tot=0.0001235; |1529s
# Epoch 473/999: train_loss_tot=0.0003101; train_loss_y=0.0003101; |val_loss_tot=0.0001357; |1532s
# Epoch 474/999: train_loss_tot=0.0003075; train_loss_y=0.0003075; |val_loss_tot=0.0001487; |1535s
# Epoch 475/999: train_loss_tot=0.0003105; train_loss_y=0.0003105; |val_loss_tot=0.0001423; |1538s
# Epoch 476/999: train_loss_tot=0.0003067; train_loss_y=0.0003067; |val_loss_tot=0.0001252; |1541s
# Epoch 477/999: train_loss_tot=0.0003098; train_loss_y=0.0003098; |val_loss_tot=0.0001292; |1544s
# Epoch 478/999: train_loss_tot=0.0003122; train_loss_y=0.0003122; |val_loss_tot=0.0001286; |1547s
# Epoch 479/999: train_loss_tot=0.0003122; train_loss_y=0.0003122; |val_loss_tot=0.0001314; |1551s
# Epoch 480/999: train_loss_tot=0.0003089; train_loss_y=0.0003089; |val_loss_tot=0.0001192; |1554s
# Epoch 481/999: train_loss_tot=0.0003042; train_loss_y=0.0003042; |val_loss_tot=0.0002103; |1557s
# Epoch 482/999: train_loss_tot=0.0003183; train_loss_y=0.0003183; |val_loss_tot=0.0001301; |1560s
# Epoch 483/999: train_loss_tot=0.0003073; train_loss_y=0.0003073; |val_loss_tot=0.0001189; |1563s
# Epoch 484/999: train_loss_tot=0.0003102; train_loss_y=0.0003102; |val_loss_tot=0.0001188; |1566s
# Epoch 485/999: train_loss_tot=0.0003057; train_loss_y=0.0003057; |val_loss_tot=0.0001661; |1570s
# Epoch 486/999: train_loss_tot=0.0003025; train_loss_y=0.0003025; |val_loss_tot=0.0001325; |1573s
# Epoch 487/999: train_loss_tot=0.0003059; train_loss_y=0.0003059; |val_loss_tot=0.0001909; |1576s
# Epoch 488/999: train_loss_tot=0.0003084; train_loss_y=0.0003084; |val_loss_tot=0.0001183; |1579s
# Epoch 489/999: train_loss_tot=0.0003108; train_loss_y=0.0003108; |val_loss_tot=0.0001508; |1582s
# Epoch 490/999: train_loss_tot=0.0003129; train_loss_y=0.0003129; |val_loss_tot=0.0001197; |1586s
# Epoch 491/999: train_loss_tot=0.000308; train_loss_y=0.000308; |val_loss_tot=0.0002332; |1589s
# Epoch 492/999: train_loss_tot=0.0003077; train_loss_y=0.0003077; |val_loss_tot=0.0001265; |1592s
# Epoch 493/999: train_loss_tot=0.0003088; train_loss_y=0.0003088; |val_loss_tot=0.0001299; |1595s
# Epoch 494/999: train_loss_tot=0.0003071; train_loss_y=0.0003071; |val_loss_tot=0.0001271; |1598s
# Epoch 495/999: train_loss_tot=0.000309; train_loss_y=0.000309; |val_loss_tot=0.000132; |1603s
# Epoch 496/999: train_loss_tot=0.0003081; train_loss_y=0.0003081; |val_loss_tot=0.0001299; |1606s
# Epoch 497/999: train_loss_tot=0.0003125; train_loss_y=0.0003125; |val_loss_tot=0.0001182; |1609s
# Epoch 498/999: train_loss_tot=0.0003062; train_loss_y=0.0003062; |val_loss_tot=0.0001323; |1613s
# ...
# Epoch 842/999: train_loss_tot=0.0004582; train_loss_y=0.0004582; |val_loss_tot=0.0003132; |2779s
# Epoch 843/999: train_loss_tot=0.0004535; train_loss_y=0.0004535; |val_loss_tot=0.0002567; |2782s
# Epoch 844/999: train_loss_tot=0.0004539; train_loss_y=0.0004539; |val_loss_tot=0.000267; |2785s
# Epoch 845/999: train_loss_tot=0.0004531; train_loss_y=0.0004531; |val_loss_tot=0.0002648; |2789s
# Epoch 846/999: train_loss_tot=0.0004559; train_loss_y=0.0004559; |val_loss_tot=0.0002694; |2792s
# Epoch 847/999: train_loss_tot=0.0004578; train_loss_y=0.0004578; |val_loss_tot=0.0002928; |2795s
# Epoch 848/999: train_loss_tot=0.0004563; train_loss_y=0.0004563; |val_loss_tot=0.0002543; |2798s
# Epoch 849/999: train_loss_tot=0.0004545; train_loss_y=0.0004545; |val_loss_tot=0.0002712; |2801s
# Epoch 850/999: train_loss_tot=0.0004543; train_loss_y=0.0004543; |val_loss_tot=0.000264; |2805s
# Epoch 851/999: train_loss_tot=0.0004532; train_loss_y=0.0004532; |val_loss_tot=0.0002674; |2808s
# Epoch 852/999: train_loss_tot=0.0004484; train_loss_y=0.0004484; |val_loss_tot=0.0002492; |2813s
# Epoch 853/999: train_loss_tot=0.0004558; train_loss_y=0.0004558; |val_loss_tot=0.0002866; |2817s
# Epoch 854/999: train_loss_tot=0.0004583; train_loss_y=0.0004583; |val_loss_tot=0.0002673; |2820s
# Epoch 855/999: train_loss_tot=0.0004575; train_loss_y=0.0004575; |val_loss_tot=0.0002797; |2823s
# Epoch 856/999: train_loss_tot=0.0004521; train_loss_y=0.0004521; |val_loss_tot=0.0002535; |2826s
# Epoch 857/999: train_loss_tot=0.0004521; train_loss_y=0.0004521; |val_loss_tot=0.0002655; |2829s
# Epoch 858/999: train_loss_tot=0.0004535; train_loss_y=0.0004535; |val_loss_tot=0.0002793; |2832s
# Epoch 859/999: train_loss_tot=0.0004569; train_loss_y=0.0004569; |val_loss_tot=0.0002563; |2836s
# Epoch 860/999: train_loss_tot=0.0004536; train_loss_y=0.0004536; |val_loss_tot=0.0002671; |2839s
# Epoch 861/999: train_loss_tot=0.0004566; train_loss_y=0.0004566; |val_loss_tot=0.0002849; |2842s
# Epoch 862/999: train_loss_tot=0.0004609; train_loss_y=0.0004609; |val_loss_tot=0.0002531; |2845s
# Epoch 863/999: train_loss_tot=0.0004593; train_loss_y=0.0004593; |val_loss_tot=0.0002588; |2849s
# Epoch 864/999: train_loss_tot=0.0004543; train_loss_y=0.0004543; |val_loss_tot=0.0002744; |2852s
# Epoch 865/999: train_loss_tot=0.0004509; train_loss_y=0.0004509; |val_loss_tot=0.0003111; |2855s
# Epoch 866/999: train_loss_tot=0.0004511; train_loss_y=0.0004511; |val_loss_tot=0.0002695; |2858s
# Epoch 867/999: train_loss_tot=0.0004559; train_loss_y=0.0004559; |val_loss_tot=0.0002678; |2862s
# Epoch 868/999: train_loss_tot=0.000452; train_loss_y=0.000452; |val_loss_tot=0.0002444; |2865s
# Epoch 869/999: train_loss_tot=0.000455; train_loss_y=0.000455; |val_loss_tot=0.0002534; |2868s
# Epoch 870/999: train_loss_tot=0.0004564; train_loss_y=0.0004564; |val_loss_tot=0.0002728; |2871s
# Epoch 871/999: train_loss_tot=0.0004481; train_loss_y=0.0004481; |val_loss_tot=0.000348; |2875s
# Epoch 872/999: train_loss_tot=0.0004578; train_loss_y=0.0004578; |val_loss_tot=0.0002869; |2878s
# Epoch 873/999: train_loss_tot=0.0004554; train_loss_y=0.0004554; |val_loss_tot=0.0002652; |2881s
# Epoch 874/999: train_loss_tot=0.0004539; train_loss_y=0.0004539; |val_loss_tot=0.0002275; |2884s
# Epoch 875/999: train_loss_tot=0.0004567; train_loss_y=0.0004567; |val_loss_tot=0.0002786; |2887s
# Epoch 876/999: train_loss_tot=0.0004544; train_loss_y=0.0004544; |val_loss_tot=0.0002769; |2891s
# Epoch 877/999: train_loss_tot=0.0004516; train_loss_y=0.0004516; |val_loss_tot=0.0003043; |2894s
# Epoch 878/999: train_loss_tot=0.0004576; train_loss_y=0.0004576; |val_loss_tot=0.0002434; |2897s
# Epoch 879/999: train_loss_tot=0.0004487; train_loss_y=0.0004487; |val_loss_tot=0.0002423; |2900s
# Epoch 880/999: train_loss_tot=0.0004586; train_loss_y=0.0004586; |val_loss_tot=0.0002882; |2903s
# Epoch 881/999: train_loss_tot=0.0004567; train_loss_y=0.0004567; |val_loss_tot=0.0002521; |2907s
# Epoch 882/999: train_loss_tot= 0.00045; train_loss_y= 0.00045; |val_loss_tot=0.0002815; |2910s
# Epoch 883/999: train_loss_tot=0.0004521; train_loss_y=0.0004521; |val_loss_tot=0.0002542; |2913s
# Epoch 884/999: train_loss_tot=0.0004547; train_loss_y=0.0004547; |val_loss_tot=0.000328; |2916s
# Epoch 885/999: train_loss_tot=0.0004516; train_loss_y=0.0004516; |val_loss_tot=0.0003094; |2919s
# Epoch 886/999: train_loss_tot=0.0004514; train_loss_y=0.0004514; |val_loss_tot=0.0002671; |2923s
# Epoch 887/999: train_loss_tot=0.000452; train_loss_y=0.000452; |val_loss_tot=0.0002562; |2926s
# Epoch 888/999: train_loss_tot=0.0004516; train_loss_y=0.0004516; |val_loss_tot=0.0003664; |2929s
# Epoch 889/999: train_loss_tot=0.0004541; train_loss_y=0.0004541; |val_loss_tot= 0.00022; |2932s
# Epoch 890/999: train_loss_tot=0.0004496; train_loss_y=0.0004496; |val_loss_tot=0.0002692; |2936s
# Epoch 891/999: train_loss_tot=0.000455; train_loss_y=0.000455; |val_loss_tot=0.0002432; |2939s
# Epoch 892/999: train_loss_tot=0.0004566; train_loss_y=0.0004566; |val_loss_tot=0.0002718; |2942s
# Epoch 893/999: train_loss_tot=0.0004493; train_loss_y=0.0004493; |val_loss_tot=0.0002274; |2945s
# Epoch 894/999: train_loss_tot=0.0004585; train_loss_y=0.0004585; |val_loss_tot=0.0002632; |2951s
# Epoch 895/999: train_loss_tot=0.0004536; train_loss_y=0.0004536; |val_loss_tot=0.0002534; |2954s
# Epoch 896/999: train_loss_tot=0.0004531; train_loss_y=0.0004531; |val_loss_tot=0.0002975; |2957s
# Epoch 897/999: train_loss_tot=0.000455; train_loss_y=0.000455; |val_loss_tot=0.0002941; |2961s
# Epoch 898/999: train_loss_tot=0.0004542; train_loss_y=0.0004542; |val_loss_tot=0.0002446; |2964s
# Epoch 899/999: train_loss_tot=0.0004572; train_loss_y=0.0004572; |val_loss_tot=0.0002402; |2967s
# Epoch 900/999: train_loss_tot=0.0004555; train_loss_y=0.0004555; |val_loss_tot=0.0002613; |2970s
# Epoch 901/999: train_loss_tot=0.0004526; train_loss_y=0.0004526; |val_loss_tot=0.0002958; |2973s
# Epoch 902/999: train_loss_tot=0.0004556; train_loss_y=0.0004556; |val_loss_tot=0.0003121; |2976s
# Epoch 903/999: train_loss_tot=0.0004544; train_loss_y=0.0004544; |val_loss_tot=0.0002765; |2980s
# Epoch 904/999: train_loss_tot=0.0004526; train_loss_y=0.0004526; |val_loss_tot=0.0003113; |2983s
# Epoch 905/999: train_loss_tot=0.0004511; train_loss_y=0.0004511; |val_loss_tot=0.0003024; |2986s
# Epoch 906/999: train_loss_tot=0.000452; train_loss_y=0.000452; |val_loss_tot=0.0002617; |2990s
# Epoch 907/999: train_loss_tot=0.0004482; train_loss_y=0.0004482; |val_loss_tot=0.0002529; |2993s
# Epoch 908/999: train_loss_tot=0.0004622; train_loss_y=0.0004622; |val_loss_tot=0.0003098; |2996s
# Epoch 909/999: train_loss_tot=0.0004569; train_loss_y=0.0004569; |val_loss_tot=0.0002695; |2999s
# Epoch 910/999: train_loss_tot=0.0004517; train_loss_y=0.0004517; |val_loss_tot=0.0002739; |3002s
# Epoch 911/999: train_loss_tot=0.0004555; train_loss_y=0.0004555; |val_loss_tot=0.0002881; |3006s
# Epoch 912/999: train_loss_tot=0.0004571; train_loss_y=0.0004571; |val_loss_tot=0.0002735; |3009s
# Epoch 913/999: train_loss_tot=0.0004492; train_loss_y=0.0004492; |val_loss_tot=0.0002787; |3012s
# Epoch 914/999: train_loss_tot=0.000456; train_loss_y=0.000456; |val_loss_tot=0.0002704; |3015s
# Epoch 915/999: train_loss_tot=0.0004515; train_loss_y=0.0004515; |val_loss_tot=0.0002588; |3018s
# Epoch 916/999: train_loss_tot=0.0004547; train_loss_y=0.0004547; |val_loss_tot=0.0004059; |3021s
# Epoch 917/999: train_loss_tot=0.0004597; train_loss_y=0.0004597; |val_loss_tot=0.0002578; |3024s
# Epoch 918/999: train_loss_tot=0.0004612; train_loss_y=0.0004612; |val_loss_tot=0.0002778; |3028s
# Epoch 919/999: train_loss_tot=0.0004536; train_loss_y=0.0004536; |val_loss_tot=0.0002648; |3031s
# Epoch 920/999: train_loss_tot=0.0004523; train_loss_y=0.0004523; |val_loss_tot=0.0002728; |3034s
# Epoch 921/999: train_loss_tot=0.0004537; train_loss_y=0.0004537; |val_loss_tot=0.0002625; |3037s
# Epoch 922/999: train_loss_tot=0.0004504; train_loss_y=0.0004504; |val_loss_tot=0.0002639; |3040s
# Epoch 923/999: train_loss_tot=0.0004547; train_loss_y=0.0004547; |val_loss_tot=0.0003133; |3043s
# Epoch 924/999: train_loss_tot=0.0004585; train_loss_y=0.0004585; |val_loss_tot=0.0002726; |3047s
# Epoch 925/999: train_loss_tot=0.0004613; train_loss_y=0.0004613; |val_loss_tot=0.0002541; |3050s
# Epoch 926/999: train_loss_tot=0.0004524; train_loss_y=0.0004524; |val_loss_tot=0.0002589; |3053s
# Epoch 927/999: train_loss_tot=0.0004525; train_loss_y=0.0004525; |val_loss_tot=0.0003245; |3056s
# Epoch 928/999: train_loss_tot=0.0004583; train_loss_y=0.0004583; |val_loss_tot=0.0002475; |3059s
# Epoch 929/999: train_loss_tot=0.0004551; train_loss_y=0.0004551; |val_loss_tot=0.000333; |3063s
# Epoch 930/999: train_loss_tot=0.000453; train_loss_y=0.000453; |val_loss_tot=0.0002516; |3066s
# Epoch 931/999: train_loss_tot=0.0004537; train_loss_y=0.0004537; |val_loss_tot=0.0002706; |3069s
# Epoch 932/999: train_loss_tot=0.0004609; train_loss_y=0.0004609; |val_loss_tot=0.0002674; |3072s
# Epoch 933/999: train_loss_tot=0.0004556; train_loss_y=0.0004556; |val_loss_tot=0.0002403; |3075s
# Epoch 934/999: train_loss_tot=0.0004554; train_loss_y=0.0004554; |val_loss_tot=0.0002918; |3079s
# Epoch 935/999: train_loss_tot=0.000451; train_loss_y=0.000451; |val_loss_tot=0.0002931; |3082s
# Epoch 936/999: train_loss_tot=0.0004524; train_loss_y=0.0004524; |val_loss_tot=0.0002971; |3085s
# Epoch 937/999: train_loss_tot=0.0004517; train_loss_y=0.0004517; |val_loss_tot=0.0002759; |3088s
# Epoch 938/999: train_loss_tot=0.0004552; train_loss_y=0.0004552; |val_loss_tot=0.0002671; |3094s
# Epoch 939/999: train_loss_tot=0.0004594; train_loss_y=0.0004594; |val_loss_tot=0.000265; |3097s
# Epoch 940/999: train_loss_tot=0.0004528; train_loss_y=0.0004528; |val_loss_tot=0.0002677; |3100s
# Epoch 941/999: train_loss_tot=0.0004517; train_loss_y=0.0004517; |val_loss_tot=0.0002735; |3104s
# Epoch 942/999: train_loss_tot=0.000453; train_loss_y=0.000453; |val_loss_tot=0.0003195; |3107s
# Epoch 943/999: train_loss_tot=0.0004541; train_loss_y=0.0004541; |val_loss_tot=0.0002437; |3110s
# Epoch 944/999: train_loss_tot=0.0004533; train_loss_y=0.0004533; |val_loss_tot=0.0002777; |3113s
# Epoch 945/999: train_loss_tot=0.0004554; train_loss_y=0.0004554; |val_loss_tot=0.0002708; |3116s
# Epoch 946/999: train_loss_tot=0.0004537; train_loss_y=0.0004537; |val_loss_tot=0.0002841; |3120s
# Epoch 947/999: train_loss_tot=0.000457; train_loss_y=0.000457; |val_loss_tot=0.0003017; |3123s
# Epoch 948/999: train_loss_tot=0.0004558; train_loss_y=0.0004558; |val_loss_tot=0.0002757; |3126s
# Epoch 949/999: train_loss_tot=0.0004536; train_loss_y=0.0004536; |val_loss_tot=0.0002669; |3129s
# Epoch 950/999: train_loss_tot=0.0004548; train_loss_y=0.0004548; |val_loss_tot=0.0002793; |3133s
# Epoch 951/999: train_loss_tot=0.0004524; train_loss_y=0.0004524; |val_loss_tot= 0.00025; |3136s
# Epoch 952/999: train_loss_tot=0.0004578; train_loss_y=0.0004578; |val_loss_tot=0.0002796; |3139s
# Epoch 953/999: train_loss_tot=0.0004572; train_loss_y=0.0004572; |val_loss_tot=0.0002435; |3142s
# Epoch 954/999: train_loss_tot=0.0004599; train_loss_y=0.0004599; |val_loss_tot=0.0003183; |3145s
# Epoch 955/999: train_loss_tot=0.0004561; train_loss_y=0.0004561; |val_loss_tot=0.0002452; |3149s
# Epoch 956/999: train_loss_tot=0.0004502; train_loss_y=0.0004502; |val_loss_tot=0.0003007; |3152s
# Epoch 957/999: train_loss_tot=0.0004496; train_loss_y=0.0004496; |val_loss_tot=0.0002746; |3155s
# Epoch 958/999: train_loss_tot=0.0004566; train_loss_y=0.0004566; |val_loss_tot=0.0003384; |3159s
# Epoch 959/999: train_loss_tot=0.0004587; train_loss_y=0.0004587; |val_loss_tot=0.000271; |3162s
# Epoch 960/999: train_loss_tot=0.0004535; train_loss_y=0.0004535; |val_loss_tot=0.0002686; |3165s
# Epoch 961/999: train_loss_tot=0.0004583; train_loss_y=0.0004583; |val_loss_tot=0.0003327; |3168s
# Epoch 962/999: train_loss_tot=0.0004564; train_loss_y=0.0004564; |val_loss_tot=0.0002688; |3172s
# Epoch 963/999: train_loss_tot=0.0004513; train_loss_y=0.0004513; |val_loss_tot=0.0002729; |3175s
# Epoch 964/999: train_loss_tot=0.0004569; train_loss_y=0.0004569; |val_loss_tot=0.0002731; |3178s
# Epoch 965/999: train_loss_tot=0.0004529; train_loss_y=0.0004529; |val_loss_tot=0.0003361; |3182s
# Epoch 966/999: train_loss_tot=0.0004484; train_loss_y=0.0004484; |val_loss_tot=0.0002458; |3185s
# Epoch 967/999: train_loss_tot=0.0004536; train_loss_y=0.0004536; |val_loss_tot=0.0003047; |3188s
# Epoch 968/999: train_loss_tot=0.000455; train_loss_y=0.000455; |val_loss_tot=0.0002738; |3192s
# Epoch 969/999: train_loss_tot=0.0004526; train_loss_y=0.0004526; |val_loss_tot=0.0003273; |3195s
# Epoch 970/999: train_loss_tot= 0.00045; train_loss_y= 0.00045; |val_loss_tot=0.0002969; |3198s
# Epoch 971/999: train_loss_tot=0.0004564; train_loss_y=0.0004564; |val_loss_tot=0.0002686; |3201s
# Epoch 972/999: train_loss_tot=0.0004512; train_loss_y=0.0004512; |val_loss_tot=0.000279; |3204s
# Epoch 973/999: train_loss_tot=0.0004516; train_loss_y=0.0004516; |val_loss_tot= 0.00035; |3207s
# Epoch 974/999: train_loss_tot=0.0004554; train_loss_y=0.0004554; |val_loss_tot=0.0002808; |3211s
# Epoch 975/999: train_loss_tot=0.0004533; train_loss_y=0.0004533; |val_loss_tot=0.0002962; |3214s
# Epoch 976/999: train_loss_tot=0.0004547; train_loss_y=0.0004547; |val_loss_tot=0.000247; |3217s
# Epoch 977/999: train_loss_tot=0.0004557; train_loss_y=0.0004557; |val_loss_tot=0.0003417; |3220s
# Epoch 978/999: train_loss_tot=0.0004567; train_loss_y=0.0004567; |val_loss_tot=0.0002648; |3224s
# Epoch 979/999: train_loss_tot=0.0004502; train_loss_y=0.0004502; |val_loss_tot= 0.00025; |3227s
# Epoch 980/999: train_loss_tot=0.0004542; train_loss_y=0.0004542; |val_loss_tot=0.0002779; |3230s
# Epoch 981/999: train_loss_tot=0.0004509; train_loss_y=0.0004509; |val_loss_tot=0.0002775; |3233s
# Epoch 982/999: train_loss_tot=0.0004524; train_loss_y=0.0004524; |val_loss_tot=0.0003061; |3238s
# Epoch 983/999: train_loss_tot=0.0004515; train_loss_y=0.0004515; |val_loss_tot=0.0002639; |3242s
# Epoch 984/999: train_loss_tot=0.0004571; train_loss_y=0.0004571; |val_loss_tot=0.0003075; |3245s
# Epoch 985/999: train_loss_tot=0.000449; train_loss_y=0.000449; |val_loss_tot=0.0003164; |3248s
# Epoch 986/999: train_loss_tot=0.0004589; train_loss_y=0.0004589; |val_loss_tot=0.0002573; |3251s
# Epoch 987/999: train_loss_tot=0.0004541; train_loss_y=0.0004541; |val_loss_tot=0.0003374; |3254s
# Epoch 988/999: train_loss_tot=0.0004537; train_loss_y=0.0004537; |val_loss_tot=0.0002369; |3258s
# Epoch 989/999: train_loss_tot=0.0004571; train_loss_y=0.0004571; |val_loss_tot=0.0002736; |3261s
# Epoch 990/999: train_loss_tot=0.0004552; train_loss_y=0.0004552; |val_loss_tot=0.000382; |3264s
# Epoch 991/999: train_loss_tot=0.000448; train_loss_y=0.000448; |val_loss_tot=0.000244; |3267s
# Epoch 992/999: train_loss_tot=0.0004564; train_loss_y=0.0004564; |val_loss_tot=0.0003099; |3270s
# Epoch 993/999: train_loss_tot=0.0004517; train_loss_y=0.0004517; |val_loss_tot=0.0003222; |3274s
# Epoch 994/999: train_loss_tot=0.0004522; train_loss_y=0.0004522; |val_loss_tot=0.0002685; |3277s
# Epoch 995/999: train_loss_tot=0.0004526; train_loss_y=0.0004526; |val_loss_tot=0.0003027; |3280s
# Epoch 996/999: train_loss_tot=0.0004525; train_loss_y=0.0004525; |val_loss_tot=0.0002742; |3283s
# Epoch 997/999: train_loss_tot=0.0004525; train_loss_y=0.0004525; |val_loss_tot=0.0002753; |3286s
# Epoch 998/999: train_loss_tot=0.0004564; train_loss_y=0.0004564; |val_loss_tot=0.0002477; |3290s
# Epoch 999/999: train_loss_tot=0.0004506; train_loss_y=0.0004506; |val_loss_tot= 0.00035; |3293s
# Total elapsed time : 54m 53s
# Best val loss: 0.000202 (return best:False)
# Model weights saved in
# ./simgnn_data/saved_models/thesis/2C_dp_sim2real_learning_noise/sd0.01_1000epochs/Single_MP_step_sd0.01f1.0cxSqrt2_epochs1000.pkl
# ---
#
# - val_loss_tot =0.0003499815171538104;
# - val_loss_y =0.0003499815171538104;
# - val_loss_T =0.0;
# - val_loss_P =0.0;
# - val2_loss_tot =0.0004319380728696376;
# - val2_loss_y =0.0004319380728696376;
# - val2_loss_T =0.0;
# - val2_loss_P =0.0;
# - H1_loss_tot =9.988545235700724e-05;
# - H1_loss_y =9.988545235700724e-05;
# - H1_loss_T =0.0;
# - H1_loss_P =0.0;
# - H1raw_loss_tot =0.0014628166865615253;
# - H1raw_loss_y =0.0014628166865615253;
# - H1raw_loss_T =0.0;
# - H1raw_loss_P =0.0;

# %% [markdown]
# ---

# %% [markdown]
# ## Load Model and Check Performance

# %%
bs = 2
pred_loaders = {'train' : DataLoader(datasets_dict['train'], batch_size=bs, shuffle=True),
           'val': DataLoader(datasets_dict['val'], batch_size=bs),
           'val2': DataLoader(datasets_dict['val2'], batch_size=bs),
          'hara': DataLoader(datasets_dict['hara'], batch_size=bs)
          }

# %% [markdown]
# ### Simple GNN (1-MP layer)

# %%
from simgnn.models import Single_MP_step

# %%
save_dir = './simgnn_data/saved_models/thesis/velocity_MP_real2real/'

num_layers = 10

dropout_p = 0.1

upd_h_layers = max([0, num_layers//2])# Update MLP hidden_layers
update_hidden_dims=[128 for k in range(upd_h_layers-1)]+[16]
msg_h_layers = max([0, num_layers - upd_h_layers])# Message MLP hidden_layers
message_hidden_dims = [32 for k in range(msg_h_layers-1)] # assume output layer is hidden for MP step model

model_name = f'Single_MP_step_h{num_layers}_dp{dropout_p}bs2w5.pkl'
print(f'Loading:\n\t{model_name}')

net = Single_MP_step(node_in_features=window_size*2, node_out_features=2, edge_in_features=2,
                     message_out_features=32, message_hidden_dims=message_hidden_dims,
                     aggr='mean', update_hidden_dims=update_hidden_dims, dropout_p=dropout_p).to(device)
net_weights_dict = torch.load(path.join(save_dir, model_name), map_location=device)
net.load_state_dict(net_weights_dict)
net.eval();

# compute predictions and plot them
pred_out, tgt_out, sample_losses = predict_batch(net, pred_loaders,
                                                 loss_func=torch.nn.MSELoss(reduction='sum'),
                                                 use_force_loss = {k: False for k in pred_loaders},
                                                 return_losses = True, device=device)
print(''.join([f'- {k} ={sample_losses[k]};\n' for k in sample_losses]))
# Out:
# Loading:
# 	Single_MP_step_h10_dp0.1bs2w5.pkl
# - train_loss_tot =0.00017289492619655482;
# - train_loss_y =0.00017289492619655482;
# - train_loss_T =0.0;
# - train_loss_P =0.0;
# - val_loss_tot =0.00021682040902172646;
# - val_loss_y =0.00021682040902172646;
# - val_loss_T =0.0;
# - val_loss_P =0.0;
# - mid_loss_tot =0.00010372566669678488;
# - mid_loss_y =0.00010372566669678488;
# - mid_loss_T =0.0;
# - mid_loss_P =0.0;
# - late_loss_tot =0.00010987656334271798;
# - late_loss_y =0.00010987656334271798;
# - late_loss_T =0.0;
# - late_loss_P =0.0;

# %% [markdown]
# ---

# %% [markdown]
# ## Movie Predictions

# %%
# !rm -dr simgnn_data/hara_movies/processed

# %%
hara = HaraMovies('simgnn_data/hara_movies/', window_size=window_size, transform=Tnorms['hara'], smoothing=True, sma_lag_time=4)
# Out:
# Processing...
# Done!

# %%
dataset_mov_names = {}
dataset_mov_idx = {}
dataset_mov = {}

d_names_list = [k.split('_')[2] for k in hara.processed_file_names]
    
dataset_mov_names['hara'] = {k : ki for ki, k in enumerate(np.unique(d_names_list))}
    
dataset_mov_idx['hara'] = torch.tensor([dataset_mov_names['hara'][k] for k in d_names_list])
    
dataset_mov['hara'] = {k:hara[dataset_mov_names['hara'][k]==dataset_mov_idx['hara']]
                              for k in dataset_mov_names['hara']}
dataset_mov
# Out:
# {'hara': {'001': HaraMovies(55), '003': HaraMovies(55), '005': HaraMovies(55)}}

# %% [markdown]
# - **Model Predictions for Movies**; Predict `Velocity[T+1]` for movies

# %%
from simgnn.train import np_loss_wrt_time, predict_dataset

from scipy.stats import pearsonr

# %%
velocity_scale
# Out:
# {'train': 1.0, 'val': 1.0, 'val2': 1.0, 'hara': 26.32}

# %%
ignore_short_edges, edge_len_threshold = False, 10**-4

# %%
model_results = {}
loss_type = 'mse'

for dataset_k in dataset_mov:
    print('-'*10+'\n'+dataset_k)
    model_results[dataset_k] = {}
    for mov_i in dataset_mov[dataset_k]:
        if None != dataset_mov[dataset_k][mov_i][0].edge_id:
            num_edges = torch.unique(dataset_mov[dataset_k][mov_i][0].edge_id).size(0)
        else:
            num_edges = dataset_mov[dataset_k][mov_i][0].num_edges
        print('\t',mov_i,f': len={len(dataset_mov[dataset_k][mov_i])};',
              f'E_n={num_edges};',
              f'V_n={dataset_mov[dataset_k][mov_i][0].num_nodes};',
              f'C_n={dataset_mov[dataset_k][mov_i][0].num_cells};', end=' ')

        model_results[dataset_k][mov_i] = predict_dataset(net, dataset_mov[dataset_k][mov_i],device=device, concat=True)


        # Edge indices
        if None != dataset_mov[dataset_k][mov_i][0].edge_id:
            edge_index = dataset_mov[dataset_k][mov_i][0].edge_index[:,torch.unique(dataset_mov[dataset_k][mov_i][0].edge_id)]
        else:
            edge_index = dataset_mov[dataset_k][mov_i][0].edge_index

        model_results[dataset_k][mov_i]['edge_index'] = edge_index
        
        # Vertex pos [targets]
        pos = np.concatenate([d.pos.reshape(1,-1,2) for d in dataset_mov[dataset_k][mov_i]],axis=0)
        model_results[dataset_k][mov_i]['targets']['pos'] = pos
        
        # Edge lengths [targets]
        edge_lengths = np.linalg.norm(pos[:, edge_index[1],:] - pos[:, edge_index[0],:], axis=-1)
        model_results[dataset_k][mov_i]['targets']['edge_lengths'] = edge_lengths
        
        # Compute predicted vertex pos, edge lengths
        dx_unnorm = velocity_scale[dataset_k]*model_results[dataset_k][mov_i]['predictions']['velocity']
        # pos predictions w/ velocity (except for first pos)
        pos_preds = np.concatenate([pos[:1],(pos+dx_unnorm)[:-1]], axis=0)
        model_results[dataset_k][mov_i]['predictions']['pos'] = pos_preds

        model_results[dataset_k][mov_i]['predictions']['edge_lengths'] = np.linalg.norm(pos_preds[:, edge_index[1],:] - pos_preds[:, edge_index[0],:], axis=-1)
        if ignore_short_edges:
            edge_mask = np.all(np.concatenate([dk.edge_length.numpy().reshape(1,-1)
                                               for dk in dataset_mov[dataset_k][mov_i]], axis=0) > edge_len_threshold, axis=0)
            model_results[dataset_k][mov_i]['predictions']['edge_masks'] = edge_mask
        else:
            model_results[dataset_k][mov_i]['predictions']['edge_masks'] = None
        
        model_results[dataset_k][mov_i]['loss'] = {}
        
        # velocity losses
        if len(model_results[dataset_k][mov_i]['targets']['velocity']) > 0:
            model_results[dataset_k][mov_i]['loss']['velocity'] = np_loss_wrt_time(model_results[dataset_k][mov_i]['predictions']['velocity'],
                                                                                   model_results[dataset_k][mov_i]['targets']['velocity'])
        else:
            model_results[dataset_k][mov_i]['loss']['velocity'] = np.full((model_results[dataset_k][mov_i]['predictions']['velocity'].shape[1],), np.nan)
        
#         # tension losses
#         if len(model_results[dataset_k][mov_i]['targets']['tension']) > 0:
#             model_results[dataset_k][mov_i]['loss']['tension'] = np_loss_wrt_time(model_results[dataset_k][mov_i]['predictions']['tension'],
#                                                                                   model_results[dataset_k][mov_i]['targets']['tension'])
#         else:
#             model_results[dataset_k][mov_i]['loss']['tension'] = np.full((model_results[dataset_k][mov_i]['predictions']['tension'].shape[1],), np.nan)

#         if ignore_short_edges:
#             model_results[dataset_k][mov_i]['loss']['tension_mask'] = model_results[dataset_k][mov_i]['loss']['tension'].copy()
#             model_results[dataset_k][mov_i]['loss']['tension_mask'][~edge_mask] = np.nan
#         else:
#             model_results[dataset_k][mov_i]['loss']['tension_mask'] = None
        model_results[dataset_k][mov_i]['loss']['edge_lengths'] = np_loss_wrt_time(model_results[dataset_k][mov_i]['predictions']['edge_lengths'],
                                                                                   model_results[dataset_k][mov_i]['targets']['edge_lengths'])
        
        print(f"Losses: Vel-y={np.nanmean(model_results[dataset_k][mov_i]['loss']['velocity']):6.4f}; "+
              f"E_len={np.nanmean(model_results[dataset_k][mov_i]['loss']['edge_lengths']):6.4f}; "+
#               f"Tension={np.nanmean(model_results[dataset_k][mov_i]['loss']['tension']):6.4f};"+
             f"Tension(mask)={np.nanmean(model_results[dataset_k][mov_i]['loss']['tension_mask']) if ignore_short_edges else 0.0:6.4f}")
# Out:
# ----------
# hara
# 	 001 : len=55; E_n=225; V_n=164; C_n=128; Losses: Vel-y=0.0001; E_len=0.0862; Tension(mask)=0.0000
# 	 003 : len=55; E_n=149; V_n=119; C_n=124; Losses: Vel-y=0.0001; E_len=0.0657; Tension(mask)=0.0000
# 	 005 : len=55; E_n=164; V_n=130; C_n=114; Losses: Vel-y=0.0001; E_len=0.0986; Tension(mask)=0.0000

# %%
dataset_k, mov_i = 'hara', '001'  # ['val2']['sim005']

# Lij = model_results['targets']['edge_lengths']
# Lij_p = model_results['val2']['sim005']['predictions']['edge_lengths']
Lij = model_results[dataset_k][mov_i]['targets']['edge_lengths']
Lij_p = model_results[dataset_k][mov_i]['predictions']['edge_lengths']

k=[101]
plt.figure(figsize=[4,4])
plt.plot(Lij[:,k], 'o-', c='orange', ms=7, alpha=.9,label=['gt']+[None for ki in k[1:]])
plt.plot(Lij_p[:,k], '-',c='royalblue', lw=2, alpha=.8, label=['pred']+[None for ki in k[1:]]);
plt.title(f'{dataset_k}({mov_i}); Edge:{k}, lengths')
plt.legend();

# %%
pos = model_results[dataset_k][mov_i]['targets']['pos']
pos_p = model_results[dataset_k][mov_i]['predictions']['pos']

e_st = model_results[dataset_k][mov_i]['edge_index'][:,k]
e_st_list = e_st.ravel().tolist()
plt.figure(figsize=[7,7])
plt.plot(pos[:,e_st_list,0],pos[:,e_st_list,1], '-', c='orange', lw=3, alpha=.9,label=['gt']+[None for k in range(len(e_st_list)-1)])
plt.plot(pos_p[:,e_st_list,0],pos_p[:,e_st_list,1], '-',c='royalblue', lw=2, alpha=.8, label=['pred']+[None for k in range(len(e_st_list)-1)]);

plt.plot(pos[0,e_st_list,0],pos[0,e_st_list,1], 'o', c='orange', ms=10, alpha=.8,label='start')
# for e_k in range(e_st.shape[1]):
#     plt.plot(pos[-1,e_st[:,e_k],0],pos[-1,e_st[:,e_k],1], '-', c='orange', lw=4, alpha=.5)
#     plt.plot(pos_p[-1,e_st[:,e_k],0],pos_p[-1,e_st[:,e_k],1], '-',c='navy', lw=4, alpha=.4);
plt.title(f'{dataset_k}({mov_i}); V:{e_st_list}, position')
# plt.xlim([340, 380])
# plt.ylim([240, 200])
# plt.axis(False)
plt.legend();

# %% [markdown]
# **Noise training noisy eval**

# %%
dataset_k, mov_i = 'hara', '001'  # ['val2']['sim005']

# Lij = model_results['targets']['edge_lengths']
# Lij_p = model_results['val2']['sim005']['predictions']['edge_lengths']
Lij = model_results[dataset_k][mov_i]['targets']['edge_lengths']
Lij_p = model_results[dataset_k][mov_i]['predictions']['edge_lengths']

k=[101]
plt.figure(figsize=[4,4])
plt.plot(Lij[:,k], 'o-', c='orange', ms=7, alpha=.9,label=['gt']+[None for ki in k[1:]])
plt.plot(Lij_p[:,k], '-',c='royalblue', lw=2, alpha=.8, label=['pred']+[None for ki in k[1:]]);
plt.title(f'{dataset_k}({mov_i}); Edge:{k}, lengths')
plt.legend();

# %%
pos = model_results[dataset_k][mov_i]['targets']['pos']
pos_p = model_results[dataset_k][mov_i]['predictions']['pos']

e_st = model_results[dataset_k][mov_i]['edge_index'][:,k]
e_st_list = e_st.ravel().tolist()
plt.figure(figsize=[7,7])
plt.plot(pos[:,e_st_list,0],pos[:,e_st_list,1], '-', c='orange', lw=3, alpha=.9,label=['gt']+[None for k in range(len(e_st_list)-1)])
plt.plot(pos_p[:,e_st_list,0],pos_p[:,e_st_list,1], '-',c='royalblue', lw=2, alpha=.8, label=['pred']+[None for k in range(len(e_st_list)-1)]);

plt.plot(pos[0,e_st_list,0],pos[0,e_st_list,1], 'o', c='orange', ms=10, alpha=.8,label='start')
# for e_k in range(e_st.shape[1]):
#     plt.plot(pos[-1,e_st[:,e_k],0],pos[-1,e_st[:,e_k],1], '-', c='orange', lw=4, alpha=.5)
#     plt.plot(pos_p[-1,e_st[:,e_k],0],pos_p[-1,e_st[:,e_k],1], '-',c='navy', lw=4, alpha=.4);
plt.title(f'{dataset_k}({mov_i}); V:{e_st_list}, position')
# plt.xlim([340, 380])
# plt.ylim([240, 200])
# plt.axis(False)
plt.legend();
